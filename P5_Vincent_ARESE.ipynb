# %% [markdown]
# <a href="https://colab.research.google.com/github/vincent-arese/OC-P5/blob/main/P5_Vincent_ARESE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color="00CED1">  Config Env de travail </font>   <a id="EnvTravail"></a>

# %% [markdown]
# ### pip install

# %%
# Prepa Env PIP
# librairie pour combiner Pyhton & SQL https://towardsdatascience.com/fugue-and-duckdb-fast-sql-code-in-python-e2e2dfc0f8eb
#!pip install -U fugue[duckdb,sql] 
# !pip install pandas-bokeh

#  TO DEL    !pip install -U dash 

# ! pip list -v
# ! pip list -v | grep [Pp]an 
# ! pip list -v | grep [Pp]lot
# ! pip list -v | grep [Ss]ea
# ! pip list -v | grep [Bb]l
# ! pip list -v | grep [Aa]ut
# ! pip install --upgrade pandas

# %% [markdown]
# ## Librairies

# %%
# librairies Pythons 
import numpy as np
import pandas as pd
from pandas.core.groupby.generic import DataFrameGroupBy
pd.set_option('display.max_columns',None)  #pd.set_option('max_columns', 10) limiter le nbr de colonnes visualisé à 10 /none (=> scrollbar)
pd.set_option('display.max_rows', 40)
import scipy.stats as stats  
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
# import pandas_bokeh
#import fugue_duckdb
#from fugue_notebook import setup ;setup()

#_____________________________________________________________________________
# Python print Color
class pcolors:
    OK = '\033[92m' #GREEN
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR

#Source : https://www.delftstack.com/fr/howto/python/python-print-colored-text/

#Exemple 
print(pcolors.OK + "File Saved Successfully!" + pcolors.RESET)
print(pcolors.WARNING + "Warning: Are you sure you want to continue?" + pcolors.RESET)
print(pcolors.FAIL + "Unable to delete record." + pcolors.RESET)

print(f"{pcolors.OK}File Saved Successfully!{pcolors.RESET}")
print(f"{pcolors.WARNING}Warning: Are you sure you want to continue?{pcolors.RESET}")
print(f"{pcolors.FAIL}Unable to delete record.{pcolors.RESET}")
#-----------------------------------------------------


#  Importer les données en Pandas dataframe
#aideDataPATH='/content/drive/MyDrive/DataSc/P4VA/'
DataPATH='https://raw.githubusercontent.com/vincent-arese/OC-P04VA/main/FAOdata/'
# Out:
# File Saved Successfully!
# Warning: Are you sure you want to continue?
# Unable to delete record.
# File Saved Successfully!
# Warning: Are you sure you want to continue?
# Unable to delete record.

# %% [markdown]
# ## Fonctions Perso

# %% [markdown]
# #### <font color="red"> Cellules de bloc-notes template </font>

# %% [markdown]
# * https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf
#
# * https://colab.research.google.com/drive/1-mfcGT9FvROM6pOL2_uNtx4ywrf6IlBn#scrollTo=icxtjOVUqN7F
#
# * https://html-color-codes.info/Codes-couleur-HTML/
#
# * https://docs.bokeh.org/en/latest/docs/gallery.html

# %%
#########################################################################
# DEBUG & Search !      Version 1.1                                     #
#########################################################################
# dt=BilanAlim
col=['index']

# dt.info()
# dt.describe(include='all')
# dt.describe(include='category')

#~~Search NaN ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SearchNaN(dt,1)
# dt.isnull().sum().sum()  # Is nul total df 
# SearchNaN(dt,2)
# SearchNaN(dt,2).CodeZone.sort_values(na_position='first').unique()
# len(SearchNaN(dt,2).CodeZone.sort_values(na_position='first').unique())
# SearchNaN(dt,2).Zone.sort_values(na_position='first').unique()
# SearchNaN(dt,2).Année.sort_values(na_position='first').unique()

# dt.replace([np.inf, -np.inf], np.nan, inplace=True) # Remplacer les infini par des NaN (division ! )

#~~Search values ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# SearchListe(dt,[0])
# SearchListe(dt,[0,np.nan,np.inf,-np.inf])
# SearchListe(dt,[ 1, 249, 250, 273, 276, 351])
# SearchListe(dt,[0]).CodeZone
# dt.CodeZone.sort_values(ascending=True,na_position='first').unique()
# dt.iloc[:,12].sort_values(ascending=True,na_position='first').unique()
#  dt.iloc[:,2].unique()
# dt.iloc[:,3:19]
# dt.AlphaISO3.sort_values(ascending=True,na_position='first').unique()
# len(dt.AlphaISO3.sort_values(ascending=True,na_position='first'))



#__Liste valeur unique dans chaque colonne du df  _____________
# for col in ListeCol: 
#   # print(col,':',len(dt[col].unique()),': \n',dt[col].sort_values(ascending=True,na_position='first').unique(),'\n______________\n')
#   print(col,':',len(dt[col].unique()),': \n',dt[col].unique(),'\n______________\n') #Unsorted
#-----------

#~~ Différences liste ou df ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# LostElement(A_array,B_array)
# get_different_rows(source_df, new_df)
# ListeColUnique(dt)


#~~ Différences liste ou df ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# df=dt
# regex="^[Tt]h.*"
# df[df.Zone.str.contains(regex)]
#-----------


#~~ Dtype ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 0.  # dtype Category => object (str)
# reduce_mem_usage(dt) # Optisation dtype
#__iloc dtype change ____________________
# for i in range(2,5):
#   dt.iloc[:,i]=dt.iloc[:,i].astype(float)
#-----------

#------ test Erreur dtype trop Petit: 

# print('Min',dt[col].min(),'Moy',dt[col].mean(),'Max',dt[col].max(),'Sum',dt[col].sum())  


# dt.info()

##### Df List
# SecuAlimGeo

##################### Aide memoire ##################
# [i for i in range(2,12)]

# dt.iloc[:, [2,3,12,14,15]]
# dt.iloc[:,[i for i in range(18)]],2)

# ColMove(df,ColName,ColIndex)
# df= df.iloc[:,[0,1,2,3,7,12,16]]
# o
####################################################


# print(BilanAlimGeo.Semences.max(),BilanAlimGeo.Semences.mean(), BilanAlimGeo.Semences.min(),BilanAlimGeo.Semences.sum(),BilanAlimGeo.Semences.count())
# !cat /proc/meminfo # Voir RAM

# %%
#########################################################################
# DEBUG & Compare Sum      Version 1.01                                 #
#########################################################################

df = pd.DataFrame({'num': [1, 2, 3], 'colors': ['red', 'white', 'blue']})
#_____________________________________________________________
# Parametre Compare Somme
dfREF=df
RechercheTest="num>0"
listeCol=dfREF.columns   # listeCol=dfREF.columns # pour filter toutes les colonnes de dfREF

df1=dfREF
df1TEXTE='Version1'

df2=dfREF
df2TEXTE='Version2'
# Itere  listeCol pour chaque df(n) et teste somme df(n) = somme dfREF 
#-------------------------------------------

for Col in listeCol:
  Col_type = dfREF[Col].dtype
  if Col_type != object and Col_type != "category":  #  Si le dtype != object & category => de type Nombre ! 
    if Col in df1.columns:   
      Test1=df1.query(RechercheTest)[Col].sum()
    if Col in df2.columns:
        Test2=df2.query(RechercheTest)[Col].sum()

    Ref=dfREF.query(RechercheTest)[Col].sum()
    if Test1!=Ref or Test2!=Ref:
       print(dfREF.columns.get_loc(Col),'~',Col,'~dtype(',Col_type,')   ', df1TEXTE,':',Test1==Ref,' - ',df2TEXTE,':',Test2==Ref)
    else:
      print(dfREF.columns.get_loc(Col),'~',Col,pcolors.OK +'~dtype(',Col_type,')  : Somme  Ok'+ pcolors.RESET)  # La somme  colonne est identique 
  else:
    Test1un=0
    Test2un=0
    if Col in df1.columns:   
      Test1un=df1.query(RechercheTest)[Col].unique().sum()
    if Col in df2.columns:
      Test2un=df2.query(RechercheTest)[Col].unique().sum()

    Refun=dfREF.query(RechercheTest)[Col].unique().sum()
    if Test1un !=Refun or Test2un !=Refun:
      print(dfREF.columns.get_loc(Col),'~',Col,'~dtype(',Col_type,')   ', df1TEXTE,':',Test1un==Refun,' - ',df2TEXTE,':',Test2un==Refun)
    else:
      print(dfREF.columns.get_loc(Col),'~',Col,pcolors.OK +'~dtype(',Col_type,')  : Concat OK'+ pcolors.RESET)   # La somme (textes concaténés)  colonne est identique 

#_FIN______________________________________________________
# Out:
# 0 ~ num ~dtype( int64 )  : Somme  Ok
# 1 ~ colors ~dtype( object )  : Concat OK

# %% [markdown]
# #### Liste Fonctions

# %% [markdown]
# ### Search

# %%
def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name
#source : https://stackoverflow.com/questions/31727333/get-the-name-of-a-pandas-dataframe   Pour les series utiliser .name  (ou .names )

# %% [markdown]
# ##### Search NaN  SearchNaN(DataFrame,Option)

# %%
#Fonction ChercheNaN : Recherche des NaN
def SearchNaN(DataFrame,Option):
  """ChercheNaN : Recherche des NaN
  
  Option : 
  1: Total nombre de NaN par colonne
  2: Afficher les lignes ayant au moins 1 NaN
  3: Nomnbre de lignes ayant 1 NaN
  """
  df_name = get_df_name(DataFrame)

  if Option==1:
   return print(pcolors.OK+ df_name +pcolors.RESET,': Nombre de NaN par colonne (total lignes',len(DataFrame),'):/n' ,
                DataFrame.isnull().sum(axis=0),'\n------%-----\n',
                (DataFrame.isnull().sum(axis=0)/len(DataFrame))*100) #  Option1 : Total nombre de NaN par colonne
  elif Option==2:
    return DataFrame[DataFrame.isnull().any(axis=1)]  #Afficher les lignes ayant au moins 1 NaN
  elif Option==3: 
    return print(pcolors.OK+ df_name +pcolors.RESET,': Nombre de ligne(s) ayant au moins 1 NaN :',
                 len(DataFrame[DataFrame.isnull().any(axis=1)]),'\n-----%------\n',
                 (len(DataFrame[DataFrame.isnull().any(axis=1)])/len(DataFrame))*100)
  else:
    print("SearchNaN(DataFrame,Option) Error :","Choisir Option :\n",
          "\n 1: Total nombre de NaN par colonne",
          "\n 2: Total nombre de NaN par colonne",
          "\n 3: Nomnbre de lignes ayant 1 NaN")

# DEBUG  recherche NaN
# temp=geo
# temp.isnull().sum(axis=0) #  Option1 : Total nombre de NaN par colonne
# test=temp[temp.isnull().any(axis=1)] ; test #Afficher les lignes ayant au moins 1 NaN
# len(test)
# test.Zone.unique()

# %% [markdown]
# ##### SearchListe(df,liste)

# %%
# Recherche une liste dans un DataFrame
def SearchListe(df,liste):
  """Recherche une liste dans un DataFrame et renvoie Df avec les Valeur pour masque SearchListe(dx,[2,4,7]) - liste=[2,4,7]/ SearchListe(dx,liste) accepte liste unique liste=[1]"""
  return df[df.isin(liste)].dropna(thresh=1)

# Exemple : 
# dx = pd.DataFrame(np.random.randint(10, size=(10, 3)),
#                      columns=['A', 'B', 'C'])
# dx
# SearchListe(dx,[2,4,7])
# liste=[2,4,7]
# SearchListe(dx,liste)
# SearchListe(dx,l)

# %% [markdown]
# ##### ListeCol Unique

# %%
def ListeColUnique(df):
  """ Itere sur les colonnes d'un DataFrame(df) et listes les valeurs unique de chaque colonne"""
  ListeCol=df.columns
  df_name = get_df_name(df)
  print(ListeCol)
  for col in ListeCol: 
     print(col,':',len(df[col].unique()),': \n',df[col].sort_values(ascending=True,na_position='first').unique(),'\n______________\n')

# %% [markdown]
# ##### SearchKey(df)

# %%
def SearchKey(df):
  """ Itere sur les colonnes d'un DataFrame(df) et Compte les valeurs uniques de chaque colonne"""
  ListeCol=df.columns
  df_name = get_df_name(df)
  # print('Liste colonnes :',pcolors.OK +ListeCol+ pcolors.RESET)
  print('\n______________________________________________________________________________________\n',
        "Recherche  valeurs uniques : ",
        pcolors.WARNING+ df_name +pcolors.RESET," ",
        # df.shape,
        "(",len(df),"Lignes,",len(ListeCol),"Colonnes)",
        '\n______________________________________________________________________________________')
  for col in ListeCol: 
    NbUnique=df[col].nunique()
    Nbdoublons=len(df)-NbUnique
    if Nbdoublons==0:
      print(pcolors.OK +col,":"+pcolors.RESET,len(df),"rows",
          "|Nb unique:",NbUnique,
          "|Nb doublons:", Nbdoublons, "-",
          np.round(((len(df)-NbUnique)/len(df))*100,0),'%',
          pcolors.OK+"Clé candidate"+pcolors.RESET,
          "|",df[col].dtype,
          '\n____________________________________________________________________________________')
    elif Nbdoublons!=0:
      print(pcolors.OK+col,":"+pcolors.RESET,len(df),"rows",
          "|Nb unique:",NbUnique,
          "|Nb doublons:", Nbdoublons, "-",
          np.round(((len(df)-NbUnique)/len(df))*100,0),'%', 
          "|",df[col].dtype,     
          '\n______________________________________________________________________________________')

# %% [markdown]
# ##### np.Array  LostElement(Array1,Array2)

# %%
# Rechercher un élément perdu à partir d’un tableau dupliqué 
def LostElement(A,B):
  """Rechercher un élément perdu à partir d’un tableau dupliqué
    LostElement(ArrayA,ArrayB)  ou LostElement(df.A.unique(),df.B.unique())
    Compare deux np.array !!!!
      =>  DifférenceA=>B  : Valeur incluse dans A mais Non dans B 
      =>  DifférenceB=>A  : Valeur incluse dans B mais Non dans A
  """

  # return print('ArrayA:',A,'- Nb val:',len(A),'\n ArrayB:',B,'- Nb val:',len(B),pcolors.OK + '\n----------------------\n Différence inA=>notB',np.setdiff1d(A, B),'\n----------------------\n Différence inB=>notN',np.setdiff1d(B, A),'\n----------------------\n'+ pcolors.RESET)
  return print('\n----------------------\n',
               pcolors.OK +'Diff. inA=>notB'+ pcolors.RESET,np.setdiff1d(A, B),'\n----------------------\n',
               pcolors.OK+'Diff. inB=>notA'+ pcolors.RESET,' ',np.setdiff1d(B, A),'\n----------------------\n',
               pcolors.OK +'ArrayA:'+ pcolors.RESET,A,'- Nb val:',len(A),'\n',
               pcolors.OK +'\n ArrayB:'+ pcolors.RESET,B,'- Nb val:',len(B),'\n----------------------\n')

# %% [markdown]
# ##### Différences entre deux df get_different_rows(source_df, new_df)

# %%
def get_different_rows(source_df, new_df):
    """Returns just the rows from the new dataframe that differ from the source dataframe"""
    merged_df = source_df.merge(new_df, indicator=True, how='outer')
    changed_rows_df = merged_df[merged_df['_merge'] == 'right_only']
    return changed_rows_df.drop('_merge', axis=1)


#Trouver les lignes peu communes entre deux DataFrames
# pd.concat([SecuAlimGeo,SecuAlim]).drop_duplicates(keep=False)

# #Trouver les lignes peu communes entre deux DataFrames
# pd.concat([SecuAlimGeo,SecuAlim]).drop_duplicates(keep=False)

# %% [markdown]
# ### Manip DataFrame

# %% [markdown]
# ##### ColMove(df,ColName,ColIndex)

# %%
# Deplacer une colonne dans un dataframe 
def ColMove(DataFrame,ColName,ColIndex):
  """Fonction  ColMove(DataFrame,ColName,ColIndex)  
   Deplace un colonne dans un DataFrame  - ColName : nom colonne  - ColIndex : rang index souhaité (ddbut df 0 !)
  """ 
  DataFrame.insert(ColIndex,'Xcol',DataFrame[ColName])
  DataFrame.drop(ColName, axis=1, inplace=True)
  DataFrame.rename(columns={'Xcol' : ColName},inplace=True)
  return DataFrame

# %% [markdown]
# ##### Change dtype Category to Object : dtypeCat2Obj(df)

# %%
def dtypeCat2Obj(df):
    """  iterate through all the columns of a dataframe and 
    modify the Dtype Catergory to Object (Str)       
    """
     
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type == 'category':
             df[col] = df[col].astype(str)    
           
    return df

# %%
def DataChangeCat2Obj(df):
    """  iterate through all the columns of a dataframe and 
    modify the Dtype Catergory to Object (Str)       
    """
     
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type == 'category':
             df[col] = df[col].astype(str)    
           
    return df

# %% [markdown]
# ##### ReduceMemUsage reduce_mem_usage(df)

# %%
# Drastically reduce df RAM usage ! 
#I don't know who the original author of this function but many thanks to him ;) 
#source : https://towardsdatascience.com/how-to-learn-from-bigdata-files-on-low-memory-incremental-learning-d377282d38ff
def reduce_mem_usage(df):
    """ 
    iterate through all the columns of a dataframe and 
    modify the data type to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage of dataframe is {:.2f}' 
                     'MB').format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max <\
                  np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max <\
                   np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max <\
                   np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max <\
                   np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max <\
                   np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max <\
                   np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    print(('Memory usage after optimization is: {:.2f}' 
                              'MB').format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) 
                                             / start_mem))
    
    return df

    # Attention ne fct pas si le df à optimizer contient un type 'category'
  #Code ...........
    # df.info(memory_usage=True)
    # DataFrame.memory_usage(index=True, deep=False)

# %% [markdown]
# ###### dtype Min-Max

# %%
pd.DataFrame.from_dict(
{'np.int8:':[np.iinfo(np.int8).min, np.iinfo(np.int8).max],
'np.int16:':[np.iinfo(np.int16).min, np.iinfo(np.int16).max],
'np.int32:':[np.iinfo(np.int32).min, np.iinfo(np.int32).max],
'np.int64:':[np.iinfo(np.int64).min, np.iinfo(np.int64).max],
'np.float16:':[np.finfo(np.float16).min, np.finfo(np.float16).max],
'np.float32:':[np.finfo(np.float32).min, np.finfo(np.float32).max],
'np.float64:':[np.finfo(np.float64).min, np.finfo(np.float64).max]})

## info complementaire https://towardsdatascience.com/reducing-memory-usage-in-pandas-with-smaller-datatypes-b527635830af
# Out:
#    np.int8:  np.int16:   np.int32:            np.int64:  np.float16:  \
# 0      -128     -32768 -2147483648 -9223372036854775808     -65504.0
# 1       127      32767  2147483647  9223372036854775807      65504.0
#
#     np.float32:    np.float64:
# 0 -3.402823e+38 -1.797693e+308
# 1  3.402823e+38  1.797693e+308

# %% [markdown]
# ##### MultiDOWN ( Conversion multi-index  à index simple)

# %%
#Fonction multiDOWN : Conversion df_MultiIndex to df_indexSimple
def multiDOWN(DataFrame):
  """Fonction multiDOWN(DataFrame) : Conversion DataFrame_MultiIndex to DataFrame_indexSimple"""
  DataFrame=DataFrame.columns=DataFrame.columns.to_flat_index() # colonnes => concatener le multi index en un index simple https://datascientyst.com/flatten-multiindex-in-pandas/
  DataFrame.reset_index(inplace=True) # Conversion Index en colonnes simple.
 

  # probleme  d'execution

# %% [markdown]
# ### Fonction Satistiques

# %% [markdown]
# ##### PercentCumul(df,Col) Calcul % cumulé

# %%
# Tri ordre decroissant puis ajoute Colonnne avec Calcul % cumulé pour identifier 20/80 ou 80/20 
def PercentCumul(df,Col):
  """ Tri ordre decroissant puis ajoute Colonnne Col_cum% avec Calcul % cumulé pour identifier facilement 20/80 ou 80/20 """
  df=df.sort_values(by=[Col],ascending=False)
  df[Col+'_percent']=(df[Col]/df[Col].sum()) * 100
  df[Col+'cum_p']=(df[Col].cumsum() / df[Col].sum()) * 100
  df[Col+'_percent']=df[Col+'_percent'].round(2)
  df[Col+'cum_p']=df[Col+'cum_p'].round(2)
 
  # df=df.sort_values(by=[Col+'cum_%'],ascending=False)
  
  return df


# Cf cumsum() pour  SommeCumulée
 #https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.cumsum.html

# %% [markdown]
# #### Moyenne Pondérée

# %%
# Calcul Moyenne Pondérée / Weighted Average

def MoyPonderee(df, Colvalues, Colweights):
  """ Moyenne Pondérée / Weighted Average
    df: DataFrame  - Colvalues : Col Valeurs  - Colweights : Col. Poids relatif 
  Peut être utlisée avec un Groupby : df.groupby('Year').apply(MoyPonderee, 'Grades', 'NumCourses')
  Source :  Rework of https://datagy.io/pandas-weighted-average/ 
  """
  return sum(df[Colweights] * df[Colvalues]) / df[Colweights].sum()


# Source Rework of https://datagy.io/pandas-weighted-average/

# %% [markdown]
# #### QartileIndicatorCol(df,col) Ajout Colonne quartile

# %%
# Ajout colonne conditionnelle quartile

def QartileIndicatorCol(df,col): 
  """ Ajout d'un colonne Conditionelle avec le quartile au df courant  & Recherce Ouliers Methode IQ ( InterQuartiles)
QartileIndicatorCol(df,col) => df[col+"Quartile"] """

  # Caculs Seuils des quartiles 
  q25=df[col].quantile(q=0.25, interpolation='linear') # Q1 1er Quartile
  q50=df[col].quantile(q=0.50, interpolation='linear') # Q2 2eme Quartile
  q75=df[col].quantile(q=0.75, interpolation='linear') # Q3 3eme Quartile

  # Conditions & label 
  conditionlist = [
    (df[col] <= q25) ,
    (df[col] > q25) & (df[col] <q75),
    (df[col] >= q75)]
   
  choicelist = ['quartile1','quartile2','quartile3']

  df[col+"Quartile"] = np.select(conditionlist, choicelist, default='Not Specified')

 #  methode des interquartiles
  df[col+"InterQuartile"]=df[col]>(q75-q25)

  df.loc[df[col] <= (q75-q25) , ColCatName] = "Outlier?"

  return df

# %% [markdown]
# ####  Zscore :  Zscore(df,Col)

# %%
def Zscore(df,Col): 
  """Zscore(df,Col) :  Ajout colonnes Zscore_Col &  NivConf_Zscore_col
                      'ZSscore Omlit NaN  & Interepretion Niv confiance
  Parametres  Df: DataFrame & col : Colonne
  """
  import scipy.stats as stats 
  #https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.zscore.html
  df["Zscore_"+Col] = stats.zscore(df[Col], axis=0, nan_policy='omit')

  #https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html 
  # df["ZscoreManuel"+Col] = (df[Col] - df[Col].mean())/df[Col].std(ddof=0) # Calcul Zscore Manuel
  
  Za=2.58 ;ZaConf="90%" # seuil confiance 90% 
  Zb=1.96 ;ZbConf="95%"# seuil confiance95% 
  Zc=1.65 ;ZcConf="99%"# seuil confiance 99% 
  # source : https://pro.arcgis.com/fr/pro-app/2.7/tool-reference/spatial-statistics/what-is-a-z-score-what-is-a-p-value.htm
  #  np.abs(z_score) > threshold:


  # Colonne Interpration Zscore 
  ColRefName="Zscore_"+Col # Nom Colonne de référence pour la segmentation
  ColCatName="Seuil_ConF_Zscore" # Nom Colonne Categorie
  df[ColCatName]="?"
  df[ColRefName].fillna(0,inplace=True)
  
  df.loc[np.abs(df[ColRefName]) > Za , ColCatName] = "Inférieur à "+ZaConf 
  df.loc[np.abs(df[ColRefName]) <= Za , ColCatName] = ZaConf    # utilisation de la Valeur Absolue (-za <= Seuil confiance <= Za )
  df.loc[np.abs(df[ColRefName]) <= Zb , ColCatName] = ZbConf
  df.loc[np.abs(df[ColRefName]) <= Zc , ColCatName] = ZcConf

  df.sort_values(ColRefName, inplace=True)


  print(ColRefName,ColCatName)
  return df

# %% [markdown]
# # <font color="00CED1">  Dataset  Ventes en lignes Bottleneck </font>

# %% [markdown]
# ## Import RAW

# %% [markdown]
# https://openclassrooms.com/fr/paths/324/projects/858/assignment

# %%
# Liste Liens OC : 
# https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/P5+ERP+vin/erp.xlsx
# https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/P5+ERP+vin/web.xlsx
# https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/P5+ERP+vin/liaison.xlsx


# #Liens Github VA / OC-P5
# webRAW=pd.read_excel("https://github.com/vincent-arese/OC-P5/blob/main/web.xlsx?raw=true", sheet_name='Sheet1') 
# liaisonRAW=pd.read_excel("https://github.com/vincent-arese/OC-P5/blob/main/liaison.xlsx?raw=true", sheet_name='Sheet1') 
# erpRAW=pd.read_excel("https://github.com/vincent-arese/OC-P5/blob/main/erp.xlsx?raw=true", sheet_name='Sheet1') 


# Liens OC AmazonWeb Service
webRAW = pd.read_excel("https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/P5+ERP+vin/web.xlsx", sheet_name='Sheet1') 
liaisonRAW = pd.read_excel("https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/P5+ERP+vin/liaison.xlsx", sheet_name='Sheet1') 
erpRAW = pd.read_excel("https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/P5+ERP+vin/erp.xlsx", sheet_name='Sheet1')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning:
#
# Unknown extension is not supported and will be removed

# %% [markdown]
# ## Nettoyage des RAW

# %% [markdown]
# ### Dataframe  erp

# %%
df=erpRAW.copy() #825 rows × 5 columns
# NbUnique=df.product_id.nunique();# print("Len DataFrame:",len(df),"~Nb Unique:",NbUnique,"~Nb non unique:",len(df)-NbUnique)
SearchKey(df)
erp=df   # product_id 825 unique /825  Clé canditate 100% unique ! 
erp.head()
# Out:
# ______________________________________________________________________________________
#  Recherche  valeurs uniques :  df   ( 825 Lignes, 5 Colonnes)
# ______________________________________________________________________________________
# product_id : 825 rows |Nb unique: 825 |Nb doublons: 0 - 0.0 % Clé candidate | int64
# ____________________________________________________________________________________
# onsale_web : 825 rows |Nb unique: 2 |Nb doublons: 823 - 100.0 % | int64
# ______________________________________________________________________________________
# price : 825 rows |Nb unique: 381 |Nb doublons: 444 - 54.0 % | float64
# ______________________________________________________________________________________
# stock_quantity : 825 rows |Nb unique: 128 |Nb doublons: 697 - 84.0 % | int64
# ______________________________________________________________________________________
# stock_status : 825 rows |Nb unique: 2 |Nb doublons: 823 - 100.0 % | object
# ______________________________________________________________________________________
#    product_id  onsale_web  price  stock_quantity stock_status
# 0        3847           1   24.2               0   outofstock
# 1        3849           1   34.3               0   outofstock
# 2        3850           1   20.8               0   outofstock
# 3        4032           1   14.1               0   outofstock
# 4        4039           1   46.0               0   outofstock

# %% [markdown]
# ### Dataframe Liaison

# %%
print(pcolors.WARNING+"\n\n DataFrame initial:"+pcolors.RESET)
df = liaisonRAW.copy() #825 rows × 2 columns
SearchKey(df)    # Unique : liaison.product_id == erp.product_id  OK !    // id_web  nettoyage nécessaire 91  doublons

# Visualiser les doublons dans id_web
doublons = df[df.duplicated(subset=['id_web'],keep=False)].sort_values(by="id_web") #91 rows × 2 columns NaN ! 
ValeurDoublons = doublons.id_web.unique()  # Il y  a 91 code id-web  dont le sku est manquant (NaN)! 
CountDoublons = len(doublons)
print("\n Il y a",CountDoublons,"doublons {",doublons.shape,"-",ValeurDoublons,"} dans la colonne id-web du DataFrame",
      "\n",doublons.head(5) )

# Suprimmer les Id_web NaN car lignes inutiles dans la table de liaison 
df.dropna(inplace=True)
print(pcolors.WARNING+"\n\n DataFrame nettoyé:"+pcolors.RESET)

# SearchKey(df) 
liaison=df #( 825 Lignes, 2 Colonnes) 
SearchKey(liaison) 
liaison.head()
# Out:
#  DataFrame initial:
#
# ______________________________________________________________________________________
#  Recherche  valeurs uniques :  df   ( 825 Lignes, 2 Colonnes)
# ______________________________________________________________________________________
# product_id : 825 rows |Nb unique: 825 |Nb doublons: 0 - 0.0 % Clé candidate | int64
# ____________________________________________________________________________________
# id_web : 825 rows |Nb unique: 734 |Nb doublons: 91 - 11.0 % | object
# ______________________________________________________________________________________
#
#  Il y a 91 doublons { (91, 2) - [nan] } dans la colonne id-web du DataFrame
#       product_id id_web
# 19         4055    NaN
# 49         4090    NaN
# 50         4092    NaN
# 119        4195    NaN
# 131        4209    NaN
#
#
#  DataFrame nettoyé:
#
# ______________________________________________________________________________________
#  Recherche  valeurs uniques :  df   ( 734 Lignes, 2 Colonnes)
# ______________________________________________________________________________________
# product_id : 734 rows |Nb unique: 734 |Nb doublons: 0 - 0.0 % Clé candidate | int64
# ____________________________________________________________________________________
# id_web : 734 rows |Nb unique: 734 |Nb doublons: 0 - 0.0 % Clé candidate | object
# ____________________________________________________________________________________
#    product_id id_web
# 0        3847  15298
# 1        3849  15296
# 2        3850  15300
# 3        4032  19814
# 4        4039  19815

# %% [markdown]
# ### Dataframe  Web

# %%
print(pcolors.WARNING+"\n\n DataFrame initial:"+pcolors.RESET)
# webRAW.info()
SearchKey(webRAW)
print(" ")
webRAW.head(3)
# Out:
#  DataFrame initial:
#
# ______________________________________________________________________________________
#  Recherche  valeurs uniques :  webRAW   ( 1513 Lignes, 28 Colonnes)
# ______________________________________________________________________________________
# sku : 1513 rows |Nb unique: 714 |Nb doublons: 799 - 53.0 % | object
# ______________________________________________________________________________________
# virtual : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | int64
# ______________________________________________________________________________________
# downloadable : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | int64
# ______________________________________________________________________________________
# rating_count : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | int64
# ______________________________________________________________________________________
# average_rating : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | float64
# ______________________________________________________________________________________
# total_sales : 1513 rows |Nb unique: 41 |Nb doublons: 1472 - 97.0 % | float64
# ______________________________________________________________________________________
# tax_status : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | object
# ______________________________________________________________________________________
# tax_class : 1513 rows |Nb unique: 0 |Nb doublons: 1513 - 100.0 % | float64
# ______________________________________________________________________________________
# post_author : 1513 rows |Nb unique: 2 |Nb doublons: 1511 - 100.0 % | float64
# ______________________________________________________________________________________
# post_date : 1513 rows |Nb unique: 716 |Nb doublons: 797 - 53.0 % | datetime64[ns]
# ______________________________________________________________________________________
# post_date_gmt : 1513 rows |Nb unique: 716 |Nb doublons: 797 - 53.0 % | datetime64[ns]
# ______________________________________________________________________________________
# post_content : 1513 rows |Nb unique: 0 |Nb doublons: 1513 - 100.0 % | float64
# ______________________________________________________________________________________
# post_title : 1513 rows |Nb unique: 713 |Nb doublons: 800 - 53.0 % | object
# ______________________________________________________________________________________
# post_excerpt : 1513 rows |Nb unique: 679 |Nb doublons: 834 - 55.0 % | object
# ______________________________________________________________________________________
# post_status : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | object
# ______________________________________________________________________________________
# comment_status : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | object
# ______________________________________________________________________________________
# ping_status : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | object
# ______________________________________________________________________________________
# post_password : 1513 rows |Nb unique: 0 |Nb doublons: 1513 - 100.0 % | float64
# ______________________________________________________________________________________
# post_name : 1513 rows |Nb unique: 716 |Nb doublons: 797 - 53.0 % | object
# ______________________________________________________________________________________
# post_modified : 1513 rows |Nb unique: 589 |Nb doublons: 924 - 61.0 % | datetime64[ns]
# ______________________________________________________________________________________
# post_modified_gmt : 1513 rows |Nb unique: 589 |Nb doublons: 924 - 61.0 % | datetime64[ns]
# ______________________________________________________________________________________
# post_content_filtered : 1513 rows |Nb unique: 0 |Nb doublons: 1513 - 100.0 % | float64
# ______________________________________________________________________________________
# post_parent : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | float64
# ______________________________________________________________________________________
# guid : 1513 rows |Nb unique: 1430 |Nb doublons: 83 - 5.0 % | object
# ______________________________________________________________________________________
# menu_order : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | float64
# ______________________________________________________________________________________
# post_type : 1513 rows |Nb unique: 2 |Nb doublons: 1511 - 100.0 % | object
# ______________________________________________________________________________________
# post_mime_type : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | object
# ______________________________________________________________________________________
# comment_count : 1513 rows |Nb unique: 1 |Nb doublons: 1512 - 100.0 % | float64
# ______________________________________________________________________________________
#                    sku  virtual  downloadable  rating_count  average_rating  \
# 0  bon-cadeau-25-euros        0             0             0             0.0
# 1                15298        0             0             0             0.0
# 2                15296        0             0             0             0.0
#
#    total_sales tax_status  tax_class  post_author           post_date  \
# 0         10.0    taxable        NaN          1.0 2018-06-01 13:53:46
# 1          6.0    taxable        NaN          2.0 2018-02-08 12:58:52
# 2          0.0    taxable        NaN          2.0 2018-02-08 13:49:41
#
#         post_date_gmt  post_content  \
# 0 2018-06-01 11:53:46           NaN
# 1 2018-02-08 11:58:52           NaN
# 2 2018-02-08 12:49:41           NaN
#
#                                         post_title  \
# 0                                Bon cadeau de 25€
# 1      Pierre Jean Villa Saint-Joseph Préface 2018
# 2  Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
#
#                                         post_excerpt post_status  \
# 0  <span style="color: #a85253;"><strong>Parlons ...     publish
# 1  Il exhale un nez subtil, racé avec du poivre f...     publish
# 2  Les vieilles vignes lui apportent une rare pro...     publish
#
#   comment_status ping_status  post_password  \
# 0         closed      closed            NaN
# 1         closed      closed            NaN
# 2         closed      closed            NaN
#
#                                      post_name       post_modified  \
# 0                       bon-cadeau-de-25-euros 2018-06-01 14:13:57
# 1  pierre-jean-villa-saint-joseph-preface-2018 2019-12-30 09:30:29
# 2    pierre-jean-villa-saint-joseph-tilde-2017 2019-12-21 09:00:17
#
#     post_modified_gmt  post_content_filtered  post_parent  \
# 0 2018-06-01 12:13:57                    NaN          0.0
# 1 2019-12-30 08:30:29                    NaN          0.0
# 2 2019-12-21 08:00:17                    NaN          0.0
#
#                                                 guid  menu_order post_type  \
# 0  https://www.bottle-neck.fr/?post_type=product&...         0.0   product
# 1  https://www.bottle-neck.fr/?post_type=product&...         0.0   product
# 2  https://www.bottle-neck.fr/?post_type=product&...         0.0   product
#
#   post_mime_type  comment_count
# 0            NaN            0.0
# 1            NaN            0.0
# 2            NaN            0.0

# %%
df = webRAW.copy() #1513 rows × 28 columns

# Drop "duplicated line" (sauf post-type) :  doublons : post_type/Product  & post_type/attachement 
df = df[~df["post_type"].isin(["attachment"])]    # Enlever les Doublons   799 rows × 28 columns

# Gestion des 0 et des NaN
df=df.replace(0,np.nan) #.dropna(axis=1,how="all")  # 799 rows × 16 columns
df=df.dropna(axis=1, how='all').dropna(axis=0, how='all') #  716 rows × 16 columns
df=df.replace(np.nan,0)

# SearchKey(df)

#Extraire le code p= de la colonne guid
df["guid_ID"] = df.guid.astype(str).str[-4:].astype(int)
# pd.to_numeric(df.guid, downcast="integer")

# Test pour voir si guid_ID  correspond au code SKU
df["Test"] = df.sku == df.guid_ID   # Il de n'agit pas du code sku 
# SearchKey(df)  # guid_ID : 717 rows |Nb unique: 717    => clé candidate ! 

# ## Extraire le code p= de la colonne guid : test avec methode split
# # type(df.guid.str.split('p='))
# # df.guid.str.split('p=',expand=True)
# # #  df.guid.str.split('p=')[1] # faire le split sur la chaine de caractere 


# Drop Colonnes Sans Interet pour Analyse des ventes 
# df.columns
['sku', 'total_sales', 'tax_status', 'post_author', 'post_date',
       'post_date_gmt', 'post_title', 'post_excerpt', 'post_status',
       'comment_status', 'ping_status', 'post_name', 'post_modified',
       'post_modified_gmt', 'guid', 'post_type', ]
df.query("post_author==1")   #sans interet pour analyses des ventes ! 
df.post_type  #sans interet pour analyses des ventes ! car il ne reste plus que  'product' 
df.guid # N'est plus utile car guid-Id à été extrait ! 
df.tax_status.unique(); len(df.tax_status)   # untile car toutes les lignes sont 'taxable'
df.post_date_gmt # post_date_gmt=  post_date -2 ! 
df.post_modified_gmt  #idem
['post_status','comment_status', 'ping_status' ,'post_name', 'post_excerpt','post_modified'] # Sans interet All published or closed

df=df.loc[:,['sku', 'guid_ID','total_sales', 'post_date','post_title']]  # Df optimisé 

# SearchKey(df) # Verification 

# Visualiser les doublons dans sku (sku=0 coresspond a sku manqant ) 
df.sku.astype(str).sort_values().unique()
print("Visualiser les doublons : sku == 0:")
print(df[df.sku==0])  # guid_ID :  5070 - 5075	 

# Remplacer les deux  Sku manquant par un code temproraire "le guid_ID " unique (clé canditate)
df['sku'] = df['sku'].where(df['sku']!=0, other=df.guid_ID ) # guid_ID :  5070 - 5075
# print(df.query("sku==5070 | sku==5075")) # verif OK 


# SearchKey(df) 
web=df
print('')
print(pcolors.WARNING+"\n\n DataFrame nettoyé:"+pcolors.RESET)
SearchKey(web)
# web.info()
print('')

web  #716 rows × 5 columns
# Out:
# Visualiser les doublons : sku == 0:
#     sku  guid_ID  total_sales           post_date  \
# 470   0     5070          0.0 2018-07-31 12:07:23
# 471   0     5075          0.0 2018-08-08 11:23:43
#
#                                           post_title
# 470       Pierre Jean Villa Côte Rôtie Fongeant 2017
# 471  Pierre Jean Villa Condrieu Jardin Suspendu 2018
#
#
#
#  DataFrame nettoyé:
#
# ______________________________________________________________________________________
#  Recherche  valeurs uniques :  df   ( 716 Lignes, 5 Colonnes)
# ______________________________________________________________________________________
# sku : 716 rows |Nb unique: 716 |Nb doublons: 0 - 0.0 % Clé candidate | object
# ____________________________________________________________________________________
# guid_ID : 716 rows |Nb unique: 716 |Nb doublons: 0 - 0.0 % Clé candidate | int64
# ____________________________________________________________________________________
# total_sales : 716 rows |Nb unique: 41 |Nb doublons: 675 - 94.0 % | float64
# ______________________________________________________________________________________
# post_date : 716 rows |Nb unique: 716 |Nb doublons: 0 - 0.0 % Clé candidate | datetime64[ns]
# ____________________________________________________________________________________
# post_title : 716 rows |Nb unique: 713 |Nb doublons: 3 - 0.0 % | object
# ______________________________________________________________________________________
#                      sku  guid_ID  total_sales           post_date  \
# 0    bon-cadeau-25-euros     4954         10.0 2018-06-01 13:53:46
# 1                  15298     3847          6.0 2018-02-08 12:58:52
# 2                  15296     3849          0.0 2018-02-08 13:49:41
# 3                  15300     3850          0.0 2018-02-08 14:08:36
# 4                  19814     4032          3.0 2018-02-09 14:01:05
# ..                   ...      ...          ...                 ...
# 762                16135     6930          5.0 2020-04-25 13:22:38
# 767                15891     7023          0.0 2020-05-02 14:53:40
# 768                15887     7025          0.0 2020-05-02 15:00:54
# 797              13127-1     7247          0.0 2020-06-09 15:42:04
# 798                16230     7338          0.0 2020-07-20 11:00:00
#
#                                             post_title
# 0                                    Bon cadeau de 25€
# 1          Pierre Jean Villa Saint-Joseph Préface 2018
# 2      Pierre Jean Villa Saint-Joseph Rouge Tildé 2017
# 3    Pierre Jean Villa Crozes-Hermitage Accroche Co...
# 4    Pierre Jean Villa IGP Collines Rhodaniennes Ga...
# ..                                                 ...
# 762   Mouthes Le Bihan Côtes de Duras L'Aimé Chai 2015
# 767         Camin Larredya Jurançon Sec La Virada 2018
# 768     Domaine Jamet Côte Rôtie Fructus Voluptas 2018
# 797       Clos du Mont-Olivet Châteauneuf-du-Pape 2007
# 798  Domaine Saint-Nicolas Vin de France Blanc Les ...
#
# [716 rows x 5 columns]

# %% [markdown]
# ## DataFrame Global Ventes Web

# %% [markdown]
# ### Merge pour obtenir le df Global Ventes Web (global)

# %%
print(pcolors.WARNING + 'Liste des colonnes:'+pcolors.RESET,
      '\n--------------------------------`\n',
      pcolors.OK+ "erp:" +pcolors.RESET,erp.columns,pcolors.OK+"", erp.shape,"" +pcolors.RESET,
      '\n--------------------------------`\n',
      pcolors.OK+ "liaison:" +pcolors.RESET,liaison.columns,pcolors.OK+"", liaison.shape,"" +pcolors.RESET,
      '\n--------------------------------`\n',
      pcolors.OK+ 'web:' +pcolors.RESET,web.columns,pcolors.OK+"", web.shape,"" +pcolors.RESET,)
# Out:
# Liste des colonnes:
# --------------------------------`
#  erp: Index(['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status'], dtype='object')  (825, 5)
# --------------------------------`
#  liaison: Index(['product_id', 'id_web'], dtype='object')  (734, 2)
# --------------------------------`
#  web: Index(['sku', 'guid_ID', 'total_sales', 'post_date', 'post_title'], dtype='object')  (716, 5)

# %%
# Merge left car 825 product_id unique dans erp a liaison 
df=erp.copy()
df=df.merge(liaison, how="inner", on="product_id", indicator=True)  #825 rows × 7 columns
df[df._merge=='both'] #825 rows × 7 columns
df

# Controle avec un merge outer 
# df=erp
# df=df.merge(liaison, how="outer", on="product_id", indicator=True)  #825 rows × 7 columns
# df[df._merge=='both'] #825 rows × 7 columns
# df[df._merge=='left_only'] # Aucuns 
# df[df._merge=='right_only'] # Aucuns 
# df.rename(columns={"_merge":"_merge_Erp_Liaison"}, inplace=True)
# df._merge_Erp_Liaison.unique() # Ok All Both 
# df # 825 rows × 7 columns
# Out:
#      product_id  onsale_web  price  stock_quantity stock_status   id_web  \
# 0          3847           1   24.2               0   outofstock    15298
# 1          3849           1   34.3               0   outofstock    15296
# 2          3850           1   20.8               0   outofstock    15300
# 3          4032           1   14.1               0   outofstock    19814
# 4          4039           1   46.0               0   outofstock    19815
# ..          ...         ...    ...             ...          ...      ...
# 729        7023           1   27.5              15      instock    15891
# 730        7025           1   69.0               2      instock    15887
# 731        7247           1   54.8              23      instock  13127-1
# 732        7329           0   26.5              14      instock  14680-1
# 733        7338           1   16.3              45      instock    16230
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 729   both
# 730   both
# 731   both
# 732   both
# 733   both
#
# [734 rows x 7 columns]

# %%
# Merge left car 825 product_id unique dans erp a liaison 
df=erp
df=df.merge(liaison, how="inner", on="product_id", indicator=True)  #825 rows × 7 columns
df[df._merge=='both'] #714 rows × 13 columns
df.rename(columns={"_merge":"_merge_Erp_Liaison"}, inplace=True)
df._merge_Erp_Liaison.unique() # Ok All Both 
df # 825 rows × 7 columns


df=df.merge(web,how='outer',left_on='id_web', right_on='sku', indicator=True) #1539 rows × 13 columns
df[df._merge=='both'] #
df[df._merge=='left_only'] #20 rows × 13 columns
df[df._merge=='right_only']  #2 rows × 13 columns


df.rename(columns={"_merge":"_merge_ErpLiaisonWeb"}, inplace=True)
df._merge_ErpLiaisonWeb.unique() # ['left_only', 'both', 'right_only']

dtypeCat2Obj(df) # Change dtype catergory to Object  (pour lever erreur) 
df.fillna(0, inplace=True)

df["ChiffreAffaires"]= (df.total_sales*df.price).round(2) #2254 rows × 26 columns
df.sort_values(by="ChiffreAffaires",  ascending=False ,na_position='last', inplace=True)



print("Le chiffre d'affaires total de la boutique web est de ",pcolors.WARNING +"%.2f" %(df.ChiffreAffaires.sum()),"€" +pcolors.RESET)



df=PercentCumul(df,"ChiffreAffaires")
df.columns
['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status',
       'id_web', '_merge_Erp_Liaison', 'sku', 'guid_ID', 'total_sales',
       'post_date', 'post_title', '_merge_ErpLiaisonWeb', 'ChiffreAffaires',
       'ChiffreAffaires_percent', 'ChiffreAffairescum_p']

Global=df.loc[:,['sku','post_title', 'price', 
       'total_sales','ChiffreAffaires','ChiffreAffaires_percent', 'ChiffreAffairescum_p',
       'stock_status','stock_quantity',
       'product_id','id_web', 'guid_ID']]

Global
# Out:
# Le chiffre d'affaires total de la boutique web est de  70568.60 €
#        sku                                         post_title  price  \
# 195   7818             Champagne Gosset Grand Blanc de Blancs   49.0
# 71    1662                        Champagne Gosset Grand Rosé   49.0
# 219   3510                               Cognac Frapin VIP XO  176.0
# 70   11641              Champagne Gosset Grand Millésime 2006   53.0
# 69     304                    Champagne Gosset Grande Réserve   39.0
# ..     ...                                                ...    ...
# 645  15134                    Christophe Pichon Condrieu 2017   38.5
# 648  15951      Jacqueson Rully Rouge 1er Cru Les Preaux 2018   24.5
# 650  15486  Château de Villeneuve Saumur-Champigny Clos de...   13.4
# 651  15489  Château de Villeneuve Saumur-Champigny Le Gran...   29.8
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 195         96.0           4704.0                     6.67
# 71          87.0           4263.0                     6.04
# 219         13.0           2288.0                     3.24
# 70          30.0           1590.0                     2.25
# 69          40.0           1560.0                     2.21
# ..           ...              ...                      ...
# 645          0.0              0.0                     0.00
# 648          0.0              0.0                     0.00
# 650          0.0              0.0                     0.00
# 651          0.0              0.0                     0.00
# 735          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 195                  6.67   outofstock             0.0      4334.0   7818
# 71                  12.71      instock            11.0      4144.0   1662
# 219                 15.95      instock             8.0      4402.0   3510
# 70                  18.20      instock             8.0      4142.0  11641
# 69                  20.41      instock             1.0      4141.0    304
# ..                    ...          ...             ...         ...    ...
# 645                100.00   outofstock             0.0      6050.0  15134
# 648                100.00      instock            19.0      6073.0  15951
# 650                100.00      instock             2.0      6094.0  15486
# 651                100.00      instock             3.0      6095.0  15489
# 735                100.00            0             0.0         0.0      0
#
#      guid_ID
# 195   4334.0
# 71    4144.0
# 219   4402.0
# 70    4142.0
# 69    4141.0
# ..       ...
# 645   6050.0
# 648   6073.0
# 650   6094.0
# 651   6095.0
# 735   5075.0
#
# [736 rows x 12 columns]

# %% [markdown]
# ### Table Conversion Sku Product_ID Id_Web GuID

# %%
TableConversion=Global.loc[:,['sku', 'product_id','id_web', 'guid_ID','post_title']]
TableConversion.sku = TableConversion.sku.astype(str)
TableConversion.sort_values(by='sku', ascending=True, inplace=True)

print("Note : Les valeurs",pcolors.WARNING+ "0"+pcolors.RESET," indiquent des données indisponibles")
TableConversion
# Out:
# Note : Les valeurs 0  indiquent des données indisponibles
#                      sku  product_id               id_web  guid_ID  \
# 400                    0      4922.0                15586      0.0
# 627                    0      5955.0                14377      0.0
# 625                    0      5953.0                14379      0.0
# 230                    0      4584.0                14785      0.0
# 732                    0      7329.0              14680-1      0.0
# ..                   ...         ...                  ...      ...
# 518                 8463      5574.0                 8463   5574.0
# 204                 9562      4357.0                 9562   4357.0
# 213                 9636      4396.0                 9636   4396.0
# 410                 9937      4932.0                 9937   4932.0
# 418  bon-cadeau-25-euros      4954.0  bon-cadeau-25-euros   4954.0
#
#                                             post_title
# 400                                                  0
# 627                                                  0
# 625                                                  0
# 230                                                  0
# 732                                                  0
# ..                                                 ...
# 518  Domaine Huet Vouvray Le Mont Moelleux Première...
# 204              Champagne Larmandier-Bernier Latitude
# 213  Wemyss Malts Blended Malt Scotch Whisky The Hi...
# 410  Marcel Richaud Cairanne Rouge Les Estrambords ...
# 418                                  Bon cadeau de 25€
#
# [736 rows x 5 columns]

# %% [markdown]
# ### Ajout Colonnes Catégorisation produits & statistiques

# %%
def Zscore(df,Col): 
  """Zscore(df,Col) :  Ajout colonnes Zscore_Col &  NivConf_Zscore_col
                      'ZSscore Omlit NaN  & Interepretion Niv confiance
  Parametres  Df: DataFrame & col : Colonne
  """
  import scipy.stats as stats 
  #https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.zscore.html
  df["Zscore_"+Col] = stats.zscore(df[Col], axis=0, nan_policy='omit')

  #https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html 
  # df["ZscoreManuel"+Col] = (df[Col] - df[Col].mean())/df[Col].std(ddof=0) # Calcul Zscore Manuel
  
  Za=2.58 ;ZaConf="90%" # seuil confiance 90% 
  Zb=1.96 ;ZbConf="95%"# seuil confiance95% 
  Zc=1.65 ;ZcConf="99%"# seuil confiance 99% 
  # source : https://pro.arcgis.com/fr/pro-app/2.7/tool-reference/spatial-statistics/what-is-a-z-score-what-is-a-p-value.htm
  #  np.abs(z_score) > threshold:


  # Colonne Interpration Zscore 
  ColRefName="Zscore_"+Col # Nom Colonne de référence pour la segmentation
  ColCatName="Seuil_ConF_Zscore" # Nom Colonne Categorie
  df[ColCatName]="?"
  df[ColRefName].fillna(0,inplace=True)
  
  df.loc[np.abs(df[ColRefName]) > Za , ColCatName] = "Inférieur à "+ZaConf 
  df.loc[np.abs(df[ColRefName]) <= Za , ColCatName] = ZaConf    # utilisation de la Valeur Absolue (-za <= Seuil confiance <= Za )
  df.loc[np.abs(df[ColRefName]) <= Zb , ColCatName] = ZbConf
  df.loc[np.abs(df[ColRefName]) <= Zc , ColCatName] = ZcConf

  df.sort_values(ColRefName, inplace=True)


  print(ColRefName,ColCatName)
  return df

# %%
# Ajout colonne conditionnelle quartile

def QartileIndicatorCol(df,col): 
  """ Ajout d'un colonne Conditionelle avec le quartile au df courant  & Recherce Ouliers Methode IQ ( InterQuartiles)
QartileIndicatorCol(df,col) => df[col+"Quartile"] """

  # Caculs Seuils des quartiles 
  q25=df[col].quantile(q=0.25, interpolation='linear')  #Q1
  q50=df[col].quantile(q=0.50, interpolation='linear')  #Q2
  q75=df[col].quantile(q=0.75, interpolation='linear')  #Q3

  Q1=q25 ;   Q2=q50 ;   Q3=q75 # Quartiles simplifiés

  # Quartiles Conditions & label 
  conditionlist = [
    (df[col] <= q25) ,
    (df[col] > q25) & (df[col] <q75),
    (df[col] >= q75)]
   
  choicelist = ['quartile1','quartile2','quartile3']

  df[col+"_Quartile"] = np.select(conditionlist, choicelist, default='Not Specified')

  # écart interquartile
  EcartInterquartile  = Q3 - Q1  # IQ = Q3 - Q1
  TauxIQoutliers = 1.5
  IQoutliersInf = Q1 -  TauxIQoutliers *  EcartInterquartile # Outliers Inférieurs ?
  IQoutliersSup = Q3 +  TauxIQoutliers *  EcartInterquartile # Outliers ISuperieur ? 

 # IQ Conditions & label 
  conditionlist = [
   (df[col] <  IQoutliersInf) ,
   (df[col] >=  IQoutliersInf) & (df[col] <= IQoutliersSup),
   (df[col] > IQoutliersSup)    ]
  
  choicelist = ['IQ_Ouliers_Inf','-','IQ_Ouliers_Sup'] 

  df[col+"_IQ_Ouliers"] = np.select(conditionlist, choicelist, default='Not Specified')
  
  print( pcolors.OK + "Methode IQ "+ col+ ":"+ pcolors.RESET ,
        "Ecart Interquartile= ",EcartInterquartile,
        " -Q1 ",Q1," -Q2 ",Q2, " -Q3 ",Q3)
  return df

# %%
# Segmentation marché : Prix Vente bouteille
df=Global.copy()
df.fillna(0,inplace=True)
ColRefName="price" # Nom Colonne de référence pour la segmentation
ColCatName="PrixBouteilleCAT" # Nom Colonne Categorie
df[ColCatName]="?"

df.loc[ df[ ColRefName ] >= 100, ColCatName] = "Prix > 100€"
df.loc[ df[ ColRefName ] < 100, ColCatName] = "50€ > Prix < 100€"
df.loc[ df[ ColRefName ] <= 50, ColCatName] = "30€ > Prix <= 50€"
df.loc[ df[ ColRefName ] <= 30, ColCatName] = "10€ > Prix <= 30€"
df.loc[ df[ ColRefName ] <= 10, ColCatName] = "Prix <= 10€"
df
#---------------------------------------------------------------


# Segmentation marché : Regex extraction Cat produit (Champagne, Cognac, Whisky, Autres (vins),?)
# df=VerifPrix.copy()
# df.fillna(0,inplace=True)
ColRefName="post_title" # Nom Colonne de référence pour la segmentation
ColCatName="BouteilleCAT" # Nom Colonne Categorie
df[ColCatName]="?"

df.loc[ df[ColRefName].str.contains("Champagne|champagne") == True, ColCatName] = "Champagne"
df.loc[ df[ColRefName].str.contains("Cognac|cognac") == True, ColCatName] = "Cognac"
df.loc[ df[ColRefName].str.contains("Whisky|whisky") == True, ColCatName] = "Whisky"
df.loc[ df[ColRefName].str.contains("Champagne|champagne|Cognac|cognac|Whisky|whisky") == False, ColCatName] = "Autres (vins)"
df
#---------------------------------------------------------------

# Methode interQuartiles
QartileIndicatorCol(df,"price")

# Zscore
Zscore(df,"price")

Global=df
Global
# Out:
# Methode IQ price: Ecart Interquartile=  27.762499999999996  -Q1  14.037500000000001  -Q2  23.299999999999997  -Q3  41.8
# Zscore_price Seuil_ConF_Zscore
#        sku                                         post_title  price  \
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 573  14338           Maurel Pays d'Oc Cabernet-Sauvignon 2017    5.7
# 99   16209                     Maurel Cabardès Tradition 2017    5.7
# ..     ...                                                ...    ...
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# 219   3510                               Cognac Frapin VIP XO  176.0
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 735          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 664          0.0              0.0                     0.00
# 573          0.0              0.0                     0.00
# 99           6.0             34.2                     0.05
# ..           ...              ...                      ...
# 566          0.0              0.0                     0.00
# 219         13.0           2288.0                     3.24
# 601          3.0            573.9                     0.81
# 434          0.0              0.0                     0.00
# 200          5.0           1125.0                     1.59
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 735                100.00            0             0.0         0.0      0
# 734                100.00            0             0.0         0.0      0
# 664                100.00      instock            30.0      6129.0  14570
# 573                100.00      instock           132.0      5777.0  14338
# 99                  97.76      instock            94.0      4174.0  16209
# ..                    ...          ...             ...         ...    ...
# 566                100.00      instock            12.0      5767.0  15185
# 219                 15.95      instock             8.0      4402.0   3510
# 601                 45.02      instock            10.0      5892.0  14983
# 434                100.00      instock            20.0      5001.0  14581
# 200                 23.98   outofstock             0.0      4352.0  15940
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 573   5777.0      Prix <= 10€  Autres (vins)      quartile1                -
# 99    4174.0      Prix <= 10€  Autres (vins)      quartile1                -
# ..       ...              ...            ...            ...              ...
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 219   4402.0      Prix > 100€         Cognac      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 200   4352.0      Prix > 100€      Champagne      quartile3   IQ_Ouliers_Sup
#
#      Zscore_price Seuil_ConF_Zscore
# 735     -1.167472               99%
# 734     -1.167472               99%
# 664     -0.978522               99%
# 573     -0.960353               99%
# 99      -0.960353               99%
# ..            ...               ...
# 566      5.191437   Inférieur à 90%
# 219      5.227774   Inférieur à 90%
# 601      5.783724   Inférieur à 90%
# 434      6.735743   Inférieur à 90%
# 200      7.008268   Inférieur à 90%
#
# [736 rows x 18 columns]

# %% [markdown]
# ### Graphe et tableau Global Ventes Web (global)

# %%
import plotly.express as px
['sku', 'post_title', 'price', 'total_sales', 'ChiffreAffaires', 'ChiffreAffaires_percent', 'ChiffreAffairescum_p', 'stock_status', 'stock_quantity', 'product_id', 'id_web', 'guid_ID']

df = Global.query("ChiffreAffaires_percent>1")
fig = px.bar(df, x="post_title", y='ChiffreAffaires',
             hover_data=df.columns, color='price',
             labels = {'post_title':"Nom produit",'price':"Prix de vente unitaire €",'ChiffreAffaires':"Chiffre d'Affaires","CA %":"CA % cumulé","total_sales":"Nombre de ventes"},
             title="Chiffre d'affaires BottleNeck on-line des sku représentant plus de 1% des ventes")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2fe14cc8-79ca-466f-8462-edf41cd618c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2fe14cc8-79ca-466f-8462-edf41cd618c4")) {                    Plotly.newPlot(                        "2fe14cc8-79ca-466f-8462-edf41cd618c4",                        [{"alignmentgroup":"True","customdata":[[16416,16.6,62.0,1.46,28.38,"instock",157.0,4068.0,16416,4068.0,"10\u20ac > Prix <= 30\u20ac","Autres (vins)","quartile2","-",-0.5642840555754578,"99%"],[16077,25.2,37.0,1.32,35.36,"instock",363.0,6207.0,16077,6207.0,"10\u20ac > Prix <= 30\u20ac","Autres (vins)","quartile2","-",-0.2517890987816577,"99%"],[16580,25.2,41.0,1.46,26.92,"instock",120.0,6206.0,16580,6206.0,"10\u20ac > Prix <= 30\u20ac","Autres (vins)","quartile2","-",-0.2517890987816577,"99%"],[15807,27.9,36.0,1.42,32.68,"outofstock",0.0,4891.0,15807,4891.0,"10\u20ac > Prix <= 30\u20ac","Autres (vins)","quartile2","-",-0.1536802169975577,"99%"],[16237,29.0,36.0,1.48,25.46,"outofstock",0.0,4153.0,16237,4153.0,"10\u20ac > Prix <= 30\u20ac","Autres (vins)","quartile2","-",-0.11370993182625765,"99%"],[15533,37.2,24.0,1.27,36.62,"outofstock",0.0,4918.0,15533,4918.0,"30\u20ac > Prix <= 50\u20ac","Autres (vins)","quartile2","-",0.1842503758143426,"99%"],[304,39.0,40.0,2.21,20.41,"instock",1.0,4141.0,304,4141.0,"30\u20ac > Prix <= 50\u20ac","Champagne","quartile2","-",0.2496562970037425,"99%"],[15476,43.9,23.0,1.43,31.26,"outofstock",0.0,4596.0,15476,4596.0,"30\u20ac > Prix <= 50\u20ac","Autres (vins)","quartile3","-",0.4277057491304425,"99%"],[13127,44.3,23.0,1.44,29.82,"instock",16.0,4053.0,13127,4053.0,"30\u20ac > Prix <= 50\u20ac","Autres (vins)","quartile3","-",0.4422403982836425,"99%"],[15343,48.5,17.0,1.17,37.79,"outofstock",0.0,5922.0,15343,5922.0,"30\u20ac > Prix <= 50\u20ac","Autres (vins)","quartile3","-",0.5948542143922426,"99%"],[1662,49.0,87.0,6.04,12.71,"instock",11.0,4144.0,1662,4144.0,"30\u20ac > Prix <= 50\u20ac","Champagne","quartile3","-",0.6130225258337427,"99%"],[7818,49.0,96.0,6.67,6.67,"outofstock",0.0,4334.0,7818,4334.0,"30\u20ac > Prix <= 50\u20ac","Champagne","quartile3","-",0.6130225258337427,"99%"],[11641,53.0,30.0,2.25,18.2,"instock",8.0,4142.0,11641,4142.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile3","-",0.7583690173657427,"99%"],[15346,59.9,16.0,1.36,34.04,"outofstock",0.0,5067.0,15346,5067.0,"50\u20ac > Prix < 100\u20ac","Autres (vins)","quartile3","-",1.0090917152584429,"99%"],[19816,71.6,10.0,1.01,38.81,"outofstock",0.0,4054.0,19816,4054.0,"50\u20ac > Prix < 100\u20ac","Autres (vins)","quartile3","-",1.4342302029895428,"99%"],[12589,126.5,11.0,1.97,22.38,"instock",2.0,4355.0,12589,4355.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",3.429110799266244,"Inf\u00e9rieur \u00e0 90%"],[3510,176.0,13.0,3.24,15.95,"instock",8.0,4402.0,3510,4402.0,"Prix > 100\u20ac","Cognac","quartile3","IQ_Ouliers_Sup",5.2277736319747445,"Inf\u00e9rieur \u00e0 90%"],[15940,225.0,5.0,1.59,23.98,"outofstock",0.0,4352.0,15940,4352.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",7.008268153241746,"Inf\u00e9rieur \u00e0 90%"]],"hovertemplate":"Nom produit=%{x}<br>Chiffre d'Affaires=%{y}<br>sku=%{customdata[0]}<br>Prix de vente unitaire \u20ac=%{marker.color}<br>Nombre de ventes=%{customdata[2]}<br>ChiffreAffaires_percent=%{customdata[3]}<br>ChiffreAffairescum_p=%{customdata[4]}<br>stock_status=%{customdata[5]}<br>stock_quantity=%{customdata[6]}<br>product_id=%{customdata[7]}<br>id_web=%{customdata[8]}<br>guid_ID=%{customdata[9]}<br>PrixBouteilleCAT=%{customdata[10]}<br>BouteilleCAT=%{customdata[11]}<br>price_Quartile=%{customdata[12]}<br>price_IQ_Ouliers=%{customdata[13]}<br>Zscore_price=%{customdata[14]}<br>Seuil_ConF_Zscore=%{customdata[15]}<extra></extra> ...

# %%
print("Le chiffre d'affaires total de la boutique web est de ",pcolors.WARNING +"%.2f" %(Global.ChiffreAffaires.sum()),"€" +pcolors.RESET)

Global
# Out:
# Le chiffre d'affaires total de la boutique web est de  70568.60 €
#        sku                                         post_title  price  \
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 573  14338           Maurel Pays d'Oc Cabernet-Sauvignon 2017    5.7
# 99   16209                     Maurel Cabardès Tradition 2017    5.7
# ..     ...                                                ...    ...
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# 219   3510                               Cognac Frapin VIP XO  176.0
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 735          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 664          0.0              0.0                     0.00
# 573          0.0              0.0                     0.00
# 99           6.0             34.2                     0.05
# ..           ...              ...                      ...
# 566          0.0              0.0                     0.00
# 219         13.0           2288.0                     3.24
# 601          3.0            573.9                     0.81
# 434          0.0              0.0                     0.00
# 200          5.0           1125.0                     1.59
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 735                100.00            0             0.0         0.0      0
# 734                100.00            0             0.0         0.0      0
# 664                100.00      instock            30.0      6129.0  14570
# 573                100.00      instock           132.0      5777.0  14338
# 99                  97.76      instock            94.0      4174.0  16209
# ..                    ...          ...             ...         ...    ...
# 566                100.00      instock            12.0      5767.0  15185
# 219                 15.95      instock             8.0      4402.0   3510
# 601                 45.02      instock            10.0      5892.0  14983
# 434                100.00      instock            20.0      5001.0  14581
# 200                 23.98   outofstock             0.0      4352.0  15940
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 573   5777.0      Prix <= 10€  Autres (vins)      quartile1                -
# 99    4174.0      Prix <= 10€  Autres (vins)      quartile1                -
# ..       ...              ...            ...            ...              ...
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 219   4402.0      Prix > 100€         Cognac      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 200   4352.0      Prix > 100€      Champagne      quartile3   IQ_Ouliers_Sup
#
#      Zscore_price Seuil_ConF_Zscore
# 735     -1.167472               99%
# 734     -1.167472               99%
# 664     -0.978522               99%
# 573     -0.960353               99%
# 99      -0.960353               99%
# ..            ...               ...
# 566      5.191437   Inférieur à 90%
# 219      5.227774   Inférieur à 90%
# 601      5.783724   Inférieur à 90%
# 434      6.735743   Inférieur à 90%
# 200      7.008268   Inférieur à 90%
#
# [736 rows x 18 columns]

# %%
['sku', 'post_title', 'price', 'total_sales', 'ChiffreAffaires', 'ChiffreAffaires_percent', 'ChiffreAffairescum_p', 'stock_status', 'stock_quantity', 'product_id', 'id_web', 'guid_ID', 'PrixBouteilleCAT', 'BouteilleCAT']

df = Global.query("ChiffreAffaires > 0")
px.sunburst(data_frame=df,
          names='post_title', values='price', 
          parents=None, 
          path=['BouteilleCAT','PrixBouteilleCAT'], 
          color='BouteilleCAT', 
          color_continuous_scale=None, range_color=None, color_continuous_midpoint=None, 
          color_discrete_sequence=None, color_discrete_map=None, 
          labels=df.columns,
          hover_data=df.columns ,
          title="Ventilation du Chriffre d'Affaires par catégories produit", 
         width=1280, height=720)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py:4616: FutureWarning:
#
# Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a4aed63c-4513-4e2c-8be1-6dd5529e1bb4" class="plotly-graph-div" style="height:720px; width:1280px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4aed63c-4513-4e2c-8be1-6dd5529e1bb4")) {                    Plotly.newPlot(                        "a4aed63c-4513-4e2c-8be1-6dd5529e1bb4",                        [{"branchvalues":"total","customdata":[["(?)","(?)",3929.25,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","10\u20ac > Prix <= 30\u20ac","Autres (vins)","(?)","-","(?)","99%","Autres (vins)"],["(?)","(?)",1043.2,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","Champagne","(?)","(?)","(?)","(?)","Champagne"],["(?)","(?)",8631.15,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","Autres (vins)","(?)","(?)","(?)","(?)","Autres (vins)"],["(?)","(?)",388.5,"(?)","(?)","(?)","(?)","instock","(?)","(?)","(?)","(?)","Prix > 100\u20ac","Cognac","quartile3","IQ_Ouliers_Sup","(?)","Inf\u00e9rieur \u00e0 90%","Cognac"],["(?)","(?)",486.5,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup","(?)","Inf\u00e9rieur \u00e0 90%","Champagne"],["(?)","(?)",443.3,"(?)","(?)","(?)","(?)","instock","(?)","(?)","(?)","(?)","Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup","(?)","Inf\u00e9rieur \u00e0 90%","Autres (vins)"],["(?)","(?)",529.5,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","Prix <= 10\u20ac","Autres (vins)","quartile1","-","(?)","99%","Autres (vins)"],["(?)","(?)",451.0,"(?)","(?)","(?)","(?)","instock","(?)","(?)","(?)","(?)","(?)","Cognac","quartile3","(?)","(?)","(?)","Cognac"],[12640,"Wemyss Malts Blended Malt Scotch Whisky Spice King Batch Strength",59.0,1.0,59.0,0.08,92.99,"instock",6.0,4399.0,12640,4399.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile3","-",0.9763887546637429,"99%","Whisky"],["(?)","(?)",328.7,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","50\u20ac > Prix < 100\u20ac","Champagne","quartile3","(?)","(?)","(?)","Champagne"],["(?)","(?)",1437.6,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","50\u20ac > Prix < 100\u20ac","Autres (vins)","quartile3","-","(?)","(?)","Autres (vins)"],[11585,"Wemyss Malts Blended Malt Scotch Whisky The Hive",49.5,1.0,49.5,0.07,94.72,"instock",6.0,4364.0,11585,4364.0,"30\u20ac > Prix <= 50\u20ac","Whisky","quartile3","-",0.6311908372752427,"99%","Whisky"],["(?)","(?)",205.5,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","30\u20ac > Prix <= 50\u20ac","Champagne","(?)","-","(?)","99%","Champagne"],["(?)","(?)",2291.5,"(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","(?)","30\u20ac > Prix <= 50\u20ac","Autres (vins)","(?)","-","(?)","99%","Autres (vins)"],[531,"Champagne Petit Lebrun &amp; Fils Blanc de Blancs Grand Cru",22.5,13.0,292.5,0.41,56.84,"instock",129.0,5047.0,531,5047.0,"10\u20ac > Prix <= 30\u20ac","Champagne","quartile2","-",-0.34989798056575777,"99%","Champagne"],[3506,"Cognac Frapin VSOP",62.5,1.0,62.5,0.09,92.13,"instock",1.0,4401.0,3506,4401.0,"50\u20ac > Prix < 100\u20ac","Cognac","quartile3","-",1.103566934754243,"99%","Cognac"],["(?)","(?)",108.5,1.0,"(?)","(?)","(?)","instock",6.0,"(?)","(?)","(?)","(?)","Whisky","quartile3","-","(?)","99%","Whisky"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>price=%{customdata[2]}<br>parent=%{parent}<br>id=%{id}<br>sku=%{customdata[0]}<br>post_title=%{customdata[1]}<br>total_sales=%{customdata[3]}<br>ChiffreAffaires=%{customdata[4]}<br>ChiffreAffaires_percent=%{customdata[5]}<br>ChiffreAffairescum_p=%{customdata[6]}<br>stock_status=%{customdata[7]}<br>stock_quantity=%{customdata[8]}<br>product_id=%{customdata[9]}<br>id_web=%{customdata[10]}<br>guid_ID=%{customdata[11]}<br>PrixBouteilleCAT=%{customdata[12]}<br>BouteilleCAT=%{customdata[ ...

# %% [markdown]
# ## Vérification des prix unitaire

# %%
VerifPrix=Global

# %%
df=VerifPrix
['sku', 'post_title', 'price', 'total_sales', 'ChiffreAffaires', 'ChiffreAffaires_percent', 'ChiffreAffairescum_p', 
 'price_Quartile', 'price_IQ_Ouliers', 'Zscore_price', 'Seuil_ConF_Zscore']

fig = px.strip(data_frame=VerifPrix, 
               x="price", y=None, color='price_Quartile', 
               facet_row=None, facet_col=None, facet_col_wrap=0, facet_row_spacing=None, facet_col_spacing=None, 
               hover_name=None, hover_data=df.columns, 
               custom_data=None, 
               animation_frame=None, animation_group=None, 
               category_orders=None, 
               labels=None, 
               color_discrete_sequence=None, color_discrete_map=None, 
               orientation=None, stripmode=None, 
               log_x=False, log_y=False, 
               range_x=None, range_y=None, title=None, template=None, 
               width=None, height=None)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cba80b7a-d3b9-491a-b6a8-0049404945b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cba80b7a-d3b9-491a-b6a8-0049404945b2")) {                    Plotly.newPlot(                        "cba80b7a-d3b9-491a-b6a8-0049404945b2",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[[5075,"Pierre Jean Villa Condrieu Jardin Suspendu 2018",0.0,0.0,0.0,100.0,0,0.0,0.0,0,5075.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-1.1674719954332582,"99%"],[5070,"Pierre Jean Villa C\u00f4te R\u00f4tie Fongeant 2017",0.0,0.0,0.0,100.0,0,0.0,0.0,0,5070.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-1.1674719954332582,"99%"],[14570,"Moulin de Gassac IGP Pays d'H\u00e9rault Guilhem Blanc 2017",0.0,0.0,0.0,100.0,"instock",30.0,6129.0,14570,6129.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9785215564416581,"99%"],[14338,"Maurel Pays d'Oc Cabernet-Sauvignon 2017",0.0,0.0,0.0,100.0,"instock",132.0,5777.0,14338,5777.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9603532450001581,"99%"],[16209,"Maurel Cabard\u00e8s Tradition 2017",6.0,34.2,0.05,97.76,"instock",94.0,4174.0,16209,4174.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9603532450001581,"99%"],[16211,"Maurel Pays d'Oc Chenin-Colombard 2019",13.0,74.1,0.11,90.72,"instock",100.0,4173.0,16211,4173.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9603532450001581,"99%"],[16210,"Maurel Pays d'Oc Chardonnay 2019",43.0,245.1,0.35,61.69,"instock",167.0,4172.0,16210,4172.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9603532450001581,"99%"],[16322,"Moulin de Gassac IGP Pays d'H\u00e9rault Guilhem Rouge 2019",0.0,0.0,0.0,100.0,"instock",105.0,4198.0,16322,4198.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.956719582711858,"99%"],[16213,"Maurel Pays d'Oc Syrah 2019",8.0,46.4,0.07,95.33,"instock",211.0,5779.0,16213,5779.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.956719582711858,"99%"],[15561,"Maurel Pays d'Oc Merlot 2018",24.0,139.2,0.2,78.51,"instock",36.0,5778.0,15561,5778.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.956719582711858,"99%"],[16295,"Moulin de Gassac IGP Pays d'H\u00e9rault Guilhem Ros\u00e9 2019",46.0,266.8,0.38,59.19,"instock",190.0,4200.0,16295,4200.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.956719582711858,"99%"],[15934,"Domaine de Joy C\u00f4tes de Gascogne Envie de Joy 2018",2.0,12.6,0.02,99.77,"instock",34.0,4680.0,15934,4680.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.938551271270358,"99%"],[16342,"Ch\u00e2teau Turcaud Bordeaux Ros\u00e9 2019",1.0,6.5,0.01,100.0,"instock",257.0,4858.0,16342,4858.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.931283946693758,"99%"],[16304,"Philippe Nusswitz IGP C\u00e9v\u00e8nnes Ros\u00e9 O Pale 2019",14.0,91.0,0.13,87.73,"instock",123.0,5695.0,16304,5695.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.931283946693758,"99%"],[15425,"Domaine La Croix Belle C\u00f4tes de Thongue Rouge La Caringole 2018",4.0,26.0,0.04,98.83,"outofstock",0.0,4927.0,15425,4927.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.931283946693758,"99%"],[16023,"Domaine Montrose C\u00f4tes de Thongue Rouge 2018",5.0,33.5,0.05,97.95,"instock",195.0,4207.0,16023,4207.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9240166221171581,"99%"],[16504,"Emile Boeckel Sylvaner Vieilles Vignes 2019",5.0,34.0,0.05,97.85,"instock",42.0,4105.0,16504,4105.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.920382959828858,"99%"],[14302,"Ch\u00e2teau de La Liqui\u00e8re Pays d'H\u00e9rault Blanc A Mi Chemin 2017",7.0,47.6,0.07,95.2,"instock",11.0,4776.0,14302,4776.0,"Prix <= 10\u20ac","Autres (vins)","quartile1","-",-0.9203829 ...

# %%
#Methode Graphique 
df=Global.copy()
px.histogram(df, x="price",
            marginal='box',     #'rug', 'box', 'violin', or 'histogram'
            hover_data=df.columns ,text_auto=True,
            title="Distribution des prix unitaires des bouteilles €")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b2d239ac-8f83-406e-9830-9fb36b282875" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2d239ac-8f83-406e-9830-9fb36b282875")) {                    Plotly.newPlot(                        "b2d239ac-8f83-406e-9830-9fb36b282875",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"texttemplate":"%{value}","x":[0.0,0.0,5.2,5.7,5.7,5.7,5.7,5.8,5.8,5.8,5.8,6.3,6.5,6.5,6.5,6.7,6.8,6.8,7.0,7.0,7.1,7.1,7.1,7.2,7.4,7.4,7.5,7.6,7.6,7.7,7.8,7.8,7.9,7.9,8.1,8.2,8.3,8.4,8.5,8.5,8.6,8.6,8.7,8.7,8.7,8.7,8.7,8.9,8.9,8.9,9.0,9.0,9.1,9.1,9.2,9.3,9.3,9.3,9.3,9.3,9.3,9.4,9.5,9.5,9.6,9.6,9.7,9.7,9.7,9.8,9.8,9.8,9.9,9.9,9.9,9.9,9.9,9.9,10.1,10.1,10.1,10.2,10.2,10.3,10.3,10.4,10.4,10.6,10.6,10.7,10.7,10.7,10.7,10.8,10.8,10.8,10.9,10.9,11.0,11.1,11.1,11.1,11.1,11.1,11.1,11.1,11.3,11.3,11.5,11.5,11.6,11.6,11.6,11.8,11.9,11.9,11.9,11.9,11.9,12.0,12.0,12.0,12.0,12.0,12.1,12.1,12.1,12.2,12.3,12.3,12.4,12.5,12.5,12.5,12.6,12.6,12.6,12.6,12.7,12.7,12.7,12.7,12.7,12.7,12.8,12.8,12.8,12.8,12.8,12.8,12.9,12.9,12.9,12.9,12.9,12.9,13.0,13.1,13.1,13.2,13.2,13.3,13.3,13.4,13.4,13.4,13.5,13.5,13.5,13.5,13.5,13.5,13.5,13.6,13.6,13.7,13.7,13.7,13.7,13.7,13.8,13.8,13.9,14.0,14.05,14.1,14.1,14.1,14.3,14.3,14.3,14.4,14.4,14.4,14.5,14.5,14.5,14.6,14.7,14.8,14.9,14.9,14.9,15.2,15.2,15.2,15.3,15.3,15.4,15.4,15.4,15.4,15.4,15.5,15.5,15.8,15.8,15.8,15.8,15.8,15.9,16.1,16.1,16.2,16.3,16.3,16.3,16.3,16.3,16.3,16.4,16.4,16.4,16.45,16.5,16.5,16.6,16.6,16.6,16.6,16.7,16.7,16.7,16.8,16.8,16.9,16.9,16.9,16.9,16.9,17.0,17.0,17.0,17.1,17.1,17.1,17.1,17.1,17.2,17.2,17.2,17.2,17.3,17.4,17.5,17.5,17.5,17.6,17.7,17.8,17.8,17.8,17.9,17.9,17.9,18.0,18.0,18.1,18.2,18.2,18.2,18.2,18.25,18.3,18.4,18.4,18.5,18.5,18.6,18.7,18.7,18.8,18.8,18.9,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.2,19.2,19.2,19.3,19.3,19.5,19.5,19.5,19.5,19.8,19.8,19.8,19.8,19.8,19.8,20.1,20.2,20.2,20.35,20.4,20.4,20.5,20.5,20.6,20.8,20.8,20.8,20.8,21.0,21.0,21.2,21.4,21.5,21.5,21.5,21.6,21.7,21.7,21.8,21.8,21.8,21.9,22.0,22.0,22.1,22.2,22.4,22.4,22.5,22.5,22.8,22.8,22.8,22.8,22.8,22.8,22.9,22.9,23.0,23.0,23.0,23.0,23.2,23.2,23.2,23.4,23.4,23.4,23.5,23.6,23.7,23.8,24.0,24.0,24.0,24.0,24.0,24.0,24.2,24.2,24.3,24.3,24.4,24.4,24.4,24.4,24.5,24.5,24.6,24.7,24.8,25.0,25.0,25.0,25.0,25.2,25.2,25.3,25.3,25.7,25.7,25.9,25.9,25.9,25.9,26.0,26.2,26.4,26.5,26.5,26.5,26.5,26.5,26.5,26.6,26.7,26.7,26.9,27.0,27.2,27.3,27.3,27.3,27.3,27.5,27.5,27.5,27.7,27.8,27.8,27.9,27.9,27.9,27.9,27.9,27.9,28.0,28.0,28.0,28.0,28.1,28.1,28.4,28.4,28.5,28.5,28.5,28.8,29.0,29.0,29.0,29.2,29.4,29.5,29.5,29.5,29.7,29.8,29.8,29.8,29.9,29.9,30.0,30.0,30.1,30.5,30.6,30.8,31.0,31.2,31.5,31.5,31.6,31.7,31.7,31.7,32.0,32.1,32.2,32.2,32.3,32.3,32.6,32.7,32.8,32.8,33.0,33.2,33.2,33.2,33.4,33.4,33.6,33.7,34.3,34.3,34.3,34.4,34.7,34.8,35.0,35.1,35.2,35.3,35.5,35.6,35.6,35.6,36.0,36.0,36.2,36.3,36.9,37.0,37.2,37.5,37.7,38.0,38.0,38.0,38.4,38.4,38.5,38.6,38.6,38.6,38.6,39.0,39.0,39.0,39.0,39.0,39.1,39.2,39.6,39.8,40.0,40.2,40.2,40.2,40.5,40.7,41.0,41.0,41.0,41.2,41.6,41.8,41.8,41.8,42.0,42.0,42.1,42.2,42.2,42.6,43.0,43.0,43.5,43.5,43.9,43.9,44.0,44.0,44.0,44.0,44.0,44.3,44.5,44.6,45.0,45.0,45.9,46.0,46.0,46.0,46.0,46.0,46.5,46.5,46.5,47.2,47.5,48.4,48.5,48.5,48.5,48.5,48.7,48.7,48.8,48.8,49.0,49.0,49.0,49.0,49.5,49.5,49.5,49.5,49.5,49.5,49.9,50.0,50.0,50.1,50.4,50.5,51.0,51.6,52.4,52.4,52.4,52.6,52.7,52.9,53.0,53.2,54.8,54.8,55.0,55.4,55.6,56.0,56.3,56.4,57.0,57.0,57.0,57.0,57.0,57.6,57.6,57.7,58.0,58.0,58.3,58.8,59.0,59.0,59.0,59.0,59.0,59.0,59.4,59.6,59.6,59.8,59.9,59.9, ...

# %%
dz=Global.copy()
dz=Zscore(dz,"price")
dz
# Out:
# Zscore_price Seuil_ConF_Zscore
#        sku                                         post_title  price  \
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 573  14338           Maurel Pays d'Oc Cabernet-Sauvignon 2017    5.7
# 99   16209                     Maurel Cabardès Tradition 2017    5.7
# ..     ...                                                ...    ...
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# 219   3510                               Cognac Frapin VIP XO  176.0
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 735          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 664          0.0              0.0                     0.00
# 573          0.0              0.0                     0.00
# 99           6.0             34.2                     0.05
# ..           ...              ...                      ...
# 566          0.0              0.0                     0.00
# 219         13.0           2288.0                     3.24
# 601          3.0            573.9                     0.81
# 434          0.0              0.0                     0.00
# 200          5.0           1125.0                     1.59
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 735                100.00            0             0.0         0.0      0
# 734                100.00            0             0.0         0.0      0
# 664                100.00      instock            30.0      6129.0  14570
# 573                100.00      instock           132.0      5777.0  14338
# 99                  97.76      instock            94.0      4174.0  16209
# ..                    ...          ...             ...         ...    ...
# 566                100.00      instock            12.0      5767.0  15185
# 219                 15.95      instock             8.0      4402.0   3510
# 601                 45.02      instock            10.0      5892.0  14983
# 434                100.00      instock            20.0      5001.0  14581
# 200                 23.98   outofstock             0.0      4352.0  15940
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 573   5777.0      Prix <= 10€  Autres (vins)      quartile1                -
# 99    4174.0      Prix <= 10€  Autres (vins)      quartile1                -
# ..       ...              ...            ...            ...              ...
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 219   4402.0      Prix > 100€         Cognac      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 200   4352.0      Prix > 100€      Champagne      quartile3   IQ_Ouliers_Sup
#
#      Zscore_price Seuil_ConF_Zscore
# 735     -1.167472               99%
# 734     -1.167472               99%
# 664     -0.978522               99%
# 573     -0.960353               99%
# 99      -0.960353               99%
# ..            ...               ...
# 566      5.191437   Inférieur à 90%
# 219      5.227774   Inférieur à 90%
# 601      5.783724   Inférieur à 90%
# 434      6.735743   Inférieur à 90%
# 200      7.008268   Inférieur à 90%
#
# [736 rows x 18 columns]

# %%
#Methode Graphique 
df=Global.copy()
px.histogram(df, x="price", color="BouteilleCAT",facet_col="BouteilleCAT",
            marginal='box',     #'rug', 'box', 'violin', or 'histogram'
            hover_data=df.columns ,text_auto=True,
            title="Distribution des prix unitaires des bouteilles € par catergorie de boissons")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fc67b65f-80c3-4869-840e-901c460a5046" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc67b65f-80c3-4869-840e-901c460a5046")) {                    Plotly.newPlot(                        "fc67b65f-80c3-4869-840e-901c460a5046",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"BouteilleCAT=Autres (vins)<br>price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Autres (vins)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Autres (vins)","offsetgroup":"Autres (vins)","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":[0.0,0.0,5.2,5.7,5.7,5.7,5.7,5.8,5.8,5.8,5.8,6.3,6.5,6.5,6.5,6.7,6.8,6.8,7.0,7.0,7.1,7.1,7.1,7.2,7.4,7.4,7.5,7.6,7.6,7.7,7.8,7.8,7.9,7.9,8.1,8.2,8.4,8.5,8.5,8.6,8.6,8.7,8.7,8.7,8.7,8.7,8.9,8.9,8.9,9.0,9.0,9.1,9.1,9.2,9.3,9.3,9.3,9.3,9.3,9.3,9.4,9.5,9.5,9.6,9.6,9.7,9.7,9.7,9.8,9.8,9.8,9.9,9.9,9.9,9.9,9.9,9.9,10.1,10.1,10.2,10.2,10.3,10.3,10.4,10.4,10.6,10.6,10.7,10.7,10.7,10.7,10.8,10.8,10.8,10.9,10.9,11.0,11.1,11.1,11.1,11.1,11.1,11.1,11.1,11.3,11.3,11.5,11.5,11.6,11.6,11.6,11.8,11.9,11.9,11.9,11.9,11.9,12.0,12.0,12.0,12.0,12.0,12.1,12.1,12.1,12.2,12.3,12.3,12.5,12.5,12.5,12.6,12.6,12.6,12.6,12.7,12.7,12.7,12.7,12.7,12.7,12.8,12.8,12.8,12.8,12.8,12.8,12.9,12.9,12.9,12.9,12.9,13.0,13.1,13.1,13.2,13.2,13.3,13.3,13.4,13.4,13.4,13.5,13.5,13.5,13.5,13.5,13.5,13.5,13.6,13.6,13.7,13.7,13.7,13.7,13.7,13.8,13.9,14.0,14.05,14.1,14.1,14.1,14.3,14.3,14.3,14.4,14.4,14.4,14.5,14.5,14.5,14.6,14.7,14.8,14.9,14.9,14.9,15.2,15.2,15.2,15.3,15.3,15.4,15.4,15.4,15.4,15.5,15.5,15.8,15.8,15.8,15.8,15.8,15.9,16.1,16.1,16.2,16.3,16.3,16.3,16.3,16.3,16.3,16.4,16.4,16.4,16.45,16.5,16.5,16.6,16.6,16.6,16.6,16.7,16.7,16.7,16.8,16.8,16.9,16.9,16.9,16.9,16.9,17.0,17.0,17.0,17.1,17.1,17.1,17.1,17.2,17.2,17.2,17.3,17.4,17.5,17.5,17.5,17.6,17.7,17.8,17.8,17.8,17.9,17.9,17.9,18.0,18.0,18.1,18.2,18.2,18.2,18.2,18.25,18.3,18.4,18.4,18.5,18.5,18.6,18.7,18.7,18.8,18.9,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.2,19.2,19.2,19.3,19.3,19.5,19.5,19.5,19.5,19.8,19.8,19.8,19.8,19.8,19.8,20.1,20.2,20.2,20.35,20.4,20.4,20.5,20.5,20.6,20.8,20.8,20.8,20.8,21.0,21.0,21.2,21.4,21.5,21.6,21.7,21.7,21.8,21.8,21.8,21.9,22.0,22.0,22.1,22.2,22.4,22.4,22.8,22.8,22.8,22.8,22.8,22.9,22.9,23.0,23.0,23.0,23.0,23.2,23.2,23.2,23.4,23.4,23.4,23.5,23.6,23.7,23.8,24.0,24.0,24.0,24.0,24.0,24.0,24.2,24.2,24.3,24.3,24.4,24.4,24.4,24.4,24.5,24.5,24.6,24.7,24.8,25.0,25.0,25.0,25.0,25.2,25.2,25.3,25.3,25.7,25.7,25.9,25.9,25.9,25.9,26.0,26.2,26.4,26.5,26.5,26.5,26.5,26.5,26.6,26.7,26.7,26.9,27.0,27.2,27.3,27.3,27.3,27.5,27.5,27.7,27.8,27.8,27.9,27.9,27.9,27.9,27.9,28.0,28.0,28.0,28.0,28.1,28.1,28.4,28.4,28.5,28.5,28.5,28.8,29.0,29.0,29.0,29.2,29.4,29.5,29.5,29.7,29.8,29.8,29.8,29.9,29.9,30.0,30.0,30.1,30.5,30.6,30.8,31.0,31.2,31.5,31.5,31.6,31.7,31.7,31.7,32.0,32.1,32.2,32.2,32.6,32.7,32.8,32.8,33.2,33.2,33.2,33.4,33.4,33.6,33.7,34.3,34.3,34.3,34.4,34.7,34.8,35.0,35.1,35.2,35.3,35.6,35.6,35.6,36.0,36.0,36.2,36.3,36.9,37.0,37.2,37.7,38.0,38.0,38.0,38.4,38.4,38.5,38.6,38.6,38.6,38.6,39.0,39.0,39.1,39.2,39.6,39.8,40.0,40.2,40.2,40.2,40.5,40.7,41.0,41.0,41.0,41.2,41.6,41.8,41.8,41.8,42.0,42.0,42.1,42.2,42.2,42.6,43.0,43.0,43.5,43.5,43.9,43.9,44.0,44.0,44.0,44.0,44.3,44.5,44.6,45.0,45.9,46.0,46.0,46.0,46.0,46.0,46.5,46.5,46.5,47.2,48.4,48.5,48.5,48.5,48.5,48.7,48.7,48.8,48.8,49.0,49.0,49.5,49.5,49.9,50.0,50.0,50.1,50.4,50.5,51.0,52.4,52.4,52.4,52.6,52.7,52.9,53.2,54.8,54.8,55.0,55.4,55.6,56.0,56.3,56.4,57.0,57.0,57.0,57.6,57.6,57.7,58.0,58.0,58.3,58.8,59.0,59.4,59.6,59.6,59.9,59.9,60.0,60.0,60.4,61.6,61.6,62.4,62.4,62.4,63.4,63.5,63.5,64.9,65.0,65.9,67.0,67.2,67.5,68.3,69.0,69.0,69.8,71.3,71.3,71.5,71.6,71.7,72.0,73.3,74.5,74.8,76.8,77.4,7 ...

# %%
df=Global.copy()
# Caculs Seuils des quartiles Pour Methode Graphique 
col="price"
q25=df[col].quantile(q=0.25, interpolation='linear')
q50=df[col].quantile(q=0.50, interpolation='linear')
q75=df[col].quantile(q=0.75, interpolation='linear')
print("Prix unitaire par quartiles : q25%<","%.2f" %(q25),"€-"," q50%","%.2f" %(q50),"€-","  q75%","%.2f" %(q75),"€-")




# print(df.price.describe())  # VERIF  OK 

df=QartileIndicatorCol(df,"price")

#Z-score  pour Methode Numérique 
df=Zscore(df,"price")
df

#DEBUG : 
# df["Zscore_priceTest"] = stats.zscore(df.price, axis=0, nan_policy='omit')
# df["ZscoreManuel"] = (df.price - df.price.mean())/df.price.std(ddof=0) #OK 
# df["CheckZscore"]=df.Zscore_price==df.ZscoreManuel
# df["CheckZscoreV2"]=df.Zscore_price-df.ZscoreManuel  #Ok différence lié à l'arrondi ! 

df.sort_values(by='price', ascending=False, inplace=True)

VerifPrix=df
VerifPrix
# Out:
# Prix unitaire par quartiles : q25%< 14.04 €-  q50% 23.30 €-   q75% 41.80 €-
# Methode IQ price: Ecart Interquartile=  27.762499999999996  -Q1  14.037500000000001  -Q2  23.299999999999997  -Q3  41.8
# Zscore_price Seuil_ConF_Zscore
#        sku                                         post_title  price  \
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 219   3510                               Cognac Frapin VIP XO  176.0
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# ..     ...                                                ...    ...
# 573  14338           Maurel Pays d'Oc Cabernet-Sauvignon 2017    5.7
# 97   16210                   Maurel Pays d'Oc Chardonnay 2019    5.7
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 200          5.0           1125.0                     1.59
# 434          0.0              0.0                     0.00
# 601          3.0            573.9                     0.81
# 219         13.0           2288.0                     3.24
# 566          0.0              0.0                     0.00
# ..           ...              ...                      ...
# 573          0.0              0.0                     0.00
# 97          43.0            245.1                     0.35
# 664          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 735          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 200                 23.98   outofstock             0.0      4352.0  15940
# 434                100.00      instock            20.0      5001.0  14581
# 601                 45.02      instock            10.0      5892.0  14983
# 219                 15.95      instock             8.0      4402.0   3510
# 566                100.00      instock            12.0      5767.0  15185
# ..                    ...          ...             ...         ...    ...
# 573                100.00      instock           132.0      5777.0  14338
# 97                  61.69      instock           167.0      4172.0  16210
# 664                100.00      instock            30.0      6129.0  14570
# 734                100.00            0             0.0         0.0      0
# 735                100.00            0             0.0         0.0      0
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 200   4352.0      Prix > 100€      Champagne      quartile3   IQ_Ouliers_Sup
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 219   4402.0      Prix > 100€         Cognac      quartile3   IQ_Ouliers_Sup
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# ..       ...              ...            ...            ...              ...
# 573   5777.0      Prix <= 10€  Autres (vins)      quartile1                -
# 97    4172.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
#
#      Zscore_price Seuil_ConF_Zscore
# 200      7.008268   Inférieur à 90%
# 434      6.735743   Inférieur à 90%
# 601      5.783724   Inférieur à 90%
# 219      5.227774   Inférieur à 90%
# 566      5.191437   Inférieur à 90%
# ..            ...               ...
# 573     -0.960353               99%
# 97      -0.960353               99%
# 664     -0.978522               99%
# 734     -1.167472               99%
# 735     -1.167472               99%
#
# [736 rows x 18 columns]

# %%
# Liste des Outliers potenciels
# VerifPrix[ VerifPrix.Seuil_ConF_Zscore == "Inférieur à 90%" | VerifPrix.price_IQ_Ouliers != "-"]
VerifPrix[ VerifPrix.Seuil_ConF_Zscore == "Inférieur à 90%" ]  # Zscore
VerifPrix[ VerifPrix.price_IQ_Ouliers != "-"]
# Out:
#        sku                                         post_title  price  \
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 219   3510                               Cognac Frapin VIP XO  176.0
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# 222   7819  Cognac Frapin Château de Fontpinot 1989 20 Ans...  157.0
# 387  14220  Domaine Des Croix Corton Charlemagne Grand Cru...  137.0
# 661  14923             Champagne Gosset Célébris Vintage 2007  135.0
# 202  12589     Champagne Egly-Ouriet Grand Cru Blanc de Noirs  126.5
# 524  14915  Domaine Weinbach Gewurztraminer Grand Cru Furs...  124.8
# 617  14775  Wemyss Malts Single Cask Scotch Whisky Choc 'n...  122.0
# 676  15070  Domaine des Comtes Lafon Volnay 1er Cru Champa...  121.0
# 673  15072  Domaine des Comtes Lafon Volnay 1er Cru Santen...  121.0
# 667  15126  Domaine Clerget Echezeaux Grand Cru En Orveaux...  116.4
# 672  13996  Domaine des Comtes Lafon Volnay 1er Cru Santen...  115.0
# 675  12790  Domaine des Comtes Lafon Volnay 1er Cru Champa...  115.0
# 618  14773  Wemyss Malts Single Cask Scotch Whisky Chai Ca...  114.0
# 447  13914  Champagne Agrapart &amp; Fils L'Avizoise Extra...  112.0
# 229  12857  Château de Meursault Puligny-Montrachet 1er Cr...  109.6
# 220   3507              Cognac Frapin Château de Fontpinot XO  108.5
# 666  14596  David Duband Chambolle-Musigny 1er Cru Les Sen...  105.6
# 439  12791  Domaine des Comtes Lafon Volnay 1er Cru Santen...  105.0
# 440  11602  Domaine des Comtes Lafon Volnay 1er Cru Santen...  105.0
# 223   3509                          Cognac Frapin Cigar Blend  104.0
# 386  14805  Domaine Des Croix Corton Grand Cru Les Grèves ...  102.3
# 63   15382  Zind-Humbrecht Riesling Grand Cru Rangen De Th...  100.0
# 674  11601  Domaine des Comtes Lafon Volnay 1er Cru Champa...   99.0
# 616  14774  Wemyss Malts Single Cask Scotch Whisky Chocola...   93.0
# 514  19822                      Tempier Bandol Cabassaou 2017   92.0
# 65   11668  Zind-Humbrecht Pinot Gris Grand Cru Rangen De ...   88.4
# 448  13913  Champagne Agrapart &amp; Fils Minéral Extra Br...   86.8
# 206  13853  Champagne Larmandier-Bernier Grand Cru Les Che...   85.6
# 519  13982  Lucien Boillot Puligny-Montrachet 1er Cru Les ...   83.7
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 200          5.0           1125.0                     1.59
# 434          0.0              0.0                     0.00
# 601          3.0            573.9                     0.81
# 219         13.0           2288.0                     3.24
# 566          0.0              0.0                     0.00
# 222          0.0              0.0                     0.00
# 387          5.0            685.0                     0.97
# 661          2.0            270.0                     0.38
# 202         11.0           1391.5                     1.97
# 524          0.0              0.0                     0.00
# 617          0.0              0.0                     0.00
# 676          0.0              0.0                     0.00
# 673          0.0              0.0                     0.00
# 667          0.0              0.0                     0.00
# 672          2.0            230.0                     0.33
# 675          0.0              0.0                     0.00
# 618          0.0              0.0                     0.00
# 447          0.0              0.0                     0.00
# 229          0.0              0.0                     0.00
# 220          2.0            217.0                     0.31
# 666          0.0              0.0                     0.00
# 439          0.0              0.0                     0.00
# 440          0.0              0.0                     0.00
# 223          1.0            104.0                     0.15
# 386          0.0              0.0                     0.00
# 63           0.0              0.0                     0.00
# 674          0.0              0.0                     0.00
# 616          0.0              0.0                     0.00
# 514          0.0              0.0                     0.00
# 65           0.0              0.0                     0.00
# 448          0.0              0.0                     0.00
# 206          1.0             85.6                     0.12
# 519          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 200                 23.98   outofstock             0.0      4352.0  15940
# 434                100.00      instock            20.0      5001.0  14581
# 601                 45.02      instock            10.0      5892.0  14983
# 219                 15.95      instock             8.0      4402.0   3510
# 566                100.00      instock            12.0      5767.0  15185
# 222                100.00      instock             3.0      4406.0   7819
# 387                 40.77      instock            13.0      4904.0  14220
# 661                 58.81      instock            10.0      6126.0  14923
# 202                 22.38      instock             2.0      4355.0  12589
# 524                100.00      instock            12.0      5612.0  14915
# 617                100.00      instock             4.0      5917.0  14775
# 676                100.00      instock             6.0      6216.0  15070
# 673                100.00      instock             7.0      6213.0  15072
# 667                100.00      instock            14.0      6202.0  15126
# 672                 64.37      instock             2.0      6212.0  13996
# 675                100.00      instock             4.0      6215.0  12790
# 618                100.00      instock             8.0      5918.0  14773
# 447                100.00   outofstock             0.0      5025.0  13914
# 229                100.00      instock             7.0      4582.0  12857
# 220                 66.87      instock             2.0      4404.0   3507
# 666                100.00      instock             7.0      6201.0  14596
# 439                100.00      instock            17.0      5007.0  12791
# 440                100.00      instock            10.0      5008.0  11602
# 223                 85.68      instock             6.0      4407.0   3509
# 386                100.00      instock            20.0      4903.0  14805
# 63                 100.00      instock            11.0      4115.0  15382
# 674                100.00      instock             7.0      6214.0  11601
# 616                100.00      instock             3.0      5916.0  14774
# 514                100.00   outofstock             0.0      5565.0  19822
# 65                 100.00      instock             5.0      4132.0  11668
# 448                100.00      instock             2.0      5026.0  13913
# 206                 88.60   outofstock             0.0      4359.0  13853
# 519                100.00      instock            18.0      5580.0  13982
#
#      guid_ID   PrixBouteilleCAT   BouteilleCAT price_Quartile  \
# 200   4352.0        Prix > 100€      Champagne      quartile3
# 434   5001.0        Prix > 100€  Autres (vins)      quartile3
# 601   5892.0        Prix > 100€  Autres (vins)      quartile3
# 219   4402.0        Prix > 100€         Cognac      quartile3
# 566   5767.0        Prix > 100€  Autres (vins)      quartile3
# 222   4406.0        Prix > 100€         Cognac      quartile3
# 387   4904.0        Prix > 100€  Autres (vins)      quartile3
# 661   6126.0        Prix > 100€      Champagne      quartile3
# 202   4355.0        Prix > 100€      Champagne      quartile3
# 524   5612.0        Prix > 100€  Autres (vins)      quartile3
# 617   5917.0        Prix > 100€         Whisky      quartile3
# 676   6216.0        Prix > 100€  Autres (vins)      quartile3
# 673   6213.0        Prix > 100€  Autres (vins)      quartile3
# 667   6202.0        Prix > 100€  Autres (vins)      quartile3
# 672   6212.0        Prix > 100€  Autres (vins)      quartile3
# 675   6215.0        Prix > 100€  Autres (vins)      quartile3
# 618   5918.0        Prix > 100€         Whisky      quartile3
# 447   5025.0        Prix > 100€      Champagne      quartile3
# 229   4582.0        Prix > 100€  Autres (vins)      quartile3
# 220   4404.0        Prix > 100€         Cognac      quartile3
# 666   6201.0        Prix > 100€  Autres (vins)      quartile3
# 439   5007.0        Prix > 100€  Autres (vins)      quartile3
# 440   5008.0        Prix > 100€  Autres (vins)      quartile3
# 223   4407.0        Prix > 100€         Cognac      quartile3
# 386   4903.0        Prix > 100€  Autres (vins)      quartile3
# 63    4115.0        Prix > 100€  Autres (vins)      quartile3
# 674   6214.0  50€ > Prix < 100€  Autres (vins)      quartile3
# 616   5916.0  50€ > Prix < 100€         Whisky      quartile3
# 514   5565.0  50€ > Prix < 100€  Autres (vins)      quartile3
# 65    4132.0  50€ > Prix < 100€  Autres (vins)      quartile3
# 448   5026.0  50€ > Prix < 100€      Champagne      quartile3
# 206   4359.0  50€ > Prix < 100€      Champagne      quartile3
# 519   5580.0  50€ > Prix < 100€  Autres (vins)      quartile3
#
#     price_IQ_Ouliers  Zscore_price Seuil_ConF_Zscore
# 200   IQ_Ouliers_Sup      7.008268   Inférieur à 90%
# 434   IQ_Ouliers_Sup      6.735743   Inférieur à 90%
# 601   IQ_Ouliers_Sup      5.783724   Inférieur à 90%
# 219   IQ_Ouliers_Sup      5.227774   Inférieur à 90%
# 566   IQ_Ouliers_Sup      5.191437   Inférieur à 90%
# 222   IQ_Ouliers_Sup      4.537378   Inférieur à 90%
# 387   IQ_Ouliers_Sup      3.810645   Inférieur à 90%
# 661   IQ_Ouliers_Sup      3.737972   Inférieur à 90%
# 202   IQ_Ouliers_Sup      3.429111   Inférieur à 90%
# 524   IQ_Ouliers_Sup      3.367339   Inférieur à 90%
# 617   IQ_Ouliers_Sup      3.265596   Inférieur à 90%
# 676   IQ_Ouliers_Sup      3.229259   Inférieur à 90%
# 673   IQ_Ouliers_Sup      3.229259   Inférieur à 90%
# 667   IQ_Ouliers_Sup      3.062111   Inférieur à 90%
# 672   IQ_Ouliers_Sup      3.011240   Inférieur à 90%
# 675   IQ_Ouliers_Sup      3.011240   Inférieur à 90%
# 618   IQ_Ouliers_Sup      2.974903   Inférieur à 90%
# 447   IQ_Ouliers_Sup      2.902230   Inférieur à 90%
# 229   IQ_Ouliers_Sup      2.815022   Inférieur à 90%
# 220   IQ_Ouliers_Sup      2.775052   Inférieur à 90%
# 666   IQ_Ouliers_Sup      2.669675   Inférieur à 90%
# 439   IQ_Ouliers_Sup      2.647873   Inférieur à 90%
# 440   IQ_Ouliers_Sup      2.647873   Inférieur à 90%
# 223   IQ_Ouliers_Sup      2.611537   Inférieur à 90%
# 386   IQ_Ouliers_Sup      2.549765               90%
# 63    IQ_Ouliers_Sup      2.466190               90%
# 674   IQ_Ouliers_Sup      2.429854               90%
# 616   IQ_Ouliers_Sup      2.211834               90%
# 514   IQ_Ouliers_Sup      2.175497               90%
# 65    IQ_Ouliers_Sup      2.044685               90%
# 448   IQ_Ouliers_Sup      1.986547               90%
# 206   IQ_Ouliers_Sup      1.942943               95%
# 519   IQ_Ouliers_Sup      1.873903               95%

# %%
import plotly.express as px
['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status', 'priceQuartile']

df=VerifPrix
fig = px.box(data_frame=df, x="price", y=None, 
          color=None, 
          facet_row=None, facet_col=None, facet_col_wrap=0, facet_row_spacing=None, facet_col_spacing=None, 
          hover_name=None, hover_data=df.columns, 
          custom_data=None, 
          animation_frame=None, animation_group=None, 
          category_orders=None, labels=None, 
          color_discrete_sequence=None, 
          color_discrete_map=None, 
          orientation="h", 
          boxmode="overlay", #['group', 'overlay']
          log_x=False, log_y=False, range_x=None, 
          range_y=None, points=False, # ['all', 'outliers', 'suspectedoutliers', False]
          notched=True, 
          title="Réparttion des prix unitaires", template=None,
          width=None, height=None)

fig.show()

#https://plotly.github.io/plotly.py-docs/generated/plotly.express.box.html
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="269da05b-d2d8-404a-bb4d-29f18c9dcd45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("269da05b-d2d8-404a-bb4d-29f18c9dcd45")) {                    Plotly.newPlot(                        "269da05b-d2d8-404a-bb4d-29f18c9dcd45",                        [{"alignmentgroup":"True","boxpoints":false,"customdata":[[15940,"Champagne Egly-Ouriet Grand Cru Mill\u00e9sim\u00e9 2008",5.0,1125.0,1.59,23.98,"outofstock",0.0,4352.0,15940,4352.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",7.008268153241746,"Inf\u00e9rieur \u00e0 90%"],[14581,"David Duband Charmes-Chambertin Grand Cru 2014",0.0,0.0,0.0,100.0,"instock",20.0,5001.0,14581,5001.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",6.735743481619245,"Inf\u00e9rieur \u00e0 90%"],[14983,"Coteaux Champenois Egly-Ouriet Ambonnay Rouge 2016",3.0,573.9,0.81,45.02,"instock",10.0,5892.0,14983,5892.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",5.783723962084645,"Inf\u00e9rieur \u00e0 90%"],[3510,"Cognac Frapin VIP XO",13.0,2288.0,3.24,15.95,"instock",8.0,4402.0,3510,4402.0,"Prix > 100\u20ac","Cognac","quartile3","IQ_Ouliers_Sup",5.2277736319747445,"Inf\u00e9rieur \u00e0 90%"],[15185,"Camille Giroud Clos de Vougeot 2016",0.0,0.0,0.0,100.0,"instock",12.0,5767.0,15185,5767.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",5.191437009091745,"Inf\u00e9rieur \u00e0 90%"],[7819,"Cognac Frapin Ch\u00e2teau de Fontpinot 1989 20 Ans d'Age",0.0,0.0,0.0,100.0,"instock",3.0,4406.0,7819,4406.0,"Prix > 100\u20ac","Cognac","quartile3","IQ_Ouliers_Sup",4.5373777971977445,"Inf\u00e9rieur \u00e0 90%"],[14220,"Domaine Des Croix Corton Charlemagne Grand Cru 2016",5.0,685.0,0.97,40.77,"instock",13.0,4904.0,14220,4904.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.810645339537744,"Inf\u00e9rieur \u00e0 90%"],[14923,"Champagne Gosset C\u00e9l\u00e9bris Vintage 2007",2.0,270.0,0.38,58.81,"instock",10.0,6126.0,14923,6126.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",3.737972093771744,"Inf\u00e9rieur \u00e0 90%"],[12589,"Champagne Egly-Ouriet Grand Cru Blanc de Noirs",11.0,1391.5,1.97,22.38,"instock",2.0,4355.0,12589,4355.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",3.429110799266244,"Inf\u00e9rieur \u00e0 90%"],[14915,"Domaine Weinbach Gewurztraminer Grand Cru Furstentum SGN 2010 1/2",0.0,0.0,0.0,100.0,"instock",12.0,5612.0,14915,5612.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.367338540365144,"Inf\u00e9rieur \u00e0 90%"],[14775,"Wemyss Malts Single Cask Scotch Whisky Choc 'n' Nut Pretzel 2001 Bunnahabhain",0.0,0.0,0.0,100.0,"instock",4.0,5917.0,14775,5917.0,"Prix > 100\u20ac","Whisky","quartile3","IQ_Ouliers_Sup",3.2655959962927437,"Inf\u00e9rieur \u00e0 90%"],[15070,"Domaine des Comtes Lafon Volnay 1er Cru Champans 2016",0.0,0.0,0.0,100.0,"instock",6.0,6216.0,15070,6216.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.229259373409744,"Inf\u00e9rieur \u00e0 90%"],[15072,"Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2016",0.0,0.0,0.0,100.0,"instock",7.0,6213.0,15072,6213.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.229259373409744,"Inf\u00e9rieur \u00e0 90%"],[15126,"Domaine Clerget Echezeaux Grand Cru En Orveaux 2015",0.0,0.0,0.0,100.0,"instock",14.0,6202.0,15126,6202.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.062110908147944,"Inf\u00e9rieur \u00e0 90%"],[13996,"Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2015",2.0,230.0,0.33,64.37,"instock",2.0,6212.0,13996,6212.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.011239636111744,"Inf\u00e9rieur \u00e0 90%"],[12790,"Domaine  ...

# %%
import plotly.express as px
['product_id', 'onsale_web', 'price', 'stock_quantity', 'stock_status', 'priceQuartile']

df=VerifPrix
fig = px.box(data_frame=df, x="price", y=None, 
          color=None, 
          facet_row=None, facet_col=None, facet_col_wrap=0, facet_row_spacing=None, facet_col_spacing=None, 
          hover_name=None, hover_data=df.columns, 
          custom_data=None, 
          animation_frame=None, animation_group=None, 
          category_orders=None, labels=None, 
          color_discrete_sequence=None, 
          color_discrete_map=None, 
          orientation="h", 
          boxmode="overlay", #['group', 'overlay']
          log_x=False, log_y=False, range_x=None, 
          range_y=None, points='suspectedoutliers', # ['all', 'outliers', 'suspectedoutliers', False]
          notched=True,
          title="Réparttion des prix unitaires et visualisation des Outilers potentiels & Outliers ", template=None,
          width=None, height=None)

fig.show()

#https://plotly.github.io/plotly.py-docs/generated/plotly.express.box.html
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c3af7ad4-44dc-4cbf-b580-34de0b059e2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3af7ad4-44dc-4cbf-b580-34de0b059e2d")) {                    Plotly.newPlot(                        "c3af7ad4-44dc-4cbf-b580-34de0b059e2d",                        [{"alignmentgroup":"True","boxpoints":"suspectedoutliers","customdata":[[15940,"Champagne Egly-Ouriet Grand Cru Mill\u00e9sim\u00e9 2008",5.0,1125.0,1.59,23.98,"outofstock",0.0,4352.0,15940,4352.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",7.008268153241746,"Inf\u00e9rieur \u00e0 90%"],[14581,"David Duband Charmes-Chambertin Grand Cru 2014",0.0,0.0,0.0,100.0,"instock",20.0,5001.0,14581,5001.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",6.735743481619245,"Inf\u00e9rieur \u00e0 90%"],[14983,"Coteaux Champenois Egly-Ouriet Ambonnay Rouge 2016",3.0,573.9,0.81,45.02,"instock",10.0,5892.0,14983,5892.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",5.783723962084645,"Inf\u00e9rieur \u00e0 90%"],[3510,"Cognac Frapin VIP XO",13.0,2288.0,3.24,15.95,"instock",8.0,4402.0,3510,4402.0,"Prix > 100\u20ac","Cognac","quartile3","IQ_Ouliers_Sup",5.2277736319747445,"Inf\u00e9rieur \u00e0 90%"],[15185,"Camille Giroud Clos de Vougeot 2016",0.0,0.0,0.0,100.0,"instock",12.0,5767.0,15185,5767.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",5.191437009091745,"Inf\u00e9rieur \u00e0 90%"],[7819,"Cognac Frapin Ch\u00e2teau de Fontpinot 1989 20 Ans d'Age",0.0,0.0,0.0,100.0,"instock",3.0,4406.0,7819,4406.0,"Prix > 100\u20ac","Cognac","quartile3","IQ_Ouliers_Sup",4.5373777971977445,"Inf\u00e9rieur \u00e0 90%"],[14220,"Domaine Des Croix Corton Charlemagne Grand Cru 2016",5.0,685.0,0.97,40.77,"instock",13.0,4904.0,14220,4904.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.810645339537744,"Inf\u00e9rieur \u00e0 90%"],[14923,"Champagne Gosset C\u00e9l\u00e9bris Vintage 2007",2.0,270.0,0.38,58.81,"instock",10.0,6126.0,14923,6126.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",3.737972093771744,"Inf\u00e9rieur \u00e0 90%"],[12589,"Champagne Egly-Ouriet Grand Cru Blanc de Noirs",11.0,1391.5,1.97,22.38,"instock",2.0,4355.0,12589,4355.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",3.429110799266244,"Inf\u00e9rieur \u00e0 90%"],[14915,"Domaine Weinbach Gewurztraminer Grand Cru Furstentum SGN 2010 1/2",0.0,0.0,0.0,100.0,"instock",12.0,5612.0,14915,5612.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.367338540365144,"Inf\u00e9rieur \u00e0 90%"],[14775,"Wemyss Malts Single Cask Scotch Whisky Choc 'n' Nut Pretzel 2001 Bunnahabhain",0.0,0.0,0.0,100.0,"instock",4.0,5917.0,14775,5917.0,"Prix > 100\u20ac","Whisky","quartile3","IQ_Ouliers_Sup",3.2655959962927437,"Inf\u00e9rieur \u00e0 90%"],[15070,"Domaine des Comtes Lafon Volnay 1er Cru Champans 2016",0.0,0.0,0.0,100.0,"instock",6.0,6216.0,15070,6216.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.229259373409744,"Inf\u00e9rieur \u00e0 90%"],[15072,"Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2016",0.0,0.0,0.0,100.0,"instock",7.0,6213.0,15072,6213.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.229259373409744,"Inf\u00e9rieur \u00e0 90%"],[15126,"Domaine Clerget Echezeaux Grand Cru En Orveaux 2015",0.0,0.0,0.0,100.0,"instock",14.0,6202.0,15126,6202.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.062110908147944,"Inf\u00e9rieur \u00e0 90%"],[13996,"Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2015",2.0,230.0,0.33,64.37,"instock",2.0,6212.0,13996,6212.0,"Prix > 100\u20ac","Autres (vins)","quartile3","IQ_Ouliers_Sup",3.011239636111744,"Inf\u00e9rieur \u00e0 90%"],[1 ...

# %%
VerifPrix.describe()
# Out:
#             price  total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# count  736.000000   736.000000       736.000000               736.000000
# mean    32.129348     3.892663        95.881250                 0.135815
# std     27.539159     8.417549       303.512915                 0.430056
# min      0.000000     0.000000         0.000000                 0.000000
# 25%     14.037500     0.000000         0.000000                 0.000000
# 50%     23.300000     1.000000        12.600000                 0.020000
# 75%     41.800000     4.000000        87.125000                 0.120000
# max    225.000000    96.000000      4704.000000                 6.670000
#
#        ChiffreAffairescum_p  stock_quantity   product_id      guid_ID  \
# count            736.000000      736.000000   736.000000   736.000000
# mean              90.611454       27.910326  5028.158967  4895.911685
# std               16.617286       47.530986   831.788599  1129.898113
# min                6.670000        0.000000     0.000000     0.000000
# 25%               88.327500        1.000000  4285.750000  4261.750000
# 50%               99.780000       12.000000  4861.500000  4785.500000
# 75%              100.000000       35.000000  5712.750000  5703.250000
# max              100.000000      578.000000  7338.000000  7338.000000
#
#        Zscore_price
# count  7.360000e+02
# mean  -7.584513e-16
# std    1.000680e+00
# min   -1.167472e+00
# 25%   -6.573967e-01
# 50%   -3.208287e-01
# 75%    3.513988e-01
# max    7.008268e+00

# %% [markdown]
# L'approche globale n'est pas pertinante car des produits aux caractéristiques très diférentes (process, prix marché, contenance par bouteille, ....)  sont mélangés  et donc réduit la fiabilité des test satistiques effectués.  Une approche par segment produits (aux caractiques plus similaire) sera plus fiable et permetra de ce concentrer sur un liste plus réduite.

# %% [markdown]
# ## Verification prix par Segment Produit

# %%
# Segmentation marché : Prix Vente bouteille
df=VerifPrix.copy()
df.fillna(0,inplace=True)
ColRefName="price" # Nom Colonne de référence pour la segmentation
ColCatName="PrixBouteilleCAT" # Nom Colonne Categorie
df[ColCatName]="?"

df.loc[ df[ ColRefName ] >= 100, ColCatName] = "Prix > 100€"
df.loc[ df[ ColRefName ] < 100, ColCatName] = "50€ > Prix < 100€"
df.loc[ df[ ColRefName ] <= 50, ColCatName] = "30€ > Prix <= 50€"
df.loc[ df[ ColRefName ] <= 30, ColCatName] = "10€ > Prix <= 30€"
df.loc[ df[ ColRefName ] <= 10, ColCatName] = "Prix <= 10€"
df
#---------------------------------------------------------------


# Segmentation marché : Regex extraction Cat produit (Champagne, Cognac, Whisky, Autres (vins),?)
# df=VerifPrix.copy()
# df.fillna(0,inplace=True)
ColRefName="post_title" # Nom Colonne de référence pour la segmentation
ColCatName="BouteilleCAT" # Nom Colonne Categorie
df[ColCatName]="?"

df.loc[ df[ColRefName].str.contains("Champagne|champagne") == True, ColCatName] = "Champagne"
df.loc[ df[ColRefName].str.contains("Cognac|cognac") == True, ColCatName] = "Cognac"
df.loc[ df[ColRefName].str.contains("Whisky|whisky") == True, ColCatName] = "Whisky"
df.loc[ df[ColRefName].str.contains("Champagne|champagne|Cognac|cognac|Whisky|whisky") == False, ColCatName] = "Autres (vins)"
df
#---------------------------------------------------------------
VerifPrix=df
VerifPrix
# Out:
#        sku                                         post_title  price  \
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 219   3510                               Cognac Frapin VIP XO  176.0
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# ..     ...                                                ...    ...
# 573  14338           Maurel Pays d'Oc Cabernet-Sauvignon 2017    5.7
# 97   16210                   Maurel Pays d'Oc Chardonnay 2019    5.7
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 200          5.0           1125.0                     1.59
# 434          0.0              0.0                     0.00
# 601          3.0            573.9                     0.81
# 219         13.0           2288.0                     3.24
# 566          0.0              0.0                     0.00
# ..           ...              ...                      ...
# 573          0.0              0.0                     0.00
# 97          43.0            245.1                     0.35
# 664          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 735          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 200                 23.98   outofstock             0.0      4352.0  15940
# 434                100.00      instock            20.0      5001.0  14581
# 601                 45.02      instock            10.0      5892.0  14983
# 219                 15.95      instock             8.0      4402.0   3510
# 566                100.00      instock            12.0      5767.0  15185
# ..                    ...          ...             ...         ...    ...
# 573                100.00      instock           132.0      5777.0  14338
# 97                  61.69      instock           167.0      4172.0  16210
# 664                100.00      instock            30.0      6129.0  14570
# 734                100.00            0             0.0         0.0      0
# 735                100.00            0             0.0         0.0      0
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 200   4352.0      Prix > 100€      Champagne      quartile3   IQ_Ouliers_Sup
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 219   4402.0      Prix > 100€         Cognac      quartile3   IQ_Ouliers_Sup
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# ..       ...              ...            ...            ...              ...
# 573   5777.0      Prix <= 10€  Autres (vins)      quartile1                -
# 97    4172.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
#
#      Zscore_price Seuil_ConF_Zscore
# 200      7.008268   Inférieur à 90%
# 434      6.735743   Inférieur à 90%
# 601      5.783724   Inférieur à 90%
# 219      5.227774   Inférieur à 90%
# 566      5.191437   Inférieur à 90%
# ..            ...               ...
# 573     -0.960353               99%
# 97      -0.960353               99%
# 664     -0.978522               99%
# 734     -1.167472               99%
# 735     -1.167472               99%
#
# [736 rows x 18 columns]

# %% [markdown]
# ###  Création des DataFrames par segment produit

# %%
print(pcolors.OK+"Création des DataFrame par Catégories Produit"+pcolors.RESET)

df=VerifPrix.copy()

dfChamp=df[df.post_title.str.contains("Champagne|Champagne") == True]
dfChamp

dfWhisky=df[df.post_title.str.contains("Whisky|whisky") == True]
dfWhisky
dfCognac=df[df.post_title.str.contains("Cognac|cognac") == True]
dfCognac

dfAutre=df[df.post_title.str.contains("Champagne|Champagne|Cognac|cognac|Whisky|whisky") == False]
dfAutre
# Out:
# Création des DataFrame par Catégories Produit
#        sku                                         post_title  price  \
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# 387  14220  Domaine Des Croix Corton Charlemagne Grand Cru...  137.0
# 524  14915  Domaine Weinbach Gewurztraminer Grand Cru Furs...  124.8
# ..     ...                                                ...    ...
# 573  14338           Maurel Pays d'Oc Cabernet-Sauvignon 2017    5.7
# 97   16210                   Maurel Pays d'Oc Chardonnay 2019    5.7
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 434          0.0              0.0                     0.00
# 601          3.0            573.9                     0.81
# 566          0.0              0.0                     0.00
# 387          5.0            685.0                     0.97
# 524          0.0              0.0                     0.00
# ..           ...              ...                      ...
# 573          0.0              0.0                     0.00
# 97          43.0            245.1                     0.35
# 664          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 735          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 434                100.00      instock            20.0      5001.0  14581
# 601                 45.02      instock            10.0      5892.0  14983
# 566                100.00      instock            12.0      5767.0  15185
# 387                 40.77      instock            13.0      4904.0  14220
# 524                100.00      instock            12.0      5612.0  14915
# ..                    ...          ...             ...         ...    ...
# 573                100.00      instock           132.0      5777.0  14338
# 97                  61.69      instock           167.0      4172.0  16210
# 664                100.00      instock            30.0      6129.0  14570
# 734                100.00            0             0.0         0.0      0
# 735                100.00            0             0.0         0.0      0
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 387   4904.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 524   5612.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# ..       ...              ...            ...            ...              ...
# 573   5777.0      Prix <= 10€  Autres (vins)      quartile1                -
# 97    4172.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
#
#      Zscore_price Seuil_ConF_Zscore
# 434      6.735743   Inférieur à 90%
# 601      5.783724   Inférieur à 90%
# 566      5.191437   Inférieur à 90%
# 387      3.810645   Inférieur à 90%
# 524      3.367339   Inférieur à 90%
# ..            ...               ...
# 573     -0.960353               99%
# 97      -0.960353               99%
# 664     -0.978522               99%
# 734     -1.167472               99%
# 735     -1.167472               99%
#
# [667 rows x 18 columns]

# %% [markdown]
# #### Export to Excel TEST

# %%
# Specify the name of the excel file
file_name = 'Output.xlsx'
  
# saving the excelsheet
dfChamp.to_excel(file_name)
print('Sales record successfully exported into Excel File')
# Out:
# Sales record successfully exported into Excel File

# %%
dfChamp.to_excel('Output.xlsx')

# %%
# !pip install openpyxl #Requirement already satisfied ! 
with pd.ExcelWriter('BottleNeck_VentesWeb_Verif_Prix.xlsx') as writer:  
   VerifPrix.to_excel(writer, sheet_name='Global-Verif_Prix',freeze_panes=(1,1))
   dfChamp.to_excel(writer, sheet_name='Champagne',freeze_panes=(1,1))
   dfCognac.to_excel(writer, sheet_name='Cognac',freeze_panes=(1,1))
   dfWhisky.to_excel(writer, sheet_name='Whisky',freeze_panes=(1,1))
   dfAutre.to_excel(writer, sheet_name='Autres',freeze_panes=(1,1))

print('DataFrame is written to Excel File successfully.')


# dfChamp.to_excel('Champagne.xlsx',)

# DOC fonction : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html

# !pip install openpyxl #Requirement already satisfied ! 
with pd.ExcelWriter('BottleNeck_VentesWeb_Verif_Prix.xlsx') as writer:  
   VerifPrix.to_excel(writer, sheet_name='Global-Verif_Prix',freeze_panes=(1,1))
# DOC fonction : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_excel.html
# Out:
# DataFrame is written to Excel File successfully.

# %% [markdown]
# ### Champagne

# %%
df=dfChamp.copy()
df=QartileIndicatorCol(df,"price")

#Z-score  pour Methode Numérique 
df=Zscore(df,"price")
df.sort_values(by='price', ascending=False, inplace=True)
VerifPrixChamp=df

print(pcolors.OK+"Liste des Champagnes"+pcolors.RESET)
VerifPrixChamp
# Out:
# Methode IQ price: Ecart Interquartile=  39.25  -Q1  42.0  -Q2  59.0  -Q3  81.25
# Zscore_price Seuil_ConF_Zscore
# Liste des Champagnes
#        sku                                         post_title  price  \
# 200  15940     Champagne Egly-Ouriet Grand Cru Millésimé 2008  225.0
# 661  14923             Champagne Gosset Célébris Vintage 2007  135.0
# 202  12589     Champagne Egly-Ouriet Grand Cru Blanc de Noirs  126.5
# 447  13914  Champagne Agrapart &amp; Fils L'Avizoise Extra...  112.0
# 448  13913  Champagne Agrapart &amp; Fils Minéral Extra Br...   86.8
# 206  13853  Champagne Larmandier-Bernier Grand Cru Les Che...   85.6
# 197   4679      Champagne Mailly Grand Cru Les Echansons 2007   83.0
# 199  12588    Champagne Egly-Ouriet Grand Cru Extra Brut V.P.   79.5
# 201  12587          Champagne Egly-Ouriet Grand Cru Brut Rosé   79.5
# 205  13854  Champagne Larmandier-Bernier Grand Cru Vieille...   77.0
# 75    7086  Champagne Mailly Grand Cru Intemporelle Rosé 2009   69.0
# 449  11997  Champagne Agrapart &amp; Fils Terroirs Brut Bl...   62.1
# 198  12586     Champagne Egly-Ouriet Grand Cru Brut Tradition   59.0
# 76    1366       Champagne Mailly Grand Cru Intemporelle 2010   59.0
# 70   11641              Champagne Gosset Grand Millésime 2006   53.0
# 203  12585  Champagne Egly-Ouriet Premier Cru Les Vignes d...   51.6
# 423  11225  Champagne Larmandier-Bernier Terre de Vertus P...   49.5
# 71    1662                        Champagne Gosset Grand Rosé   49.0
# 195   7818             Champagne Gosset Grand Blanc de Blancs   49.0
# 446  11996  Champagne Agrapart &amp; Fils Les 7 Crus Brut ...   45.0
# 204   9562              Champagne Larmandier-Bernier Latitude   39.0
# 69     304                    Champagne Gosset Grande Réserve   39.0
# 74    1364               Champagne Mailly Grand Cru Brut Rosé   37.5
# 196  13599     Champagne Mailly Grand Cru Blanc de Pinot Noir   35.5
# 73   15648  Champagne Mailly Grand Cru Extra Brut Millésim...   33.0
# 72    1360            Champagne Mailly Grand Cru Brut Réserve   29.5
# 450    531  Champagne Petit Lebrun &amp; Fils Blanc de Bla...   22.5
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 200          5.0           1125.0                     1.59
# 661          2.0            270.0                     0.38
# 202         11.0           1391.5                     1.97
# 447          0.0              0.0                     0.00
# 448          0.0              0.0                     0.00
# 206          1.0             85.6                     0.12
# 197          0.0              0.0                     0.00
# 199          0.0              0.0                     0.00
# 201          3.0            238.5                     0.34
# 205          0.0              0.0                     0.00
# 75           0.0              0.0                     0.00
# 449          0.0              0.0                     0.00
# 198          0.0              0.0                     0.00
# 76           1.0             59.0                     0.08
# 70          30.0           1590.0                     2.25
# 203         12.0            619.2                     0.88
# 423          0.0              0.0                     0.00
# 71          87.0           4263.0                     6.04
# 195         96.0           4704.0                     6.67
# 446          0.0              0.0                     0.00
# 204          0.0              0.0                     0.00
# 69          40.0           1560.0                     2.21
# 74           0.0              0.0                     0.00
# 196          1.0             35.5                     0.05
# 73           3.0             99.0                     0.14
# 72           0.0              0.0                     0.00
# 450         13.0            292.5                     0.41
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 200                 23.98   outofstock             0.0      4352.0  15940
# 661                 58.81      instock            10.0      6126.0  14923
# 202                 22.38      instock             2.0      4355.0  12589
# 447                100.00   outofstock             0.0      5025.0  13914
# 448                100.00      instock             2.0      5026.0  13913
# 206                 88.60   outofstock             0.0      4359.0  13853
# 197                100.00      instock            13.0      4337.0   4679
# 199                100.00      instock            20.0      4350.0  12588
# 201                 63.05      instock            11.0      4353.0  12587
# 205                100.00   outofstock             0.0      4358.0  13854
# 75                 100.00      instock            34.0      4149.0   7086
# 449                100.00   outofstock             0.0      5027.0  11997
# 198                100.00      instock            21.0      4348.0  12586
# 76                  92.90      instock            17.0      4150.0   1366
# 70                  18.20      instock             8.0      4142.0  11641
# 203                 42.54      instock             5.0      4356.0  12585
# 423                100.00   outofstock             0.0      4970.0  11225
# 71                  12.71      instock            11.0      4144.0   1662
# 195                  6.67   outofstock             0.0      4334.0   7818
# 446                100.00   outofstock             0.0      5024.0  11996
# 204                100.00   outofstock             0.0      4357.0   9562
# 69                  20.41      instock             1.0      4141.0    304
# 74                 100.00      instock            18.0      4148.0   1364
# 196                 97.61      instock            36.0      4336.0  13599
# 73                  86.53      instock             7.0      4147.0  15648
# 72                 100.00      instock            33.0      4146.0   1360
# 450                 56.84      instock           129.0      5047.0    531
#
#      guid_ID   PrixBouteilleCAT BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 200   4352.0        Prix > 100€    Champagne      quartile3   IQ_Ouliers_Sup
# 661   6126.0        Prix > 100€    Champagne      quartile3                -
# 202   4355.0        Prix > 100€    Champagne      quartile3                -
# 447   5025.0        Prix > 100€    Champagne      quartile3                -
# 448   5026.0  50€ > Prix < 100€    Champagne      quartile3                -
# 206   4359.0  50€ > Prix < 100€    Champagne      quartile3                -
# 197   4337.0  50€ > Prix < 100€    Champagne      quartile3                -
# 199   4350.0  50€ > Prix < 100€    Champagne      quartile2                -
# 201   4353.0  50€ > Prix < 100€    Champagne      quartile2                -
# 205   4358.0  50€ > Prix < 100€    Champagne      quartile2                -
# 75    4149.0  50€ > Prix < 100€    Champagne      quartile2                -
# 449   5027.0  50€ > Prix < 100€    Champagne      quartile2                -
# 198   4348.0  50€ > Prix < 100€    Champagne      quartile2                -
# 76    4150.0  50€ > Prix < 100€    Champagne      quartile2                -
# 70    4142.0  50€ > Prix < 100€    Champagne      quartile2                -
# 203   4356.0  50€ > Prix < 100€    Champagne      quartile2                -
# 423   4970.0  30€ > Prix <= 50€    Champagne      quartile2                -
# 71    4144.0  30€ > Prix <= 50€    Champagne      quartile2                -
# 195   4334.0  30€ > Prix <= 50€    Champagne      quartile2                -
# 446   5024.0  30€ > Prix <= 50€    Champagne      quartile2                -
# 204   4357.0  30€ > Prix <= 50€    Champagne      quartile1                -
# 69    4141.0  30€ > Prix <= 50€    Champagne      quartile1                -
# 74    4148.0  30€ > Prix <= 50€    Champagne      quartile1                -
# 196   4336.0  30€ > Prix <= 50€    Champagne      quartile1                -
# 73    4147.0  30€ > Prix <= 50€    Champagne      quartile1                -
# 72    4146.0  10€ > Prix <= 30€    Champagne      quartile1                -
# 450   5047.0  10€ > Prix <= 30€    Champagne      quartile1                -
#
#      Zscore_price Seuil_ConF_Zscore
# 200      3.754471   Inférieur à 90%
# 661      1.583740               99%
# 202      1.378727               99%
# 447      1.028998               99%
# 448      0.421193               99%
# 206      0.392250               99%
# 197      0.329540               99%
# 199      0.245123               99%
# 201      0.245123               99%
# 205      0.184825               99%
# 75      -0.008129               99%
# 449     -0.174552               99%
# 198     -0.249321               99%
# 76      -0.249321               99%
# 70      -0.394037               99%
# 203     -0.427804               99%
# 423     -0.478454               99%
# 71      -0.490514               99%
# 195     -0.490514               99%
# 446     -0.586991               99%
# 204     -0.731706               99%
# 69      -0.731706               99%
# 74      -0.767885               99%
# 196     -0.816123               99%
# 73      -0.876421               99%
# 72      -0.960839               99%
# 450     -1.129673               99%

# %%
#Methode Graphique 
df=VerifPrixChamp
px.histogram(df, x="price",
            marginal='box',     #'rug', 'box', 'violin', or 'histogram'
            hover_data=df.columns ,
            title="Distribution des prix unitaires des bouteilles de Champagne en €")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6cd6a5e3-a77e-47db-890e-09e265edd58a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cd6a5e3-a77e-47db-890e-09e265edd58a")) {                    Plotly.newPlot(                        "6cd6a5e3-a77e-47db-890e-09e265edd58a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[225.0,135.0,126.5,112.0,86.8,85.6,83.0,79.5,79.5,77.0,69.0,62.1,59.0,59.0,53.0,51.6,49.5,49.0,49.0,45.0,39.0,39.0,37.5,35.5,33.0,29.5,22.5],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[15940,"Champagne Egly-Ouriet Grand Cru Mill\u00e9sim\u00e9 2008",5.0,1125.0,1.59,23.98,"outofstock",0.0,4352.0,15940,4352.0,"Prix > 100\u20ac","Champagne","quartile3","IQ_Ouliers_Sup",3.754470913562703,"Inf\u00e9rieur \u00e0 90%"],[14923,"Champagne Gosset C\u00e9l\u00e9bris Vintage 2007",2.0,270.0,0.38,58.81,"instock",10.0,6126.0,14923,6126.0,"Prix > 100\u20ac","Champagne","quartile3","-",1.5837401514800054,"99%"],[12589,"Champagne Egly-Ouriet Grand Cru Blanc de Noirs",11.0,1391.5,1.97,22.38,"instock",2.0,4355.0,12589,4355.0,"Prix > 100\u20ac","Champagne","quartile3","-",1.3787266906166395,"99%"],[13914,"Champagne Agrapart &amp; Fils L'Avizoise Extra Brut Blanc de Blancs Grand Cru 2012",0.0,0.0,0.0,100.0,"outofstock",0.0,5025.0,13914,5025.0,"Prix > 100\u20ac","Champagne","quartile3","-",1.0289978456144273,"99%"],[13913,"Champagne Agrapart &amp; Fils Min\u00e9ral Extra Brut Blanc de Blancs Grand Cru 2012",0.0,0.0,0.0,100.0,"instock",2.0,5026.0,13913,5026.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile3","-",0.4211932322312722,"99%"],[13853,"Champagne Larmandier-Bernier Grand Cru Les Chemins d'Avize 2011",1.0,85.6,0.12,88.6,"outofstock",0.0,4359.0,13853,4359.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile3","-",0.39225015540350283,"99%"],[4679,"Champagne Mailly Grand Cru Les Echansons 2007",0.0,0.0,0.0,100.0,"instock",13.0,4337.0,4679,4337.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile3","-",0.3295401556100029,"99%"],[12588,"Champagne Egly-Ouriet Grand Cru Extra Brut V.P.",0.0,0.0,0.0,100.0,"instock",20.0,4350.0,12588,4350.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",0.24512284819567576,"99%"],[12587,"Champagne Egly-Ouriet Grand Cru Brut Ros\u00e9",3.0,238.5,0.34,63.05,"instock",11.0,4353.0,12587,4353.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",0.24512284819567576,"99%"],[13854,"Champagne Larmandier-Bernier Grand Cru Vieilles Vignes du Levant 2008",0.0,0.0,0.0,100.0,"outofstock",0.0,4358.0,13854,4358.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",0.18482477147115642,"99%"],[7086,"Champagne Mailly Grand Cru Intemporelle Ros\u00e9 2009",0.0,0.0,0.0,100.0,"instock",34.0,4149.0,7086,4149.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",-0.00812907404730553,"99%"],[11997,"Champagne Agrapart &amp; Fils Terroirs Brut Blanc de Blancs Grand Cru",0.0,0.0,0.0,100.0,"outofstock",0.0,5027.0,11997,5027.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",-0.17455176580697893,"99%"],[12586,"Champagne Egly-Ouriet Grand Cru Brut Tradition",0.0,0.0,0.0,100.0,"instock",21.0,4348.0,12586,4348.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",-0.24932138094538295,"99%"],[1366,"Champagne Mailly Grand Cru Intemporelle 2010",1.0,59.0,0.08,92.9,"instock",17.0,4150.0,1366,4150.0,"50\u20ac > Prix < 100\u20ac","Champagne","quartile2","-",-0.24932138094538295,"99%"],[11641,"Champagne Gosset Grand Mill\u00e9sime 2006",30.0,1590.0,2.25,18.2,"instock",8.0,4142.0,11641,4142.0,"50\u20a ...

# %% [markdown]
# Prix à verifier :
#
#
# *   Sku:15940	Champagne Egly-Ouriet Grand Cru Millésimé 2008	225.00€                                                                       - semble cohérent avec les niveaux de prix trouvé sur  [internet](https://www.google.com/search?q=Champagne+Egly-Ouriet+Grand+Cru+Mill%C3%A9sim%C3%A9+2008&rlz=1C1CHBD_frFR933FR933&sxsrf=ALiCzsbhHgjdV0AnhoGhzYdb66m4u7eXsg:1652498957057&source=lnms&tbm=shop&sa=X&ved=2ahUKEwjOzM6qht73AhVegM4BHSNaD9MQ_AUoAXoECAEQAw&biw=2560&bih=880&dpr=1)

# %% [markdown]
# ### Cognac

# %%
df=dfCognac.copy()
df=QartileIndicatorCol(df,"price")

#Z-score  pour Methode Numérique 
df=Zscore(df,"price")
df.sort_values(by='price', ascending=False, inplace=True)
VerifPrixCognac=df

print(pcolors.OK+"Liste des Cognacs"+pcolors.RESET)
VerifPrixCognac
# Out:
# Methode IQ price: Ecart Interquartile=  58.775  -Q1  61.85  -Q2  86.05  -Q3  120.625
# Zscore_price Seuil_ConF_Zscore
# Liste des Cognacs
#        sku                                         post_title  price  \
# 219   3510                               Cognac Frapin VIP XO  176.0
# 222   7819  Cognac Frapin Château de Fontpinot 1989 20 Ans...  157.0
# 220   3507              Cognac Frapin Château de Fontpinot XO  108.5
# 223   3509                          Cognac Frapin Cigar Blend  104.0
# 221  13230          Cognac Frapin Château de Fontpinot XO 1/2   68.1
# 218   3506                                 Cognac Frapin VSOP   62.5
# 622    523                       Cognac Normandin Mercier VFC   59.9
# 217  14768                                 Cognac Frapin 1270   44.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 219         13.0           2288.0                     3.24
# 222          0.0              0.0                     0.00
# 220          2.0            217.0                     0.31
# 223          1.0            104.0                     0.15
# 221          0.0              0.0                     0.00
# 218          1.0             62.5                     0.09
# 622          0.0              0.0                     0.00
# 217          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 219                 15.95      instock             8.0      4402.0   3510
# 222                100.00      instock             3.0      4406.0   7819
# 220                 66.87      instock             2.0      4404.0   3507
# 223                 85.68      instock             6.0      4407.0   3509
# 221                100.00      instock             6.0      4405.0  13230
# 218                 92.13      instock             1.0      4401.0   3506
# 622                100.00      instock             3.0      5932.0    523
# 217                100.00   outofstock             0.0      4400.0  14768
#
#      guid_ID   PrixBouteilleCAT BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 219   4402.0        Prix > 100€       Cognac      quartile3                -
# 222   4406.0        Prix > 100€       Cognac      quartile3                -
# 220   4404.0        Prix > 100€       Cognac      quartile2                -
# 223   4407.0        Prix > 100€       Cognac      quartile2                -
# 221   4405.0  50€ > Prix < 100€       Cognac      quartile2                -
# 218   4401.0  50€ > Prix < 100€       Cognac      quartile2                -
# 622   5932.0  50€ > Prix < 100€       Cognac      quartile1                -
# 217   4400.0  30€ > Prix <= 50€       Cognac      quartile1                -
#
#      Zscore_price Seuil_ConF_Zscore
# 219      1.742771               95%
# 222      1.320954               99%
# 220      0.244210               99%
# 223      0.144306               99%
# 221     -0.652707               99%
# 218     -0.777032               99%
# 622     -0.834754               99%
# 217     -1.187749               99%

# %%
#Methode Graphique 
df=VerifPrixCognac
px.histogram(df, x="price",
            marginal='box',     #'rug', 'box', 'violin', or 'histogram'
            hover_data=df.columns ,
            title="Distribution des prix unitaires des bouteilles de Cognac en €")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="454b7431-6190-4e5c-be30-bf47a10938c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("454b7431-6190-4e5c-be30-bf47a10938c4")) {                    Plotly.newPlot(                        "454b7431-6190-4e5c-be30-bf47a10938c4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[176.0,157.0,108.5,104.0,68.1,62.5,59.9,44.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[3510,"Cognac Frapin VIP XO",13.0,2288.0,3.24,15.95,"instock",8.0,4402.0,3510,4402.0,"Prix > 100\u20ac","Cognac","quartile3","-",1.7427713264674516,"95%"],[7819,"Cognac Frapin Ch\u00e2teau de Fontpinot 1989 20 Ans d'Age",0.0,0.0,0.0,100.0,"instock",3.0,4406.0,7819,4406.0,"Prix > 100\u20ac","Cognac","quartile3","-",1.320954062736476,"99%"],[3507,"Cognac Frapin Ch\u00e2teau de Fontpinot XO",2.0,217.0,0.31,66.87,"instock",2.0,4404.0,3507,4404.0,"Prix > 100\u20ac","Cognac","quartile2","-",0.24420999479161742,"99%"],[3509,"Cognac Frapin Cigar Blend",1.0,104.0,0.15,85.68,"instock",6.0,4407.0,3509,4407.0,"Prix > 100\u20ac","Cognac","quartile2","-",0.14430590601322849,"99%"],[13230,"Cognac Frapin Ch\u00e2teau de Fontpinot XO 1/2",0.0,0.0,0.0,100.0,"instock",6.0,4405.0,13230,4405.0,"50\u20ac > Prix < 100\u20ac","Cognac","quartile2","-",-0.6527067133521413,"99%"],[3506,"Cognac Frapin VSOP",1.0,62.5,0.09,92.13,"instock",1.0,4401.0,3506,4401.0,"50\u20ac > Prix < 100\u20ac","Cognac","quartile2","-",-0.7770318016096918,"99%"],[523,"Cognac Normandin Mercier VFC",0.0,0.0,0.0,100.0,"instock",3.0,5932.0,523,5932.0,"50\u20ac > Prix < 100\u20ac","Cognac","quartile1","-",-0.8347541640149833,"99%"],[14768,"Cognac Frapin 1270",0.0,0.0,0.0,100.0,"outofstock",0.0,4400.0,14768,4400.0,"30\u20ac > Prix <= 50\u20ac","Cognac","quartile1","-",-1.1877486110319575,"99%"]],"hovertemplate":"price=%{x}<br>sku=%{customdata[0]}<br>post_title=%{customdata[1]}<br>total_sales=%{customdata[2]}<br>ChiffreAffaires=%{customdata[3]}<br>ChiffreAffaires_percent=%{customdata[4]}<br>ChiffreAffairescum_p=%{customdata[5]}<br>stock_status=%{customdata[6]}<br>stock_quantity=%{customdata[7]}<br>product_id=%{customdata[8]}<br>id_web=%{customdata[9]}<br>guid_ID=%{customdata[10]}<br>PrixBouteilleCAT=%{customdata[11]}<br>BouteilleCAT=%{customdata[12]}<br>price_Quartile=%{customdata[13]}<br>price_IQ_Ouliers=%{customdata[14]}<br>Zscore_price=%{customdata[15]}<br>Seuil_ConF_Zscore=%{customdata[16]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":true,"offsetgroup":"","showlegend":false,"x":[176.0,157.0,108.5,104.0,68.1,62.5,59.9,44.0],"xaxis":"x2","yaxis":"y2","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %% [markdown]
# Prix à verifier :
#
#  Aucun prix suspect d'un point de vue graphque ou satistique :     Cepandant verifier les prix des Cognacs Frappin car il y a des différences importante de prix entre les différents Cognac ([gamme <50€ ](https://www.google.com/search?rlz=1C1CHBD_frFR933FR933&tbm=shop&sxsrf=ALiCzsbv5hcs-Bqn2rmLJXLuiajM4iUVjQ:1652499892951&q=Cognac+Frapin+VIP+XO&tbs=mr:1,price:1,ppr_max:50,pdtr0:931743%7C2809570&sa=X&ved=0ahUKEwiU3PDoid73AhXExIUKHZ7BBU4QvSsI3QEoAA&biw=2560&bih=880&dpr=1), [50€<gamme <100€ ](https://www.google.com/search?rlz=1C1CHBD_frFR933FR933&tbm=shop&sxsrf=ALiCzsacIShfKy4mvzRjhdJQ2YDuGcvVaw:1652500097832&q=Cognac+Frapin+VIP+XO&tbs=mr:1,price:1,ppr_min:50,ppr_max:100,pdtr0:931743%7C2809570&sa=X&ved=0ahUKEwjrxsnKit73AhXNz4UKHXwuDZoQvSsIdigB&biw=2560&bih=880&dpr=1), [gamme >100€ ](https://www.google.com/search?rlz=1C1CHBD_frFR933FR933&tbm=shop&sxsrf=ALiCzsZjEcIj9mbMFJ-v1UaIlr4YxyrSeQ:1652500178044&q=Cognac+Frapin+VIP+XO&tbs=mr:1,price:1,ppr_min:100,ppr_max:300,pdtr0:931743%7C2809570&sa=X&ved=0ahUKEwipmenwit73AhXNxYUKHTk7AUEQvSsI3wEoAg&biw=2560&bih=880&dpr=1). L'experience d'un expert marché est nécessaire, car les test statistiques effectués ne permetent pas de mettre en évidence deux références dont les prix on été inversés.

# %% [markdown]
# ### Whisky

# %%
df=dfWhisky.copy()
df=QartileIndicatorCol(df,"price")

#Z-score  pour Methode Numérique 
df=Zscore(df,"price")
df.sort_values(by='price', ascending=False, inplace=True)
VerifPrixWhisky=df

print(pcolors.OK+"Liste des Whisky"+pcolors.RESET)
VerifPrixWhisky
# Out:
# Methode IQ price: Ecart Interquartile=  10.075000000000003  -Q1  51.375  -Q2  59.0  -Q3  61.45
# Zscore_price Seuil_ConF_Zscore
# Liste des Whisky
#        sku                                         post_title  price  \
# 617  14775  Wemyss Malts Single Cask Scotch Whisky Choc 'n...  122.0
# 618  14773  Wemyss Malts Single Cask Scotch Whisky Chai Ca...  114.0
# 616  14774  Wemyss Malts Single Cask Scotch Whisky Chocola...   93.0
# 213   9636  Wemyss Malts Blended Malt Scotch Whisky The Hi...   62.0
# 211  13766  Wemyss Malts Blended Malt Scotch Whisky Treacl...   59.8
# 216  12640  Wemyss Malts Blended Malt Scotch Whisky Spice ...   59.0
# 214  12639  Wemyss Malts Blended Malt Scotch Whisky The Hi...   59.0
# 215  12641  Wemyss Malts Blended Malt Scotch Whisky Peat C...   59.0
# 613  15227   Kingsbarns Distillery Lowland Single Malt Whisky   57.0
# 210  13765  Wemyss Malts Blended Malt Scotch Whisky Vanill...   57.0
# 208  11467  Wemyss Malts Blended Malt Scotch Whisky Peat C...   49.5
# 207  11585   Wemyss Malts Blended Malt Scotch Whisky The Hive   49.5
# 209  11586  Wemyss Malts Blended Malt Scotch Whisky Spice ...   49.5
# 212  11587      Wemyss Malts Blended Scotch Whisky Lord Elcho   27.5
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 617          0.0              0.0                     0.00
# 618          0.0              0.0                     0.00
# 616          0.0              0.0                     0.00
# 213          0.0              0.0                     0.00
# 211          0.0              0.0                     0.00
# 216          1.0             59.0                     0.08
# 214          0.0              0.0                     0.00
# 215          0.0              0.0                     0.00
# 613          0.0              0.0                     0.00
# 210          0.0              0.0                     0.00
# 208          0.0              0.0                     0.00
# 207          1.0             49.5                     0.07
# 209          0.0              0.0                     0.00
# 212          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 617                100.00      instock             4.0      5917.0  14775
# 618                100.00      instock             8.0      5918.0  14773
# 616                100.00      instock             3.0      5916.0  14774
# 213                100.00      instock             7.0      4396.0   9636
# 211                100.00   outofstock             0.0      4394.0  13766
# 216                 92.99      instock             6.0      4399.0  12640
# 214                100.00      instock             7.0      4397.0  12639
# 215                100.00   outofstock             0.0      4398.0  12641
# 613                100.00      instock             8.0      5912.0  15227
# 210                100.00      instock             2.0      4393.0  13765
# 208                100.00      instock             7.0      4391.0  11467
# 207                 94.72      instock             6.0      4364.0  11585
# 209                100.00      instock            13.0      4392.0  11586
# 212                100.00      instock             8.0      4395.0  11587
#
#      guid_ID   PrixBouteilleCAT BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 617   5917.0        Prix > 100€       Whisky      quartile3   IQ_Ouliers_Sup
# 618   5918.0        Prix > 100€       Whisky      quartile3   IQ_Ouliers_Sup
# 616   5916.0  50€ > Prix < 100€       Whisky      quartile3   IQ_Ouliers_Sup
# 213   4396.0  50€ > Prix < 100€       Whisky      quartile3                -
# 211   4394.0  50€ > Prix < 100€       Whisky      quartile2                -
# 216   4399.0  50€ > Prix < 100€       Whisky      quartile2                -
# 214   4397.0  50€ > Prix < 100€       Whisky      quartile2                -
# 215   4398.0  50€ > Prix < 100€       Whisky      quartile2                -
# 613   5912.0  50€ > Prix < 100€       Whisky      quartile2                -
# 210   4393.0  50€ > Prix < 100€       Whisky      quartile2                -
# 208   4391.0  30€ > Prix <= 50€       Whisky      quartile1                -
# 207   4364.0  30€ > Prix <= 50€       Whisky      quartile1                -
# 209   4392.0  30€ > Prix <= 50€       Whisky      quartile1                -
# 212   4395.0  10€ > Prix <= 30€       Whisky      quartile1   IQ_Ouliers_Inf
#
#      Zscore_price Seuil_ConF_Zscore
# 617      2.247630               90%
# 618      1.929059               95%
# 616      1.092811               99%
# 213     -0.141650               99%
# 211     -0.229257               99%
# 216     -0.261114               99%
# 214     -0.261114               99%
# 215     -0.261114               99%
# 613     -0.340757               99%
# 210     -0.340757               99%
# 208     -0.639417               99%
# 207     -0.639417               99%
# 209     -0.639417               99%
# 212     -1.515486               99%

# %%
#Methode Graphique 
df=VerifPrixWhisky
px.histogram(df, x="price",
            marginal='box',     #'rug', 'box', 'violin', or 'histogram'
            hover_data=df.columns ,
            title="Distribution des prix unitaires des bouteilles de Whisky en €")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c8bf4286-201d-4ef0-b1a8-457e61282ba1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8bf4286-201d-4ef0-b1a8-457e61282ba1")) {                    Plotly.newPlot(                        "c8bf4286-201d-4ef0-b1a8-457e61282ba1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[122.0,114.0,93.0,62.0,59.8,59.0,59.0,59.0,57.0,57.0,49.5,49.5,49.5,27.5],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[[14775,"Wemyss Malts Single Cask Scotch Whisky Choc 'n' Nut Pretzel 2001 Bunnahabhain",0.0,0.0,0.0,100.0,"instock",4.0,5917.0,14775,5917.0,"Prix > 100\u20ac","Whisky","quartile3","IQ_Ouliers_Sup",2.2476297310856204,"90%"],[14773,"Wemyss Malts Single Cask Scotch Whisky Chai Caramel Latte 2002 Craigellachie",0.0,0.0,0.0,100.0,"instock",8.0,5918.0,14773,5918.0,"Prix > 100\u20ac","Whisky","quartile3","IQ_Ouliers_Sup",1.9290590782362287,"95%"],[14774,"Wemyss Malts Single Cask Scotch Whisky Chocolate Moka Cake 2005 Strathclyde",0.0,0.0,0.0,100.0,"instock",3.0,5916.0,14774,5916.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile3","IQ_Ouliers_Sup",1.0928111145065749,"99%"],[9636,"Wemyss Malts Blended Malt Scotch Whisky The Hive 12 ans",0.0,0.0,0.0,100.0,"instock",7.0,4396.0,9636,4396.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile3","-",-0.1416501652848186,"99%"],[13766,"Wemyss Malts Blended Malt Scotch Whisky Treacle Chest",0.0,0.0,0.0,100.0,"outofstock",0.0,4394.0,13766,4394.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile2","-",-0.22925709481840148,"99%"],[12640,"Wemyss Malts Blended Malt Scotch Whisky Spice King Batch Strength",1.0,59.0,0.08,92.99,"instock",6.0,4399.0,12640,4399.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile2","-",-0.26111416010334054,"99%"],[12639,"Wemyss Malts Blended Malt Scotch Whisky The Hive Batch Strength",0.0,0.0,0.0,100.0,"instock",7.0,4397.0,12639,4397.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile2","-",-0.26111416010334054,"99%"],[12641,"Wemyss Malts Blended Malt Scotch Whisky Peat Chimney Batch Strength",0.0,0.0,0.0,100.0,"outofstock",0.0,4398.0,12641,4398.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile2","-",-0.26111416010334054,"99%"],[15227,"Kingsbarns Distillery Lowland Single Malt Whisky",0.0,0.0,0.0,100.0,"instock",8.0,5912.0,15227,5912.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile2","-",-0.3407568233156885,"99%"],[13765,"Wemyss Malts Blended Malt Scotch Whisky Vanilla Burst",0.0,0.0,0.0,100.0,"instock",2.0,4393.0,13765,4393.0,"50\u20ac > Prix < 100\u20ac","Whisky","quartile2","-",-0.3407568233156885,"99%"],[11467,"Wemyss Malts Blended Malt Scotch Whisky Peat Chimney",0.0,0.0,0.0,100.0,"instock",7.0,4391.0,11467,4391.0,"30\u20ac > Prix <= 50\u20ac","Whisky","quartile1","-",-0.6394168103619934,"99%"],[11585,"Wemyss Malts Blended Malt Scotch Whisky The Hive",1.0,49.5,0.07,94.72,"instock",6.0,4364.0,11585,4364.0,"30\u20ac > Prix <= 50\u20ac","Whisky","quartile1","-",-0.6394168103619934,"99%"],[11586,"Wemyss Malts Blended Malt Scotch Whisky Spice King",0.0,0.0,0.0,100.0,"instock",13.0,4392.0,11586,4392.0,"30\u20ac > Prix <= 50\u20ac","Whisky","quartile1","-",-0.6394168103619934,"99%"],[11587,"Wemyss Malts Blended Scotch Whisky Lord Elcho",0.0,0.0,0.0,100.0,"instock",8.0,4395.0,11587,4395.0,"10\u20ac > Prix <= 30\u20ac","Whisky","quartile1","IQ_Ouliers_Inf",-1.515486105697821,"99%"]],"hovertemplate":"price=%{x}<br>sku=%{customdata[0]}<br>post_title=%{customdata[1]}<br>total_sales=%{customdata[2]}<br>ChiffreAffaires=%{customdata[3]}<br>ChiffreAffaires_percent= ...

# %% [markdown]
# Le nombre de Wisky est trop faible pour avoir des données fiable d'un point de vue satistique, en effet les outliers potentiels identifiés semblent cohérents avec les prix sur [internet](https://www.google.com/search?rlz=1C1CHBD_frFR933FR933&tbm=shop&sxsrf=ALiCzsaCGpSC_kbbEtXfG5e4fodeGQTyvg:1652501574533&q=Wemyss+Malts+Blended+Scotch+Whisky+Lord+Elcho&tbs=mr:1&sa=X&ved=0ahUKEwifpNyKkN73AhURExoKHdF5CQkQvSsI1gEoAA&biw=2560&bih=880&dpr=1) des wisky de la gamme Wemyss Malts qui pert de 20€ à plus de 500€  donc seul un expert métier pour détecter si les pricx de deux références on été intervertis.

# %% [markdown]
# ### Vins (catégorie autre)

# %%
df=dfAutre.copy()
df=QartileIndicatorCol(df,"price")

#Z-score  pour Methode Numérique 
df=Zscore(df,"price")
df.sort_values(by='price', ascending=False, inplace=True)
VerifPrixAutre=df
VerifPrixAutre
# Out:
# Methode IQ price: Ecart Interquartile=  24.9  -Q1  13.5  -Q2  21.9  -Q3  38.4
# Zscore_price Seuil_ConF_Zscore
#        sku                                         post_title  price  \
# 434  14581     David Duband Charmes-Chambertin Grand Cru 2014  217.5
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 566  15185                Camille Giroud Clos de Vougeot 2016  175.0
# 387  14220  Domaine Des Croix Corton Charlemagne Grand Cru...  137.0
# 524  14915  Domaine Weinbach Gewurztraminer Grand Cru Furs...  124.8
# ..     ...                                                ...    ...
# 98   16211             Maurel Pays d'Oc Chenin-Colombard 2019    5.7
# 99   16209                     Maurel Cabardès Tradition 2017    5.7
# 664  14570  Moulin de Gassac IGP Pays d'Hérault Guilhem Bl...    5.2
# 734   5070         Pierre Jean Villa Côte Rôtie Fongeant 2017    0.0
# 735   5075    Pierre Jean Villa Condrieu Jardin Suspendu 2018    0.0
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 434          0.0              0.0                     0.00
# 601          3.0            573.9                     0.81
# 566          0.0              0.0                     0.00
# 387          5.0            685.0                     0.97
# 524          0.0              0.0                     0.00
# ..           ...              ...                      ...
# 98          13.0             74.1                     0.11
# 99           6.0             34.2                     0.05
# 664          0.0              0.0                     0.00
# 734          0.0              0.0                     0.00
# 735          0.0              0.0                     0.00
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 434                100.00      instock            20.0      5001.0  14581
# 601                 45.02      instock            10.0      5892.0  14983
# 566                100.00      instock            12.0      5767.0  15185
# 387                 40.77      instock            13.0      4904.0  14220
# 524                100.00      instock            12.0      5612.0  14915
# ..                    ...          ...             ...         ...    ...
# 98                  90.72      instock           100.0      4173.0  16211
# 99                  97.76      instock            94.0      4174.0  16209
# 664                100.00      instock            30.0      6129.0  14570
# 734                100.00            0             0.0         0.0      0
# 735                100.00            0             0.0         0.0      0
#
#      guid_ID PrixBouteilleCAT   BouteilleCAT price_Quartile price_IQ_Ouliers  \
# 434   5001.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 601   5892.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 566   5767.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 387   4904.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# 524   5612.0      Prix > 100€  Autres (vins)      quartile3   IQ_Ouliers_Sup
# ..       ...              ...            ...            ...              ...
# 98    4173.0      Prix <= 10€  Autres (vins)      quartile1                -
# 99    4174.0      Prix <= 10€  Autres (vins)      quartile1                -
# 664   6129.0      Prix <= 10€  Autres (vins)      quartile1                -
# 734   5070.0      Prix <= 10€  Autres (vins)      quartile1                -
# 735   5075.0      Prix <= 10€  Autres (vins)      quartile1                -
#
#      Zscore_price Seuil_ConF_Zscore
# 434      7.776946   Inférieur à 90%
# 601      6.693538   Inférieur à 90%
# 566      6.019509   Inférieur à 90%
# 387      4.448153   Inférieur à 90%
# 524      3.943665   Inférieur à 90%
# ..            ...               ...
# 98      -0.981295               99%
# 99      -0.981295               99%
# 664     -1.001970               99%
# 734     -1.216998               99%
# 735     -1.216998               99%
#
# [667 rows x 18 columns]

# %%
#Methode Graphique 
df=VerifPrixAutre
px.histogram(df, x="price",
            marginal='box',     #'rug', 'box', 'violin', or 'histogram'
            hover_data=df.columns ,
            title="Distribution des prix unitaires des bouteilles de vins (autre) en €")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3371e6bc-459a-464c-a936-a9faba86399d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3371e6bc-459a-464c-a936-a9faba86399d")) {                    Plotly.newPlot(                        "3371e6bc-459a-464c-a936-a9faba86399d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[217.5,191.3,175.0,137.0,124.8,121.0,121.0,116.4,115.0,115.0,109.6,105.6,105.0,105.0,102.3,100.0,99.0,92.0,88.4,83.7,80.0,79.8,78.0,78.0,78.0,78.0,78.0,77.8,77.4,76.8,74.8,74.5,73.3,72.0,71.7,71.6,71.5,71.3,71.3,69.8,69.0,69.0,68.3,67.5,67.2,67.0,65.9,65.0,64.9,63.5,63.5,63.4,62.4,62.4,62.4,61.6,61.6,60.4,60.0,60.0,59.9,59.9,59.6,59.6,59.4,59.0,58.8,58.3,58.0,58.0,57.7,57.6,57.6,57.0,57.0,57.0,56.4,56.3,56.0,55.6,55.4,55.0,54.8,54.8,53.2,52.9,52.7,52.6,52.4,52.4,52.4,51.0,50.5,50.4,50.1,50.0,50.0,49.9,49.5,49.5,49.0,49.0,48.8,48.8,48.7,48.7,48.5,48.5,48.5,48.5,48.4,47.2,46.5,46.5,46.5,46.0,46.0,46.0,46.0,46.0,45.9,45.0,44.6,44.5,44.3,44.0,44.0,44.0,44.0,43.9,43.9,43.5,43.5,43.0,43.0,42.6,42.2,42.2,42.1,42.0,42.0,41.8,41.8,41.8,41.6,41.2,41.0,41.0,41.0,40.7,40.5,40.2,40.2,40.2,40.0,39.8,39.6,39.2,39.1,39.0,39.0,38.6,38.6,38.6,38.6,38.5,38.4,38.4,38.0,38.0,38.0,37.7,37.2,37.0,36.9,36.3,36.2,36.0,36.0,35.6,35.6,35.6,35.3,35.2,35.1,35.0,34.8,34.7,34.4,34.3,34.3,34.3,33.7,33.6,33.4,33.4,33.2,33.2,33.2,32.8,32.8,32.7,32.6,32.2,32.2,32.1,32.0,31.7,31.7,31.7,31.6,31.5,31.5,31.2,31.0,30.8,30.6,30.5,30.1,30.0,30.0,29.9,29.9,29.8,29.8,29.8,29.7,29.5,29.5,29.4,29.2,29.0,29.0,29.0,28.8,28.5,28.5,28.5,28.4,28.4,28.1,28.1,28.0,28.0,28.0,28.0,27.9,27.9,27.9,27.9,27.9,27.8,27.8,27.7,27.5,27.5,27.3,27.3,27.3,27.2,27.0,26.9,26.7,26.7,26.6,26.5,26.5,26.5,26.5,26.5,26.4,26.2,26.0,25.9,25.9,25.9,25.9,25.7,25.7,25.3,25.3,25.2,25.2,25.0,25.0,25.0,25.0,24.8,24.7,24.6,24.5,24.5,24.4,24.4,24.4,24.4,24.3,24.3,24.2,24.2,24.0,24.0,24.0,24.0,24.0,24.0,23.8,23.7,23.6,23.5,23.4,23.4,23.4,23.2,23.2,23.2,23.0,23.0,23.0,23.0,22.9,22.9,22.8,22.8,22.8,22.8,22.8,22.4,22.4,22.2,22.1,22.0,22.0,21.9,21.8,21.8,21.8,21.7,21.7,21.6,21.5,21.4,21.2,21.0,21.0,20.8,20.8,20.8,20.8,20.6,20.5,20.5,20.4,20.4,20.35,20.2,20.2,20.1,19.8,19.8,19.8,19.8,19.8,19.8,19.5,19.5,19.5,19.5,19.3,19.3,19.2,19.2,19.2,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,19.0,18.9,18.8,18.7,18.7,18.6,18.5,18.5,18.4,18.4,18.3,18.25,18.2,18.2,18.2,18.2,18.1,18.0,18.0,17.9,17.9,17.9,17.8,17.8,17.8,17.7,17.6,17.5,17.5,17.5,17.4,17.3,17.2,17.2,17.2,17.1,17.1,17.1,17.1,17.0,17.0,17.0,16.9,16.9,16.9,16.9,16.9,16.8,16.8,16.7,16.7,16.7,16.6,16.6,16.6,16.6,16.5,16.5,16.45,16.4,16.4,16.4,16.3,16.3,16.3,16.3,16.3,16.3,16.2,16.1,16.1,15.9,15.8,15.8,15.8,15.8,15.8,15.5,15.5,15.4,15.4,15.4,15.4,15.3,15.3,15.2,15.2,15.2,14.9,14.9,14.9,14.8,14.7,14.6,14.5,14.5,14.5,14.4,14.4,14.4,14.3,14.3,14.3,14.1,14.1,14.1,14.05,14.0,13.9,13.8,13.7,13.7,13.7,13.7,13.7,13.6,13.6,13.5,13.5,13.5,13.5,13.5,13.5,13.5,13.4,13.4,13.4,13.3,13.3,13.2,13.2,13.1,13.1,13.0,12.9,12.9,12.9,12.9,12.9,12.8,12.8,12.8,12.8,12.8,12.8,12.7,12.7,12.7,12.7,12.7,12.7,12.6,12.6,12.6,12.6,12.5,12.5,12.5,12.3,12.3,12.2,12.1,12.1,12.1,12.0,12.0,12.0,12.0,12.0,11.9,11.9,11.9,11.9,11.9,11.8,11.6,11.6,11.6,11.5,11.5,11.3,11.3,11.1,11.1,11.1,11.1,11.1,11.1,11.1,11.0,10.9,10.9,10.8,10.8,10.8,10.7,10.7,10.7,10.7,10.6,10.6,10.4,10.4,10.3,10.3,10.2,10.2,10.1,10.1,9.9,9.9,9.9,9.9,9.9,9.9,9.8,9.8,9.8,9.7,9.7,9.7,9.6,9.6,9.5,9.5,9.4,9.3,9.3,9.3,9.3,9.3,9.3,9.2,9.1,9.1,9.0,9.0,8.9,8.9,8.9,8.7,8.7,8.7,8.7,8.7,8.6,8.6,8.5,8.5,8.4,8.2,8.1,7.9,7.9,7.8,7.8,7.7,7.6,7.6,7.5,7.4,7.4,7.2,7.1,7.1,7.1,7.0,7.0,6.8,6.8,6.7 ...

# %%
# restreindre la liste au produits qui ont été vendus (exclusion des produits non vendus)
VerifPrixAutre.query("price>=78.8 | price<=7.4 ").query("ChiffreAffaires>0")
# VerifPrixAutre.query("price>=78.8")
# Out:
#        sku                                         post_title  price  \
# 601  14983  Coteaux Champenois Egly-Ouriet Ambonnay Rouge ...  191.3
# 387  14220  Domaine Des Croix Corton Charlemagne Grand Cru...  137.0
# 672  13996  Domaine des Comtes Lafon Volnay 1er Cru Santen...  115.0
# 10   15269       Pierre Gaillard Côte Rôtie Rose Pourpre 2017   80.0
# 551  15026  Domaine de l'Hortus Pays de l'Hérault Le Loup ...    7.1
# 296  15933  Domaine de Joy Côtes de Gascogne Blanc Moelleu...    7.1
# 422  16586               Château Turcaud Entre-Deux-Mers 2019    7.1
# 420  15958                Château Turcaud Bordeaux Rouge 2016    7.0
# 401  15928  Cave de Castelmaure Corbières Rouge Vigneron 2018    7.0
# 344  14302  Château de La Liquière Pays d'Hérault Blanc A ...    6.8
# 59   16504        Emile Boeckel Sylvaner Vieilles Vignes 2019    6.8
# 125  16023       Domaine Montrose Côtes de Thongue Rouge 2018    6.7
# 363  16342                 Château Turcaud Bordeaux Rosé 2019    6.5
# 405  15425  Domaine La Croix Belle Côtes de Thongue Rouge ...    6.5
# 538  16304    Philippe Nusswitz IGP Cévènnes Rosé O Pale 2019    6.5
# 295  15934  Domaine de Joy Côtes de Gascogne Envie de Joy ...    6.3
# 119  16295  Moulin de Gassac IGP Pays d'Hérault Guilhem Ro...    5.8
# 575  16213                        Maurel Pays d'Oc Syrah 2019    5.8
# 574  15561                       Maurel Pays d'Oc Merlot 2018    5.8
# 97   16210                   Maurel Pays d'Oc Chardonnay 2019    5.7
# 98   16211             Maurel Pays d'Oc Chenin-Colombard 2019    5.7
# 99   16209                     Maurel Cabardès Tradition 2017    5.7
#
#      total_sales  ChiffreAffaires  ChiffreAffaires_percent  \
# 601          3.0            573.9                     0.81
# 387          5.0            685.0                     0.97
# 672          2.0            230.0                     0.33
# 10           6.0            480.0                     0.68
# 551         19.0            134.9                     0.19
# 296         12.0             85.2                     0.12
# 422         26.0            184.6                     0.26
# 420          2.0             14.0                     0.02
# 401         10.0             70.0                     0.10
# 344          7.0             47.6                     0.07
# 59           5.0             34.0                     0.05
# 125          5.0             33.5                     0.05
# 363          1.0              6.5                     0.01
# 405          4.0             26.0                     0.04
# 538         14.0             91.0                     0.13
# 295          2.0             12.6                     0.02
# 119         46.0            266.8                     0.38
# 575          8.0             46.4                     0.07
# 574         24.0            139.2                     0.20
# 97          43.0            245.1                     0.35
# 98          13.0             74.1                     0.11
# 99           6.0             34.2                     0.05
#
#      ChiffreAffairescum_p stock_status  stock_quantity  product_id id_web  \
# 601                 45.02      instock            10.0      5892.0  14983
# 387                 40.77      instock            13.0      4904.0  14220
# 672                 64.37      instock             2.0      6212.0  13996
# 10                  48.70   outofstock             0.0      4046.0  15269
# 551                 79.29      instock           118.0      5722.0  15026
# 296                 88.72      instock           178.0      4681.0  15933
# 422                 69.96      instock           203.0      4965.0  16586
# 420                 99.66      instock           289.0      4963.0  15958
# 401                 91.02      instock           143.0      4923.0  15928
# 344                 95.20      instock            11.0      4776.0  14302
# 59                  97.85      instock            42.0      4105.0  16504
# 125                 97.95      instock           195.0      4207.0  16023
# 363                100.00      instock           257.0      4858.0  16342
# 405                 98.83   outofstock             0.0      4927.0  15425
# 538                 87.73      instock           123.0      5695.0  16304
# 295                 99.77      instock            34.0      4680.0  15934
# 119                 59.19      instock           190.0      4200.0  16295
# 575                 95.33      instock           211.0      5779.0  16213
# 574                 78.51      instock            36.0      5778.0  15561
# 97                  61.69      instock           167.0      4172.0  16210
# 98                  90.72      instock           100.0      4173.0  16211
# 99                  97.76      instock            94.0      4174.0  16209
#
#      guid_ID   PrixBouteilleCAT   BouteilleCAT price_Quartile  \
# 601   5892.0        Prix > 100€  Autres (vins)      quartile3
# 387   4904.0        Prix > 100€  Autres (vins)      quartile3
# 672   6212.0        Prix > 100€  Autres (vins)      quartile3
# 10    4046.0  50€ > Prix < 100€  Autres (vins)      quartile3
# 551   5722.0        Prix <= 10€  Autres (vins)      quartile1
# 296   4681.0        Prix <= 10€  Autres (vins)      quartile1
# 422   4965.0        Prix <= 10€  Autres (vins)      quartile1
# 420   4963.0        Prix <= 10€  Autres (vins)      quartile1
# 401   4923.0        Prix <= 10€  Autres (vins)      quartile1
# 344   4776.0        Prix <= 10€  Autres (vins)      quartile1
# 59    4105.0        Prix <= 10€  Autres (vins)      quartile1
# 125   4207.0        Prix <= 10€  Autres (vins)      quartile1
# 363   4858.0        Prix <= 10€  Autres (vins)      quartile1
# 405   4927.0        Prix <= 10€  Autres (vins)      quartile1
# 538   5695.0        Prix <= 10€  Autres (vins)      quartile1
# 295   4680.0        Prix <= 10€  Autres (vins)      quartile1
# 119   4200.0        Prix <= 10€  Autres (vins)      quartile1
# 575   5779.0        Prix <= 10€  Autres (vins)      quartile1
# 574   5778.0        Prix <= 10€  Autres (vins)      quartile1
# 97    4172.0        Prix <= 10€  Autres (vins)      quartile1
# 98    4173.0        Prix <= 10€  Autres (vins)      quartile1
# 99    4174.0        Prix <= 10€  Autres (vins)      quartile1
#
#     price_IQ_Ouliers  Zscore_price Seuil_ConF_Zscore
# 601   IQ_Ouliers_Sup      6.693538   Inférieur à 90%
# 387   IQ_Ouliers_Sup      4.448153   Inférieur à 90%
# 672   IQ_Ouliers_Sup      3.538421   Inférieur à 90%
# 10    IQ_Ouliers_Sup      2.091120               90%
# 551                -     -0.923402               99%
# 296                -     -0.923402               99%
# 422                -     -0.923402               99%
# 420                -     -0.927538               99%
# 401                -     -0.927538               99%
# 344                -     -0.935808               99%
# 59                 -     -0.935808               99%
# 125                -     -0.939943               99%
# 363                -     -0.948213               99%
# 405                -     -0.948213               99%
# 538                -     -0.948213               99%
# 295                -     -0.956484               99%
# 119                -     -0.977159               99%
# 575                -     -0.977159               99%
# 574                -     -0.977159               99%
# 97                 -     -0.981295               99%
# 98                 -     -0.981295               99%
# 99                 -     -0.981295               99%

# %% [markdown]
# Les prix sur intenet semblent cohérent, seul un expert métier pourra confimer le prix de la liste de références ci-dessus.

# %% [markdown]
# #  <a id="ListeQuestionsOC"> Listes des Questions OC ❓</a>

# %% [markdown]
# 1. Premièrement, j’ai besoin que tu rapproches deux exports : un export de l’ERP contenant les références produit, leur prix de vente et leur état de stock, et un export d’une table de l’outil de CMS contenant les informations des produits commercialisés en ligne (nom, description, nombre de ventes...)
# 2. Deuxièmement, une fois le rapprochement effectué, je souhaiterais avoir le chiffre d’affaires par produit, ainsi que le total du chiffre d’affaires réalisé en ligne.
# 3. Troisièmement et pour finir, je me demande s’il n’y a pas eu des erreurs de saisie dans certains prix des produits. J'aimerais que tu effectues une analyse sur cette variable afin de détecter d’éventuelles valeurs aberrantes, de les lister et d’en faire une représentation graphique pour plus de lisibilité.
# 4. Comme promis, voici en pièce jointe le fichier Excel qui liste les product_id de l’ERP avec leur référence côté Web. La liste des product_id est exhaustive, mais pour les références côté Web, j’en suis moins sûre... J’ai peiné à rapprocher certaines références.
#
# Je suis désolée, mais je me rends compte à l’instant que j’ai également mal nommé la colonne dans le fichier Excel. En fait, la colonne id_web dans mon fichier correspond au SKU des produits dans la boutique en ligne.
#
# 1
#
#  <A name="Q1-2"> (Q1)  </a>
#  [#Consolidation des deux exports (erp & web)](#Q1-1)    [#Q1-2](#Q1-2)

# %% [markdown]
# # WordCloud

# %%
Global.query("post_title != 0").post_title.values
# Out:
# array(['Pierre Jean Villa Condrieu Jardin Suspendu 2018',
#        'Pierre Jean Villa Côte Rôtie Fongeant 2017',
#        "Moulin de Gassac IGP Pays d'Hérault Guilhem Blanc 2017",
#        "Maurel Pays d'Oc Cabernet-Sauvignon 2017",
#        'Maurel Cabardès Tradition 2017',
#        "Maurel Pays d'Oc Chenin-Colombard 2019",
#        "Maurel Pays d'Oc Chardonnay 2019",
#        "Moulin de Gassac IGP Pays d'Hérault Guilhem Rouge 2019",
#        "Maurel Pays d'Oc Syrah 2019", "Maurel Pays d'Oc Merlot 2018",
#        "Moulin de Gassac IGP Pays d'Hérault Guilhem Rosé 2019",
#        'Domaine de Joy Côtes de Gascogne Envie de Joy 2018',
#        'Château Turcaud Bordeaux Rosé 2019',
#        'Philippe Nusswitz IGP Cévènnes Rosé O Pale 2019',
#        'Domaine La Croix Belle Côtes de Thongue Rouge La Caringole 2018',
#        'Domaine Montrose Côtes de Thongue Rouge 2018',
#        'Emile Boeckel Sylvaner Vieilles Vignes 2019',
#        "Château de La Liquière Pays d'Hérault Blanc A Mi Chemin 2017",
#        'Château Turcaud Bordeaux Rouge 2016',
#        'Cave de Castelmaure Corbières Rouge Vigneron 2018',
#        "Domaine de l'Hortus Pays de l'Hérault Le Loup Dans La Bergerie 2018",
#        'Domaine de Joy Côtes de Gascogne Blanc Moelleux Saint-André 2018',
#        'Château Turcaud Entre-Deux-Mers 2019',
#        'Parcé Frères Côtes du Roussillon Villages Hommage à Fernand 2017',
#        'Domaine de Montgilet Vin de France Grolleau 2019',
#        'Jean-Paul Brun Beaujolais Le Ronsay 2016',
#        'Domaine de Montgilet Anjou Rouge 2016',
#        'Parés Baltà Penedès Mas Petit 2015',
#        'Domaine Montrose Côtes de Thongue Rosé 2019',
#        'Jeanne Gaillard IGP Collines Rhodaniennes Syrah Terre de Mandrin 2018',
#        'Le Hameau Des Ollieux Monsieur Pinot 2017',
#        'Clos du Mont-Olivet Vin de France La Sabonite',
#        'Domaine La Croix Belle Côtes de Thongue Rouge Le Champ du Coq 2016',
#        'Domaine La Croix Belle Côtes de Thongue Blanc Champ des Lys 2018',
#        "Domaine de l'Idylle Savoie Cruet 2018",
#        'Château Ollieux Romanis Corbières Rosé Classique 2019',
#        "Mouthes Le Bihan Côtes de Duras L'Aimé Chai 2015",
#        "Philippe Nusswitz Duché d'Uzès Orénia Rouge 2017",
#        'Domaine La Croix Belle Côtes de Thongue Rosé Les Grillons 2019',
#        'Emile Boeckel Crémant Brut Blanc de Blancs',
#        'Parcé Frères Côtes du Roussillon Villages Zoé Rouge 2018',
#        'Mourgues du Grès Costières de Nîmes Galets Rosés 2019',
#        'Mourgues du Grès Costières de Nîmes Galets Rouges 2019',
#        'Domaine Labranche Laffont Madiran Tradition 2016',
#        'Mourgues du Grès Costières de Nîmes Galets Dorés 2019',
#        "Philippe Nusswitz Duché d'Uzès Orénia Rosé 2019",
#        "Parcé Frères IGP Pays d'Oc Zoé Viognier 2019",
#        'Parcé Frères IGP Côtes Catalanes Hommage à Fernand Blanc 2019',
#        'Xavier Frissant Touraine Amboise M de La Touche 2016',
#        'Ollieux Romanis Corbières Classique 2018',
#        "Borie de Maurel Minervois Rouge Esprit d'Automne 2019",
#        'Château Plaisance Fronton Rosé 2019',
#        'Château Plaisance Fronton Rouge 2017',
#        'Domaine Sérol Côte Roannaise Rosé Cabochard 2016',
#        "Borie La Vitarèle Pays d'Hérault Les Cigales 2019",
#        'Château de La Liquière Faugères Les Amandiers Rouge 2019',
#        'Triennes IGP Méditerranée Rosé 2019',
#        'Château Tour Des Gendres Bergerac Blanc Cuvée Des Conti 2017',
#        'Planeta Sicilia La Segreta Bianco 2017',
#        'Planeta Sicilia La Segreta Rosso 2017',
#        'Château de La Liquière Faugères Les Amandiers Rosé 2019',
#        'Château de La Liquière Languedoc Blanc Les Amandiers 2019',
#        'Domaine Rotier Gaillac Rouge Les Gravels 2016',
#        "Mérieau Touraine L'Arpent des Vaudons 2018",
#        'Domaine Bulliat Beaujolais Villages Bibine 2018',
#        'Xavier Frissant Touraine Sauvignon 2019',
#        "Jean-Paul Brun Beaujolais L'Ancien 2016",
#        'Emile Boeckel Riesling Brandluft 2018',
#        'Paul Ginglinger Pinot Blanc 2017',
#        'Elian Daros Côtes du Marmandais Le Vin Est Une Fête 2017',
#        'Mourgues du Grès Costières de Nîmes Capitelles Rosé 2018',
#        'Domaine Rouge Garance Côtes du Rhône Feuille de Garance 2019',
#        "Mas Laval IGP Pays d'Hérault Les Pampres Blancs 2018",
#        'Clos du Mont-Olivet Vins de Pays du Gard Rive Droite 2018',
#        "Philippe Nusswitz Duché d'Uzès Orénia Blanc 2018",
#        'Chermette Domaine du Vissoux Beaujolais Griottes 2018',
#        "Château De La Selve IGP Coteaux de l'Ardèche Maguelonne Rosé 2019",
#        'Maurice Schoech Pinot Auxerrois Vieilles Vignes 2018',
#        'Château de la Selve Vin de France Petite Selve 2019',
#        'Domaine Sérol Côte Roannaise Les Originelles 2019',
#        'Domaine Bulliat Beaujolais Blanc 2019',
#        'Parés Baltà Cava Brut Nature',
#        "Domaine des Terres d'Ocre Saint-Pourçain Blanc Instant T 2018",
#        'Domaine Bulliat Chiroubles Cuvée Félix 2019',
#        'Borie de Maurel Minervois Blanc La Belle Aude 2018',
#        "Moulin de Gassac IGP Pays d'Hérault Rouge Mazet du Levant 2017",
#        "Moulin de Gassac IGP Pays d'Hérault Blanc Faune 2017",
#        'Triennes IGP Méditerranée Rouge Merlot 2016',
#        "Domaine de l'Idylle Roussette de Savoie Anne de Chypre 2018",
#        'Chili Valdivieso Merlot 2017',
#        'Domaine Rotier Gaillac Blanc Sec Renaissance 2015',
#        'Parés Baltà Penedès Calcari 2018',
#        "Domaine des Terres d'Ocre Saint-Pourçain Rouge Instant T 2015",
#        'Château de La Liquière Faugères 2017',
#        "Château de La Liquière Faugères L'Ampoule 2019",
#        "Domaine de l'Idylle Savoie Mondeuse Le Tithonien 2018",
#        'Triennes IGP Méditerranée Rouge Les Auréliens 2016',
#        'Domaine Rouge Garance Côtes du Rhône Blanc De Garance 2018',
#        'Argentine Mendoza Alamos Malbec 2018',
#        'Domaine Schoenheitz Pinot Blanc Val Saint Grégoire 2017',
#        'Maurice Schoech Pinot Noir 2018', 'Maurice Schoech Riesling 2018',
#        'Argentine Mendoza Alamos Torrontes 2017',
#        'Argentine Mendoza Alamos Chardonnay 2019',
#        "Mas Laval IGP Pays d'Hérault Les Pampres Rouges 2017",
#        'Château Turcaud Bordeaux Blanc Cuvée Majeure 2018',
#        'Domaine Bulliat Moulin-à-Vent 2017',
#        "Domaine de l'Hortus Pic Saint-Loup La Bergerie Rosé 2019",
#        'Xavier Frissant Touraine Amboise Chenin Les Pierres 2018',
#        'Château de Cazeneuve Val de Montferrand Rouge Caza Sorix 2019',
#        'Planeta Sicilia Plumbago 2017',
#        'François Bergeret Hautes Côtes de Beaune Rouge 2017',
#        "Mourgues du Grès IGP Pont du Gard Terre d'Argence 2018",
#        'Bernard Baudry Chinon Rouge Les Granges 2018',
#        'Domaine de Montgilet Anjou Blanc 2016',
#        'Borie La Vitarèle Saint-Chinian Les Terres Blanches 2019',
#        "Mourgues du Grès Costières de Nîmes Terre d'Argence 2017",
#        'Emile Boeckel Crémant Brut Rosé',
#        "Domaine de Montgilet Coteaux de l'Aubance 2017",
#        'Planeta Sicilia Alastro 2017',
#        'Parés Baltà Penedès Indigena 2017',
#        'Domaine Chambeyron Vin de Pays des Collines Rhodaniennes Viognier 2016',
#        'Maurice Schoech Gewurztraminer 2018',
#        'Château Turcaud Bordeaux Rouge Cuvée Majeure 2018',
#        "Le Pas de l'Escalette Coteaux du Languedoc Ze Rozé 2019",
#        'Chermette Domaine du Vissoux Beaujolais Blanc Collonge 2017',
#        "Xavier Frissant Touraine Amboise L'Orée des Frênes 2015",
#        'Maurice Schoech Pinot Gris 2018',
#        'Domaine Schoenheitz Pinot Noir Tradition 2019',
#        'Château Saransot-Dupré Bordeaux Blanc 2016',
#        'Domaine Rouge Garance Côtes du Rhône Villages Garances 2016',
#        'La Cotelleraie Saint-Nicolas-de-Bourgueil La Croisée 2018',
#        'Emile Boeckel Pinot Noir Barriques Oberpfoeller 2018',
#        'Paul Ginglinger Muscat Caroline 2018',
#        'Château de Villeneuve Saumur-Champigny 2017',
#        "Philippe Nusswitz Duché d'Uzès Orénia Rouge Réserve 2016",
#        'Domaine de la Jérôme Côtes du Rhône Village 201',
#        'François Baur Pinot Noir Schlittweg 2017',
#        'Domaine Labranche Laffont Pacherenc du Vic-Bilh Sec 2017',
#        'Chili Errazuriz Cabernet Sauvignon 2016',
#        'Clos du Mont-Olivet Côtes-du-Rhône Vieilles Vignes 2018',
#        'Cave de Castelmaure Corbières Rouge Grande Cuvée 2017',
#        'Paul Ginglinger Pinot Gris Les Prelats 2018',
#        'Domaine Plageoles Côtes du Tarn Blanc Sec Ondenc',
#        'Xavier Frissant Touraine Les Roses du Clos 2018',
#        'Domaine Plageoles Vin de France Contre-Pied 2016',
#        'Paul Ginglinger Riesling Drei Exa 2018',
#        'Domaine Chambeyron Côtes du Rhône 2017',
#        'Domaine Rotier Gaillac Blanc Doux Les Gravels 2016',
#        'Parcé Frères Collioure Rouge Petit Gus 2018',
#        'Oratoire Saint Martin Cairanne Blanc Réserve des Seigneurs 2018',
#        'Domaine Sérol Vin Mousseux Rosé Turbullent Méthode Ancestrale',
#        "Philippe Nusswitz Duché d'Uzès Orénia Blanc Réserve 2018",
#        "Huile d'Olive Extra Vierge Planeta 50cl",
#        'François Bergeret Hautes Côtes de Beaune Blanc 2018',
#        'Domaine Rotier Gaillac Rouge Renaissance 2016',
#        'La Préceptorie Maury Sec Rouge Copain Comme Cochon 2018',
#        "Le Pas de l'Escalette Languedoc Les Petits Pas 2019",
#        'Domaine Schoenheitz Muscat 2017',
#        'Château de Villeneuve Saumur-Champigny Clos de la Bienboire 2018',
#        "Domaine de l'Ecu Muscadet Classic 2018",
#        'François Bergeret Hautes Côtes de Beaune Vieilles Vignes Rondo 2017',
#        "Domaine de l'Hortus Val de Montferrand La Bergerie Blanc 2018",
#        'La Préceptorie Côtes du Roussillon Coume Marie 2018',
#        'La Préceptorie Côtes du Roussillon Blanc Coume Marie 2018',
#        "Domaine de l'Ancienne Cure Bergerac Blanc Sec L'Abbaye 2016",
#        'Clos du Mont-Olivet Vins de Pays du Gard Confluence 2017',
#        "Domaine de l'Hortus Pic Saint-Loup La Bergerie Rouge 2018",
#        'Château de La Liquière Faugères Cistus Blanc 2019',
#        'Maurice Schoech Pinot Noir Pièce de Chêne 2016',
#        'Clos du Mont-Olivet Côtes-du-Rhône Blanc 2019',
#        'Paul Ginglinger Gewurztraminer Wahlenbourg 2017',
#        'François Baur Gewurztraminer Herrenweg de Turckheim 2016',
#        "Maurice Schoech Crémant d'Alsace Brut Rosé Bulles de Granite",
#        'François Baur Pinot Gris Herrenweg de Turckheim 2018',
#        'Elian Daros Côtes du Marmandais Abouriou 2016',
#        "Château de la Selve Coteaux de l'Ardèche Blanc Saint-Régis Blanc 2019",
#        'Clos du Mont-Olivet Lirac Rosé Farel 2019',
#        'Cosse Maisonneuve Cahors Solis 2018',
#        'Plateau des Chênes Lirac 2016',
#        'Pierre Jean Villa IGP Collines Rhodaniennes Gamine 2018',
#        'Borie La Vitarèle Languedoc Blanc Le Grand Mayol 2019',
#        'Domaine Saint-Denis Bourgogne Rouge Le Clos 2017',
#        'Domino Romano Ribera Del Duero Camino Romano 2016',
#        'Ollieux Romanis Corbières Rouge Cuvée Prestige 2017',
#        "Domaine Muré Crémant d'Alsace Cuvée Prestige",
#        'Vincent Carême Vouvray Sec 2018',
#        'Rimauresq Côtes de Provence Cru Classé Rosé 2019',
#        'Oratoire Saint Martin Cairanne Rouge Réserve des Seigneurs 2017',
#        'Jean-Paul Brun Saint-Amour 2017',
#        "Elian Daros Côtes du Marmandais Le Vignoble d'Elian 2016",
#        'Mourgues du Grès Costières de Nîmes Terre de Feu 2017',
#        'Triennes IGP Méditerranée Rouge Saint Auguste 2016',
#        'Plateau des Chênes Lirac 2015',
#        'Domaine Saint-Denis Mâcon Chardonnay 2017',
#        'Domaine de la Monardière Vacqueyras Les Deux Monardes 2017',
#        'Triennes IGP Méditerranée Blanc Sainte Fleur 2018',
#        'I Fabbri Chianti Classico Lamole 2017',
#        'Thierry Germain Saumur-Champigny Cuvée Domaine 2018',
#        'David-Beaupère Juliénas Les Trois Verres 2018',
#        'Domaine Bulliat Morgon Le Colombier 2019',
#        'Domaine Saint-Denis Mâcon Lugny 2017',
#        'Camin Larredya Jurançon Moelleux Costat Darrer 2018',
#        'Emile Boeckel Crémant Chardonnay Extra Brut 2016',
#        'Clos du Mont-Olivet Lirac Rouge 2017',
#        'Thevenet Quintaine Viré-Clessé Emilian Gillet 2017',
#        'Domaine Labranche Laffont Madiran Vieilles Vignes 2015',
#        'La Préceptorie Maury Rouge Cuvée Aurélie 2017',
#        'Domaine Sérol Côte Roannaise Les Millerands 2018',
#        'Emile Boeckel Pinot Gris Grand Cru Zotzenberg 2016',
#        "Domaine Schoenheitz Crémant d'Alsace Mémoire de Granit Extra Brut",
#        'Chermette Domaine du Vissoux Fleurie Poncié 2018',
#        'Chermette Domaine du Vissoux Brouilly Pierreux 2018',
#        'Emile Boeckel Gewurztraminer Grand Cru Zotzenberg 2016',
#        'Domaine Schoenheitz Riesling Herrenreben 2018',
#        'Catherine et Claude Maréchal Bourgogne Aligoté 2018',
#        'Australie Maverick Breechens Blend 2012',
#        'Parcé Frères Banyuls Rimage 2018',
#        'Domaine Saint-Nicolas Vin de France Blanc Les Clous 2019',
#        'Emile Boeckel Riesling Grand Cru Wiebelsberg 2016',
#        "Domaine de l'Ancienne Cure Pécharmant L'Abbaye 2015",
#        'Château Lafont Menaut Pessac-Leognan Blanc 2017',
#        'Emile Boeckel Sylvaner Grand Cru Zotzenberg 2017',
#        'La Préceptorie Maury Blanc 2015',
#        'La Cotelleraie Saint-Nicolas-de-Bourgueil Le Vau Jaumier 2016',
#        'Rimauresq Côtes de Provence Blanc Cru Classé 2019',
#        'Domaine de Montgilet Anjou Rouge Les Yvonnais 2015',
#        'Château Lafont Menaut Pessac-Leognan Rouge 2017',
#        'Bernard Baudry Chinon Rouge Les Grézeaux 2017',
#        'Bernard Baudry Chinon Blanc 2018',
#        'Domaine Sérol Côte Roannaise Perdrizière 2016',
#        'Maison Trimbach Muscat Réserve 2017',
#        'Gilles Robin Crozes-Hermitage Rouge Papillon 2019',
#        "Le Pas de l'Escalette Terrasses du Larzac Les Clapas Rouge 2018",
#        'Domaine La Croix Belle Côtes de Thongue Rouge N°7 2017',
#        "Domaine de l'Ecu Muscadet Orthogneiss 2014",
#        'Borie La Vitarèle Saint-Chinian Les Schistes 2017',
#        'Albert Mann Muscat 2018',
#        'Camin Larredya Jurançon Sec La Part Davant 2018',
#        'Maison Trimbach Riesling 2017',
#        'Domaine Saint-Nicolas Fiefs Vendéens Rouge Reflets 2018',
#        "Domaine de l'Ecu Muscadet Gneiss 2015",
#        'Pierre Martin Sancerre Chavignol Blanc 2019',
#        'Gilbert Picq Chablis 2017', 'Saumaize-Michelin Saint-Véran 2018',
#        'Domaine Pellé Menetou Salon Blanc Morogues 2018',
#        'Rimauresq Côtes de Provence Blanc Cru Classé "R" 2019',
#        "Domaine de l'Ecu Muscadet Granite 2018",
#        'Maroc Graillot/Thaleb Tandem Syrah 2015',
#        'Château Tour Haut-Caussan Médoc 2015',
#        'Chili De Martino Gallardia Cinsault 2017',
#        'Château Saransot-Dupré Listrac-Médoc 2016',
#        'Pierre Martin Sancerre Chavignol Rouge 2017',
#        'Clos du Prieur Terrasses du Larzac 2018',
#        'Antoine-Marie Arena Vin de France Rouge San Giovanni 2017',
#        'Château La Croix Meunier Saint-Emilion Grand Cru 2014',
#        'Planeta Sicilia Etna Bianco 2018',
#        'Domaine de La Tour Du Bon Bandol Rosé 2019',
#        'Domaine La Croix Belle Côtes de Thongue Blanc N°7 2018',
#        'I Fabbri Chianti Classico Terra Di Lamole 2015',
#        'Domaine de Montbourgeau Vin de Paille 2013',
#        'Château de La Liquière Faugères Cistus Rouge 2017',
#        'Domaine Pellé Menetou Salon Rouge Morogues 2017',
#        'Chermette Domaine du Vissoux Moulin à Vent Les Trois Roches 2018',
#        'Château Tour De Pez Saint-Estèphe Les Hauts de Pez 2016',
#        'Zind-Humbrecht Muscat Turckheim 2016',
#        'David-Beaupère Juliénas La Bottière Vieilles Vignes 2018',
#        'Domaine Weinbach Pinot Blanc 2017',
#        'Nouvelle-Zélande Marlborough Momo Sauvignon Blanc 2018',
#        'Château Plaisance Fronton To Co Que Cal 2015',
#        "Château de la Selve Coteaux de l'Ardèche Rouge Serre de Berty 2014",
#        'Ollieux Romanis Corbières Blanc Cuvée Prestige 2018',
#        'Albert Mann Gewurztraminer 2017',
#        'Domaine Schoenheitz Pinot Noir Val Saint Grégoire 2017',
#        'Stéphane Tissot Arbois D.D. 2016',
#        'Pierre Gaillard Côtes-du-Rhône Blanc Les Gendrines 2018',
#        'Marcel Richaud Cairanne Rouge 2018',
#        'Domaine Schoenheitz Gewurztraminer Lisenberg 2015',
#        'Château Dutruch Grand Poujeaux Moulis 2016',
#        'Planeta Sicilia Etna Rosso 2018',
#        'Domaine Schoenheitz Pinot Gris Herrenreben 2017',
#        'Saumaize-Michelin Mâcon Vergisson Sur La Roche 2017',
#        'Maurice Schoech Pinot Gris Grand Cru Schlossberg 2017',
#        'Domaine de Montbourgeau Côtes du Jura Poulsard 2018',
#        'Château de Cazeneuve Languedoc Blanc 2016',
#        'Domaine Bulliat Morgon Amphore Cou de Jus 2019',
#        'Le Cèdre de Jean Faure Saint-Emilion 2016',
#        'Argentine Alamos Catena Malbec 2017',
#        'La Préceptorie Côtes du Roussillon Blanc Terres Nouvelles 2018',
#        'Gilbert Picq Chablis En Vaudécorse 2017',
#        'Saumaize-Michelin Viré-Clessé 2018',
#        'Domaine de La Tour Du Bon Bandol Blanc 2019',
#        'Rimauresq Côtes de Provence Rouge Cru Classé 2017',
#        'Domaine Pellé Sancerre Blanc La Croix Au Garde 2018',
#        'Elian Daros Côtes du Marmandais Chante Coucou 2016',
#        'Albert Boxler Chasselas 2016',
#        "Albert Boxler Crémant d'Alsace Brut 2014",
#        'Pierre Gaillard Saint-Joseph Rouge 2018',
#        'Saumaize-Michelin Saint-Véran Les Crèches 2018',
#        'Oratoire Saint Martin Cairanne Rouge Les Douyes 2016',
#        'Nouvelle-Zélande Marlborough Kim Crawford Sauvignon Blanc 2015',
#        'Domaine Saint-Denis Bourgogne Rouge Clos de la Coque 2018',
#        "Huiles d'Olive Extra Vierge Planeta 3x 10cl",
#        'Domaine Pellé Sancerre Rouge La Croix Au Garde 2017',
#        'Domaine Pellé Menetou Salon Blanc Les Vignes de Ratier 2018',
#        'Domaine Huet Vouvray Pétillant Brut 2014',
#        'Château Tour Des Gendres Bergerac Blanc Moulin Des Dames 2016',
#        "Domaine de Montbourgeau L'Etoile En Banode 2016",
#        "Albert Mann Crémant d'Alsace Extra Brut 2017",
#        'Jacqueson Rully Rouge Les Chaponnières 2018',
#        'Domaine Pellé Menetou Salon Blanc Le Carroir 2018',
#        'Domaine Giudicelli Vin de France Corail Rouge 2019',
#        'Elian Daros Côtes du Marmandais Coucou Blanc 2016',
#        "Le Pas de l'Escalette IGP Hérault Ze Cinsault 2017",
#        "Le Pas de l'Escalette Terrasses du Larzac Le Pas de D. 2017",
#        'Oratoire Saint Martin Cairanne Blanc Haut-Coustias 2017',
#        'Ollieux Romanis Corbières Boutenac Atal Sia 2017',
#        'Gilbert Picq Chablis Vieilles Vignes 2017',
#        'Domaine Brintet Mercurey Rouge Vieilles Vignes 2018',
#        'Oratoire Saint Martin Cairanne Rouge Haut Coustias 2016',
#        'Pierre Jean Villa Crozes-Hermitage Accroche Coeur 2018',
#        'Pierre Martin Sancerre Les Monts Damnés 2018',
#        'Vincent Carême Vouvray Moelleux 2015',
#        'Maurice Schoech Riesling Grand Cru Kaefferkopf 2018',
#        'Domaine Brintet Mercurey Blanc Vieilles Vignes 2018',
#        'Borie La Vitarèle Saint-Chinian Les Crès 2016',
#        'Bernard Baudry Chinon Rouge Le Clos Guillot 2017',
#        'David-Beaupère Juliénas Vayolette 2017',
#        'Château Fonréaud Bordeaux Blanc Le Cygne 2016',
#        'Domaine Giudicelli Vin de France Eté Rouge 2018',
#        'Christophe Pichon Saint-Joseph Blanc 2017',
#        'Gratavinum Priorat 2?r 2017',
#        'Pierre Gaillard Saint-Joseph Blanc 2019',
#        'Domaine Pellé Menetou Salon Rouge Les Cris 2015',
#        "Domaine Muré Crémant d'Alsace Rosé",
#        'Gilles Robin Crozes-Hermitage Rouge Albéric 2017',
#        'Paul Ginglinger Pinot Noir Les Rocailles 2016',
#        'Marcel Richaud Rasteau Rouge 2017',
#        "Le Pas de l'Escalette IGP Pays d'Hérault Les Clapas Blanc 2018",
#        'Domaine de la Monardière Vacqueyras Vieilles Vignes 2016',
#        'Champagne Petit Lebrun &amp; Fils Blanc de Blancs Grand Cru',
#        'Albert Mann Pinot Gris Cuvée Albert 2017',
#        'Nouvelle-Zélande Marlborough Momo Pinot Noir 2016',
#        'Tempier Bandol Rosé 2019',
#        'Paul Ginglinger Pinot Gris Grand Cru Eichberg 2015',
#        'Pierre Gaillard Saint-Joseph Rouge Clos de Cuminaille 2018',
#        'Domaine des Bosquets Gigondas 2016',
#        'Alphonse Mellot Coteaux Charitois Rouge Les Pénitents 2015',
#        'Château du Couvent Pomerol 2017',
#        'Château de Chantegrive Graves Blanc Caroline 2016',
#        'Zind-Humbrecht Pinot Gris Roche Calcaire 2017',
#        'Mas Laval Terrasses du Larzac La Grande Cuvée 2016',
#        'Rimauresq Côtes de Provence Rouge Cru Classé "R" 2017',
#        'Cave de Castelmaure Corbières Rouge N°3 2017',
#        'Domaine de La Tour Du Bon Bandol Rouge 2018',
#        'Gilles Robin Crozes-Hermitage Blanc Les Marelles 2018',
#        'François Baur Riesling Grand Cru Brand Clos De La Treille 2017',
#        'Domaine Schoenheitz Pinot Noir Herrenreben 2017',
#        'Planeta Sicilia Eruzione 1614 2017',
#        'La Rectorie Banyuls Léon Parcé 2016',
#        'Château Cordet Margaux 2013',
#        'Château Peymartin Saint-Julien 2014',
#        "Domaine de l'Hortus Pic Saint-Loup La Grande Cuvée 2018",
#        'Château Tour De Pez Saint-Estèphe 2017',
#        'Château Monbrison Margaux Bouquet de Monbrison 2012',
#        'Chili De Martino Viejas Tinajas Cinsault 2013',
#        'Alphonse Mellot Sancerre Blanc La Moussière 2018',
#        "Domaine de l'Hortus Val de Montferrand La Grande Cuvée Blanc 2018",
#        'Australie Maverick Trial Hill Riesling 2010',
#        'Pierre Jean Villa Saint-Joseph Préface 2018',
#        'Bernard Baudry Chinon Blanc La Croix Boissée 2018',
#        'Domaine Saint-Nicolas Fiefs Vendéens Rouge Cuvée Jacques 2016',
#        'Alain Graillot Crozes-Hermitage Rouge 2017',
#        'Domaine de la Monardière Vacqueyras Blanc Galéjade 2018',
#        'Alain Graillot Crozes-Hermitage Blanc 2018',
#        'Domaine Huet Vouvray Haut-Lieu Sec 2017',
#        'Thibaud Boudignon Anjou Blanc 2018',
#        'Jacqueson Rully Rouge 1er Cru Les Preaux 2018',
#        'Thierry Germain Saumur-Champigny Terres Chaudes 2017',
#        'Thevenet Quintaine Viré-Clessé La Bongran 2015',
#        'I Fabbri Chianti Classico Riserva 2015',
#        'Parés Baltà Penedès Hisenda Miret 2013',
#        'Albert Mann Riesling Cuvée Albert 2017', 'Bon cadeau de 25€',
#        'Château Le Puy Bordeaux Côtes-de-Francs Emilien 2016',
#        'Domaine Giudicelli Patrimonio Rouge 2016',
#        'Domaine Giudicelli Patrimonio Blanc 2019',
#        "Thierry Germain Saumur Blanc L'Insolite 2018",
#        'Saumaize-Michelin Pouilly-Fuissé Vignes Blanches 2018',
#        'Zind-Humbrecht Zind 2017',
#        'Marcel Richaud Cairanne Rouge Les Estrambords 2011',
#        'Antoine-Marie Arena Patrimonio Hauts de Carco 2018',
#        'Jean-Baptiste Arena Patrimonio Blanc Morta Maio',
#        'Antoine-Marie Arena Vin de France Bianco Gentile 2018',
#        'Jean-Baptiste Arena Patrimonio Rouge Grotte Di Sole 2018',
#        'Paul Ginglinger Riesling Grand Cru Pfersigberg 2018',
#        'Gilbert Picq Chablis Vosgros 1er Cru 2017',
#        'Planeta Sicilia Passito di Noto 2016',
#        'Marc Colin Et Fils Chassagne-Montrachet Rouge Vieilles Vignes 2017',
#        'Marc Colin Et Fils Santenay Rouge 2017',
#        'Marc Colin Et Fils Saint-Aubin Blanc Luce 2017',
#        'Domaine Saint-Nicolas Fiefs Vendéens Blanc Le Haut des Clous 2017',
#        "Château La Tour l'Aspic Pauillac 2014",
#        'Gilbert Picq Chablis 1er Cru Vaucoupin 2016',
#        'Domaine Hauvette IGP Alpilles Jaspe 2017',
#        'Planeta Sicilia Chardonnay 2017',
#        'Domaine Huet Vouvray Haut-Lieu Demi-Sec 2015',
#        'Château de Cazeneuve Pic Saint-Loup Le Roc Des Mates 2017',
#        'Château de La Liquière Faugères Tucade 2015',
#        'Stéphane Tissot Arbois Trousseau Singulier 2017',
#        "Château d'Arcole Saint-Emilion Grand Cru 2016",
#        'David Duband Côtes de Nuits Villages 2017',
#        "Le Pas de l'Escalette Terrasses du Larzac Le Grand Pas 2018",
#        'Wemyss Malts Blended Scotch Whisky Lord Elcho',
#        'Camin Larredya Jurançon Sec La Virada 2018',
#        'Domaine Hauvette IGP Alpilles Jaspe 2017',
#        'Albert Boxler Pinot Gris Réserve 2016',
#        "Marcel Richaud Cairanne Rouge L'Ebrescade 2017",
#        'Tempier Bandol Blanc 2018',
#        'Saumaize-Michelin Pouilly-Fuissé Les Ronchevats 2018',
#        "Domaine de Montgilet Coteaux de l'Aubance Les Trois Schistes 2016",
#        'Jacqueson Rully Blanc 1er Cru La Pucelle 2018',
#        'Jacqueson Rully Rouge 1er Cru Les Cloux 2018',
#        'Domaine Augustin Collioure Blanc Adéodat 2019',
#        'Parés Baltà Penedès Electio 2013',
#        'Domaine Augustin Collioure Rouge Adéodat 2017',
#        'Jean-Batiste Arena Muscat du Cap Corse 2015',
#        'Stéphane Tissot Arbois Blanc Les Bruyères 2015',
#        'Domaine de Montcalmès Terrasses du Larzac Rouge 2017',
#        'Decelle-Villa Côte de Nuits Villages "Aux Montagnes" 2014',
#        'Saumaize-Michelin Pouilly-Fuissé Clos sur la Roche 2018',
#        'Maurice Schoech Riesling Vendanges Tardives 2017',
#        'Bernard Baudry Chinon Rouge La Croix Boissée 2017',
#        'Domaine de Montcalmès Coteaux du Languedoc Blanc 2017',
#        'Liban Vallée de la Békaa Château Marsyas 2012',
#        'Elian Daros Côtes du Marmandais Clos Baquey 2015',
#        'François Baur Pinot Noir Sang Du Dragon 2017',
#        'Decelle-Villa Chorey-Lès-Beaune 2016',
#        'Decelle-Villa Marsannay Les Longeroies 2015',
#        "Domaine de l'Ecu Muscadet Taurus 2012",
#        'Maurice Schoech Gewurztraminer Vendanges Tardives 2017',
#        'Champagne Mailly Grand Cru Brut Réserve',
#        'Maurice Schoech Pinot Gris Vendanges Tardives 2015',
#        'Camille Giroud Santenay Rouge 2016',
#        "Domaine Rotier Gaillac Rouge L'Ame 2016",
#        'Château de Villeneuve Saumur-Champigny Le Grand Clos 2017',
#        'Zind-Humbrecht Muscat Grand Cru Goldert 2015',
#        'Planeta Sicilia Noto Santa Cecilia 2016',
#        'Domaine de Bellivière Jasnières Les Rosiers 2015',
#        'Rimauresq Côtes de Provence Rouge Cru Classé Quintessence 2015',
#        'Camin Larredya Jurançon Moelleux Au Capcéu 2018',
#        'Cosse-Maisonneuve Cahors Le Sid 2014',
#        'Domaine Weinbach Gewurztraminer Cuvée Théo 2018',
#        'Alphonse Mellot Sancerre Rouge La Moussière 2014',
#        'Tempier Bandol Rouge 2017',
#        'Domaine Giudicelli Muscat du Cap Corse 2016',
#        'Pierre Gaillard Cornas 2017',
#        'Catherine et Claude Maréchal Ladoix Rouge Les Chaillots 2017',
#        'Catherine et Claude Maréchal Chorey-Lès-Beaune 2017',
#        'Albert Mann Gewurztraminer Grand Cru Steingrubler 2016',
#        'Zind-Humbrecht Riesling Herrenweg de Turckheim 2017',
#        'Domaine Huet Vouvray Le Mont Moelleux 2015',
#        'Philippe Alliet Chinon Rouge Coteau de Noiré 2016',
#        'Château de Vaudieu Châteauneuf-du-Pape Blanc 2015',
#        'Domaine Huet Vouvray Le Mont Sec 2017',
#        'Weingut Besson-Strasser Zürich Blauer Zweigelt 2016',
#        'Catherine et Claude Maréchal Savigny-Lès-Beaune Rouge 2016',
#        'Albert Mann Pinot Gris Grand Cru Furstentum 2016',
#        'Pierre Gaillard Condrieu 2018',
#        'Clos du Mont-Olivet Châteauneuf-du-Pape 2018',
#        'Decelle-Villa Auxey-Duresses Blanc 2017',
#        'Champagne Mailly Grand Cru Extra Brut Millésimé 2012',
#        'Stéphane Tissot Arbois Blanc Savagnin 2015',
#        'Château de Vaudieu Châteauneuf-du-Pape Rouge 2015',
#        'Weingut Besson-Strasser Zürich Räuschling 2018',
#        'Decelle-Villa Savigny-Lès-Beaune Blanc 2018',
#        'Thierry Germain Saumur-Champigny La Marginale 2016',
#        'Camille Giroud Marsannay Rouge Les Longeroies 2016',
#        'Clos du Mont-Olivet Châteauneuf-du-Pape Blanc 2019',
#        'Pierre Jean Villa Saint-Joseph Rouge Tildé 2017',
#        "Pierre Jean Villa Saint-Joseph Saut De l'Ange 2018",
#        'Thierry Germain Saumur-Champigny La Marginale 2017',
#        'Camille Giroud Santenay Blanc 2017',
#        'Domaine Huet Vouvray Le Clos du Bourg Demi-Sec 2017',
#        'Stéphane Tissot Côtes du Jura Sursis 2017',
#        'Emile Boeckel Pinot Noir Terres Rouges 2016',
#        'Stéphane Tissot Arbois Pinot Noir Sous La Tour 2016',
#        'Thierry Germain Saumur-Champigny La Marginale 2018',
#        'Australie Harkham Wines Old Vines 2011',
#        'Champagne Mailly Grand Cru Blanc de Pinot Noir',
#        'Catherine et Claude Maréchal Savigny-Lès-Beaune Rouge 2017',
#        'Camille Giroud Auxey-Duresses Blanc 2017',
#        'Camille Giroud Maranges Rouge 1er Cru Le Croix Moines 2016',
#        "Darnley's London Dry Gin Original",
#        "Darnley's London Dry Gin Spiced",
#        'Thierry Germain Saumur-Champigny Franc De Pied 2016',
#        'Thierry Germain Saumur-Champigny Franc De Pied 2017',
#        'Stéphane Tissot Arbois Blanc La Mailloche 2016',
#        'Le Vieux Donjon Châteauneuf-du-Pape 2013',
#        'Alain Graillot Crozes-Hermitage Rouge La Guiraude 2016',
#        'Champagne Mailly Grand Cru Brut Rosé',
#        'Weingut Besson-Strasser Zürich Pinot Noir Cholfirst 2017',
#        'Mas de Daumas Gassac IGP Saint-Guilhem-le-Désert 2018',
#        'Mas de Daumas Gassac IGP Saint-Guilhem-le-Désert Blanc 2019',
#        "Thierry Germain Saumur-Champigny Clos de l'Echelier 2017",
#        'Camille Giroud Santenay Rouge 1er Cru Clos Rousseau 2016',
#        'Albert Boxler Pinot Noir "S" 2016',
#        'Christophe Pichon Condrieu 2017',
#        'Domaine Chambeyron Côte Rôtie La Chavarine 2017',
#        'Domaine Weinbach Riesling Cuvée Colette 2018',
#        'Domaine Hauvette Les Baux de Provence Cornaline 2014',
#        'Domaine Chambeyron Condrieu Vernon 2018',
#        'Champagne Larmandier-Bernier Latitude',
#        'Le Vieux Donjon Châteauneuf-du-Pape 2016',
#        'Chili Montsecano (Ostertag) Pinot Noir 2013',
#        'Champagne Gosset Grande Réserve',
#        'Domaine de La Tour Du Bon Bandol Rouge Saint Ferréol 2018',
#        'Gilles Robin Saint-Joseph Rouge André Péalat 2010',
#        'Marcel Windholtz Eau de Vie de Marc de Muscat',
#        'Lucien Boillot Volnay 2017',
#        'Saumaize-Michelin Pouilly-Fuissé Ampélopsis 2016',
#        'Château Carbonnieux Graves Blanc 2017',
#        'Thierry Germain Saumur-Champigny Les Mémoires 2016',
#        "Le Pas de l'Escalette Terrasses du Larzac Les Frieys 2017",
#        'Borie La Vitarèle Saint-Chinian Midi Rouge 2015',
#        'Stéphane Tissot Arbois Trousseau Amphore 2017',
#        'Château de Cazeneuve Pic Saint-Loup Le Sang Du Calvaire 2017',
#        'Domaine Des Croix Beaune 1er Cru Les Cent Vignes 2017',
#        'Marcel Windholtz Eau de Vie de Marc de Gewurztraminer',
#        'Agnès Levet Côte Rôtie Améthyste 2017',
#        'Maurice Schoech Riesling Grand Cru Rangen de Thann 2014',
#        'Marc Colin Et Fils Saint-Aubin Blanc En Montceau 2017',
#        'Marc Colin Et Fils Saint-Aubin 1er Cru La Chatenière 2017',
#        'Weingut Besson-Strasser Zürich Fumé 2017',
#        'Gratavinum Priorat GV5 2011',
#        'Domaine Saint-Nicolas Fiefs Vendéens Rouge La Grande Pièce 2013',
#        'Domaine Clerget Chambolle-Musigny 2014',
#        'Thierry Germain Saumur-Champigny Les Mémoires 2018',
#        "Huile d'Olive Extra Vierge Planeta Selezione Chef 3L",
#        'Pierre Gaillard Côte Rôtie 2018',
#        'Thierry Germain Saumur-Champigny Outre Terre 2013',
#        'Thierry Germain Saumur-Champigny Outre Terre 2014',
#        'Decelle-Villa Nuits-Saint-Georges Rouge 2016',
#        'Decelle-Villa Beaune Rouge 2015',
#        'Marc Colin Et Fils Chassagne-Montrachet Blanc Margot 2017',
#        "Domaine de Montbourgeau L'Etoile Vin Jaune 2009",
#        'Decelle-Villa Saint-Aubin 1er Cru Sous Roche Dumay 2015',
#        'Albert Mann Pinot Gris Vendanges Tardives Altenbourg 2011',
#        'Domaine de La Tour Du Bon Bandol Rouge En Sol 2017',
#        'Cognac Frapin 1270',
#        'Domaine des Bosquets Gigondas La Colline 2015',
#        'Clos du Mont-Olivet Châteauneuf-du-Pape 2012',
#        'Gilles Robin Crozes-Hermitage Rouge "1920" 2016',
#        'Domaine Hauvette IGP Alpilles Dolia 2012',
#        'Champagne Agrapart &amp; Fils Les 7 Crus Brut Blanc de Blancs',
#        'Lucien Boillot Gevrey Chambertin 2017',
#        'Borie de Maurel Minervois Rouge Maxime 2003',
#        'Domaine de Vaccelli AOP Ajaccio Rouge Granit 2016',
#        'Domaine Des Croix Savigny-Lès-Beaune 1er Cru Les Peuillets 2015',
#        'Pierre Jean Villa Côte Rôtie Carmina 2017',
#        'Domaine de Vaccelli Ajaccio Blanc Sirocco 2017',
#        'Gilles Robin Cornas 2016', 'Château Simone Palette Blanc 2017',
#        'Domino Romano Ribera del Duero RDR 2015',
#        'Château Simone Palette Rouge 2015',
#        'Weingut Besson-Strasser Zürich Pinot Noir Albi 2016',
#        "Domaine Chambeyron Côte Rôtie L'Angéline 2017",
#        'Domaine Hauvette IGP Alpilles Dolia 2013',
#        'Albert Mann Pinot Noir Clos de la Faille 2017',
#        'I Fabbri Chianti Classico Gran Selezione 2015',
#        'Lucien Boillot Pommard 2017',
#        'David Duband Nuits-Saint-Georges 2017',
#        'David Duband Morey-Saint-Denis 2017',
#        'Thierry Germain Saumur-Champigny Outre Terre 2016',
#        'Thierry Germain Saumur-Champigny Outre Terre 2017',
#        'Thierry Germain Saumur Blanc Terres 2014',
#        'Champagne Gosset Grand Rosé',
#        'Champagne Gosset Grand Blanc de Blancs',
#        'Catherine et Claude Maréchal Pommard La Chanière 2016',
#        'Wemyss Malts Blended Malt Scotch Whisky Peat Chimney',
#        'Albert Mann Riesling Grand Cru Furstentum 2017',
#        'Decelle-Villa Meursault 2018',
#        'Champagne Larmandier-Bernier Terre de Vertus Premier Cru 2011',
#        'Wemyss Malts Blended Malt Scotch Whisky The Hive',
#        'Wemyss Malts Blended Malt Scotch Whisky Spice King',
#        'Château Jean Faure Saint-Emilion Grand Cru 2016',
#        "Marcel Windholtz Eau de Vie de Framboise d'Alsace",
#        "Marcel Windholtz Eau de Vie de Quetsch d'Alsace Réserve Particulière",
#        'Catherine et Claude Maréchal Volnay 2017',
#        'Catherine et Claude Maréchal Pommard La Chanière 2017',
#        'Château Jean Faure Saint-Emilion Grand Cru 2015',
#        'Domaine de La Tour Du Bon Bandol Rouge Saint Ferréol 2005',
#        'Champagne Egly-Ouriet Premier Cru Les Vignes de Vrigny',
#        'Marcel Windholtz Eau de Vie de Sureau',
#        "Marcel Windholtz Eau de Vie de Mirabelle d'Alsace Réserve Particulière",
#        'Marcel Windholtz Eau de Vie de Fraise',
#        'Lucien Boillot Gevrey Chambertin Les Evocelles 2017',
#        'Weingut Besson-Strasser Zürich Pinot Noir Chlosterberg 2016',
#        'Marcel Windholtz Eau de Vie de Prunelle Sauvage',
#        'Champagne Gosset Grand Millésime 2006',
#        'Alphonse Mellot Sancerre Blanc Edmond 2016',
#        'Clos du Mont-Olivet Châteauneuf-du-Pape 2007',
#        'Clos du Mont-Olivet Châteauneuf-du-Pape 2007',
#        'Agnès Levet Côte Rôtie Maestria 2017',
#        'Albert Mann Riesling Grand Cru Schlossberg 2018',
#        'Domaine des Comtes Lafon Monthélie 1er Cru Les Duresses 2017',
#        'Maison Trimbach Riesling Cuvée Frédéric Emile 2008',
#        'Zind-Humbrecht Gewurztraminer Clos Windsbuhl 2012',
#        'Albert Boxler Pinot Gris Grand Cru Sommerberg "W" 2016',
#        'Kingsbarns Distillery Lowland Single Malt Whisky',
#        'Domaine Clerget Vosne-Romanée Les Violettes 2015',
#        'Wemyss Malts Blended Malt Scotch Whisky Vanilla Burst',
#        'Alphonse Mellot Sancerre Rouge La Demoiselle 2015',
#        'Agnès Levet Côte Rôtie Péroline 2017',
#        'Maison Trimbach Riesling Grand Cru Geisberg 2012',
#        'Albert Mann Gewurztraminer Vendanges Tardives Altenbourg 2015',
#        'Thierry Germain Saumur Blanc Clos Roman 2016',
#        'Tempier Bandol Tourtine 2017', 'Tempier Bandol Migoua 2017',
#        'Marcel Windholtz Eau de Vie de Poire Williams Réserve Particulière',
#        'Lucien Boillot Volnay 1er Cru Les Angles 2017',
#        'Champagne Mailly Grand Cru Intemporelle 2010',
#        'Wemyss Malts Blended Malt Scotch Whisky The Hive Batch Strength',
#        'Wemyss Malts Blended Malt Scotch Whisky Peat Chimney Batch Strength',
#        'Alphonse Mellot Sancerre Rouge En Grands Champs 2012',
#        'Champagne Egly-Ouriet Grand Cru Brut Tradition',
#        'Wemyss Malts Blended Malt Scotch Whisky Spice King Batch Strength',
#        'David Duband Vosne Romanée 2017',
#        'Domaine Huet Vouvray Le Mont Moelleux Première Trie 2008',
#        'Domaine Huet Vouvray Le Clos du Bourg Moelleux Première Trie 2008',
#        'Wemyss Malts Blended Malt Scotch Whisky Treacle Chest',
#        'Cognac Normandin Mercier VFC',
#        'Albert Mann Pinot Noir Grand H 2017',
#        'Albert Mann Pinot Noir Grand P 2017',
#        'Gilles Robin Hermitage Rouge 2012',
#        'Pierre Gaillard Côte Rôtie Esprit de Blonde 2017',
#        'Domaine Chambeyron Côte Rôtie Lancement 2017',
#        'Marc Colin Et Fils Chassagne-Montrachet Blanc Les Vide-Bourses 1er Cru 2016',
#        'Marc Colin Et Fils Chassagne-Montrachet Blanc Les Vide-Bourses 1er Cru 2016',
#        'Wemyss Malts Blended Malt Scotch Whisky The Hive 12 ans',
#        'Champagne Agrapart &amp; Fils Terroirs Brut Blanc de Blancs Grand Cru',
#        "Marcel Windholtz Eau de Vie de Kirsch d'Alsace Réserve Particulière",
#        'Marcel Windholtz Eau de Vie de Coing',
#        'Stéphane Tissot Arbois Vin Jaune En Spois 2011',
#        'Cognac Frapin VSOP',
#        'Domaine Weinbach Riesling Grand Cru Schlossberg Cuvée Ste Catherine 2018',
#        'Maison Trimbach Riesling Cuvée Frédéric Emile 2012',
#        'Maison Trimbach Riesling Grand Cru Schlossberg 2015',
#        'David Duband Morey-Saint-Denis 1er Cru Les Broc 2016',
#        'Albert Mann Pinot Noir Les Saintes Claires 2017',
#        'Marc Colin Et Fils Chassagne-Montrachet Blanc Les Caillerets 1er Cru 2016',
#        'Lucien Boillot Pommard 1er Cru Les Croix Noires 2017',
#        'Château de Meursault Beaune-Grèves Les Trois Journaux 1er Cru 2015',
#        'Alphonse Mellot Sancerre Rouge Génération XIX 2011',
#        'Cognac Frapin Château de Fontpinot XO 1/2',
#        'Marc Colin Et Fils Chassagne-Montrachet 1er Cru Les Champs Gain 2017',
#        'Domaine Jamet Côte Rôtie Fructus Voluptas 2018',
#        'Champagne Mailly Grand Cru Intemporelle Rosé 2009',
#        'Zind-Humbrecht Riesling Clos Windsbuhl 2014',
#        'Domaine Hauvette Les Baux de Provence Amethyste 2017',
#        'Albert Boxler Riesling Grand Cru Sommerberg "E" 2018',
#        'Albert Boxler Riesling Grand Cru Sommerberg "D" 2018',
#        'Zind-Humbrecht Pinot Gris Clos Windsbuhl 2013',
#        'Clos du Mont-Olivet Châteauneuf-du-Pape Cuvée du Papet 2018',
#        'Château de Vaudieu Châteauneuf-du-Pape Amiral G 2015',
#        'Decelle-Villa Chambolle-Musigny 2017',
#        'Domaine Clerget Chambolle-Musigny Les Charmes 2015',
#        'Domaine de Vaccelli AOP Ajaccio Rouge Granit 174 2017',
#        'Stéphane Tissot Château-Chalon 2011',
#        'Marcel Windholtz Eau de Vie de Baie de Houx',
#        'Champagne Larmandier-Bernier Grand Cru Vieilles Vignes du Levant 2008',
#        'Zind-Humbrecht Gewurztraminer Grand Cru Rangen De Thann Clos Saint-Urbain 2013',
#        "Château de Vaudieu Châteauneuf-du-Pape L'Avenue 2015",
#        'Lucien Boillot Gevrey Chambertin 1er Cru Les Cherbaudes 2017',
#        'Domaine Peyre Rose Syrah Léone 2008',
#        'Domaine Peyre Rose Clos des Cistes 2008',
#        'Domaine Peyre Rose Oro Blanc 2002',
#        'Domaine Peyre Rose Marlène N°3 2008',
#        'Champagne Egly-Ouriet Grand Cru Brut Rosé',
#        'Champagne Egly-Ouriet Grand Cru Extra Brut V.P.',
#        'Lucien Boillot Nuits-Saint-Georges 1er Cru Les Pruliers 2017',
#        'Pierre Gaillard Côte Rôtie Rose Pourpre 2017',
#        'Champagne Mailly Grand Cru Les Echansons 2007',
#        'Lucien Boillot Puligny-Montrachet 1er Cru Les Perrières 2016',
#        "Champagne Larmandier-Bernier Grand Cru Les Chemins d'Avize 2011",
#        'Champagne Agrapart &amp; Fils Minéral Extra Brut Blanc de Blancs Grand Cru 2012',
#        'Zind-Humbrecht Pinot Gris Grand Cru Rangen De Thann Clos Saint-Urbain 2012',
#        'Tempier Bandol Cabassaou 2017',
#        'Wemyss Malts Single Cask Scotch Whisky Chocolate Moka Cake 2005 Strathclyde',
#        'Domaine des Comtes Lafon Volnay 1er Cru Champans 2013',
#        'Zind-Humbrecht Riesling Grand Cru Rangen De Thann Clos Saint-Urbain 2017',
#        'Domaine Des Croix Corton Grand Cru Les Grèves 2017',
#        'Cognac Frapin Cigar Blend',
#        'Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2014',
#        'Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2013',
#        'David Duband Chambolle-Musigny 1er Cru Les Sentiers 2016',
#        'Cognac Frapin Château de Fontpinot XO',
#        'Château de Meursault Puligny-Montrachet 1er Cru Champ Canet 2014',
#        "Champagne Agrapart &amp; Fils L'Avizoise Extra Brut Blanc de Blancs Grand Cru 2012",
#        'Wemyss Malts Single Cask Scotch Whisky Chai Caramel Latte 2002 Craigellachie',
#        'Domaine des Comtes Lafon Volnay 1er Cru Champans 2014',
#        'Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2015',
#        'Domaine Clerget Echezeaux Grand Cru En Orveaux 2015',
#        'Domaine des Comtes Lafon Volnay 1er Cru Santenots du Milieu 2016',
#        'Domaine des Comtes Lafon Volnay 1er Cru Champans 2016',
#        "Wemyss Malts Single Cask Scotch Whisky Choc 'n' Nut Pretzel 2001 Bunnahabhain",
#        'Domaine Weinbach Gewurztraminer Grand Cru Furstentum SGN 2010 1/2',
#        'Champagne Egly-Ouriet Grand Cru Blanc de Noirs',
#        'Champagne Gosset Célébris Vintage 2007',
#        'Domaine Des Croix Corton Charlemagne Grand Cru 2016',
#        "Cognac Frapin Château de Fontpinot 1989 20 Ans d'Age",
#        'Camille Giroud Clos de Vougeot 2016', 'Cognac Frapin VIP XO',
#        'Coteaux Champenois Egly-Ouriet Ambonnay Rouge 2016',
#        'David Duband Charmes-Chambertin Grand Cru 2014',
#        'Champagne Egly-Ouriet Grand Cru Millésimé 2008'], dtype=object)

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

# Create a list of word
text="BottleNeck BottleNeck BottleNeck  BottleNeck  BottleNeck   vin champagne AOC Bordeaux Bordeaux Bourgogne Bourgogne Gewurztraminer Grand Cru Château Turcaud Bordeaux Rouge Domaine La Croix    Beaune Vieilles Vignes Champagne Mailly Grand Cru  Mailly Grand Cru Brut Réserve Alscace Jurançon Pinot Gris Vendanges Tardives Sec Pinot Gris Champagne Gosset  Pinot Noir Domaine Huet Vouvray Saumur Blanc Clos RomanDomaine Saint-Nicolas Château de Villeneuve Saumur-Champigny Domaine Labranche Pinot Noir Sous La Tour Chambolle-Musigny 1er Cru  Wemyss Malts Single Cask Scotch Whisky Domaine de La Tour Cognac Frapin" #+Global.query("post_title != 0").post_title.values
text
# text

# # Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
